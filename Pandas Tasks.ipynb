# %%
import pandas as pd

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = pd.read_json(url)
data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/46351  1167422549
# 1     https://github.com/pandas-dev/pandas/pull/46350  1167422110
# 2     https://github.com/pandas-dev/pandas/pull/46349  1167417912
# 3     https://github.com/pandas-dev/pandas/pull/46348  1167412829
# 4     https://github.com/pandas-dev/pandas/pull/46347  1167404425
# 5     https://github.com/pandas-dev/pandas/pull/46346  1167386303
# 6     https://github.com/pandas-dev/pandas/pull/46343  1167366731
# 7     https://github.com/pandas-dev/pandas/pull/46342  1167331327
# 8     https://github.com/pandas-dev/pandas/pull/46341  1167329989
# 9   https://github.com/pandas-dev/pandas/issues/46339  1167181077
# 10    https://github.com/pandas-dev/pandas/pull/46338  1167165103
# 11  https://github.com/pandas-dev/pandas/issues/46337  1167162310
# 12  https://github.com/pandas-dev/pandas/issues/46336  1167160890
# 13  https://github.com/pandas-dev/pandas/issues/46332  1166971186
# 14  https://github.com/pandas-dev/pandas/issues/46331  1166957820
# 15    https://github.com/pandas-dev/pandas/pull/46330  1166865454
# 16  https://github.com/pandas-dev/pandas/issues/46326  1166612234
# 17  https://github.com/pandas-dev/pandas/issues/46324  1166353036
# 18    https://github.com/pandas-dev/pandas/pull/46321  1166312846
# 19  https://github.com/pandas-dev/pandas/issues/46319  1166255061
# 20  https://github.com/pandas-dev/pandas/issues/46313  1165672382
# 21    https://github.com/pandas-dev/pandas/pull/46312  1165636565
# 22  https://github.com/pandas-dev/pandas/issues/46310  1165554305
# 23    https://github.com/pandas-dev/pandas/pull/46308  1165401382
# 24  https://github.com/pandas-dev/pandas/issues/46305  1165243629
# 25    https://github.com/pandas-dev/pandas/pull/46304  1165164366
# 26    https://github.com/pandas-dev/pandas/pull/46300  1164717212
# 27  https://github.com/pandas-dev/pandas/issues/46298  1164620575
# 28  https://github.com/pandas-dev/pandas/issues/46297  1164499430
# 29  https://github.com/pandas-dev/pandas/issues/46294  1164194103
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85FlXRV   46351
# 1   PR_kwDOAA0YD840WVgz   46350
# 2   PR_kwDOAA0YD840WUvE   46349
# 3   PR_kwDOAA0YD840WT3e   46348
# 4   PR_kwDOAA0YD840WSZR   46347
# 5   PR_kwDOAA0YD840WO50   46346
# 6   PR_kwDOAA0YD840WLMs   46343
# 7   PR_kwDOAA0YD840WEz_   46342
# 8   PR_kwDOAA0YD840WEmO   46341
# 9    I_kwDOAA0YD85FkcUV   46339
# 10  PR_kwDOAA0YD840VmSV   46338
# 11   I_kwDOAA0YD85FkXvG   46337
# 12   I_kwDOAA0YD85FkXY6   46336
# 13   I_kwDOAA0YD85FjpEy   46332
# 14   I_kwDOAA0YD85Fjlz8   46331
# 15  PR_kwDOAA0YD840UmcA   46330
# 16   I_kwDOAA0YD85FiRcK   46326
# 17   I_kwDOAA0YD85FhSKM   46324
# 18  PR_kwDOAA0YD840SzrD   46321
# 19   I_kwDOAA0YD85Fg6PV   46319
# 20   I_kwDOAA0YD85Fer--   46313
# 21  PR_kwDOAA0YD840QmJ_   46312
# 22   I_kwDOAA0YD85FePKB   46310
# 23  PR_kwDOAA0YD840P1BQ   46308
# 24   I_kwDOAA0YD85FdDTt   46305
# 25  PR_kwDOAA0YD840PCL-   46304
# 26  PR_kwDOAA0YD840Nj7j   46300
# 27   I_kwDOAA0YD85FarMf   46298
# 28   I_kwDOAA0YD85FaNnm   46297
# 29   I_kwDOAA0YD85FZDE3   46294
#
#                                                 title  ...  \
# 0                     Question: why use Azure for CI?  ...
# 1   TST: xfail(strict=False) flaky hashtable test ...  ...
# 2                            PERF: Index[StringArray]  ...
# 3   Series.map Performance Improvement When Using ...  ...
# 4                                  Fix snappy version  ...
# 5                   WIP Use provision-with-micromamba  ...
# 6   TYP: Add typing for pd.to_timedelta, fix Timed...  ...
# 7              Bug fix -  groupby sum removed columns  ...
# 8             PERF: use bisect_right_i8 in vectorized  ...
# 9                                       PyCon US 2022  ...
# 10             REF: de-duplicate hard-coded unit code  ...
# 11                   TYP: returning None for __init__  ...
# 12  BUG: dataframe.rename function shows no warnin...  ...
# 13  BUG: Binary operations with empty string array...  ...
# 14  BUG: the behavior of "date_range" function wit...  ...
# 15  REF/PERF: MultiIndex.get_locs to use boolean a...  ...
# 16  BUG: `isin` propagates nulls for DataFrame but...  ...
# 17  BUG: core.groupby.GroupBy.apply unexpected beh...  ...
# 18                     WIP Add ccache to Azure builds  ...
# 19  BUG: `UnicodeError` when using `Period.strftim...  ...
# 20  BUG: Categorical of booleans has object .categ...  ...
# 21         BUG: avoid OOB flow in read_gbq and to_gbq  ...
# 22      ENH: Add `subset` param to `add_(pre|suf)fix`  ...
# 23                    DOC: Add TextFileReader to docs  ...
# 24  ENH: merging using DataFrame index should rais...  ...
# 25  BUG: merge raising for Int64 and int64 dtype w...  ...
# 26                                    TYP: sort_index  ...
# 27           BUG:  "data type 'Int64' not understood"  ...
# 28  BUG: Error writing DataFrame with categorical ...  ...
# 29  BUG: Setting datetime value using dataframe ma...  ...
#
#                   updated_at closed_at author_association  active_lock_reason  \
# 0  2022-03-12 23:13:37+00:00       NaT        CONTRIBUTOR                 NaN
# 1  2022-03-13 00:56:30+00:00       NaT             MEMBER                 NaN
# 2  2022-03-12 22:40:13+00:00       NaT             MEMBER                 NaN
# 3  2022-03-12 23:36:30+00:00       NaT               NONE                 NaN
# 4  2022-03-13 00:23:34+00:00       NaT        CONTRIBUTOR                 NaN
# 5  2022-03-12 21:42:38+00:00       NaT        CONTRIBUTOR                 NaN
# 6  2022-03-13 00:05:22+00:00       NaT        CONTRIBUTOR                 NaN
# 7  2022-03-12 16:36:23+00:00       NaT        CONTRIBUTOR                 NaN
# 8  2022-03-13 01:27:44+00:00       NaT             MEMBER                 NaN
# 9  2022-03-12 05:00:28+00:00       NaT             MEMBER                 NaN
# 10 2022-03-13 01:34:01+00:00       NaT             MEMBER                 NaN
# 11 2022-03-12 18:37:12+00:00       NaT        CONTRIBUTOR                 NaN
# 12 2022-03-12 14:48:33+00:00       NaT               NONE                 NaN
# 13 2022-03-11 23:15:26+00:00       NaT               NONE                 NaN
# 14 2022-03-12 14:00:18+00:00       NaT               NONE                 NaN
# 15 2022-03-12 21:07:45+00:00       NaT             MEMBER                 NaN
# 16 2022-03-11 16:53:06+00:00       NaT               NONE                 NaN
# 17 2022-03-11 12:19:20+00:00       NaT               NONE                 NaN
# 18 2022-03-12 19:10:13+00:00       NaT        CONTRIBUTOR                 NaN
# 19 2022-03-11 10:51:46+00:00       NaT        CONTRIBUTOR                 NaN
# 20 2022-03-11 12:32:13+00:00       NaT        CONTRIBUTOR                 NaN
# 21 2022-03-11 01:30:39+00:00       NaT        CONTRIBUTOR                 NaN
# 22 2022-03-11 00:46:10+00:00       NaT        CONTRIBUTOR                 NaN
# 23 2022-03-11 23:48:13+00:00       NaT             MEMBER                 NaN
# 24 2022-03-10 13:42:15+00:00       NaT               NONE                 NaN
# 25 2022-03-10 19:40:21+00:00       NaT             MEMBER                 NaN
# 26 2022-03-12 20:30:13+00:00       NaT        CONTRIBUTOR                 NaN
# 27 2022-03-10 09:32:52+00:00       NaT               NONE                 NaN
# 28 2022-03-09 22:18:16+00:00       NaT               NONE                 NaN
# 29 2022-03-09 17:20:02+00:00       NaT               NONE                 NaN
#
#                                                  body  \
# 0   What’s the reason that pandas uses GHA alongsi...
# 1   - [x] [Tests added and passed](https://pandas....
# 2   - [x] closes #45652 (Replace xxxx with the Git...
# 3   - [x] closes #46248\r\n- [ ] [Tests added and ...
# 4   Fix for https://github.com/pandas-dev/pandas/p...
# 5   Based on #45701\r\n\r\n- [ ] closes #xxxx (Rep...
# 6   Add typing for pd.to_timedelta\r\nChange opera...
# 7   - [x] closes #44132 \r\n- [ ] [Tests added and...
# 8   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 9   Do we have any plan for PyCon US 2022?\r\n\r\n...
# 10  I had hoped  to go further and get rid of one ...
# 11  xref https://github.com/pandas-dev/pandas/pull...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  ### Pandas version checks\r\n\r\n- [X] I have ...
# 14  ### Pandas version checks\r\n\r\n- [X] I have ...
# 15  - [x] [Tests added and passed](https://pandas....
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  ### Pandas version checks\n\n- [X] I have chec...
# 18  Save around 5-10 minutes on Azure\r\n\r\nWhy d...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Pandas version checks\n\n- [X] I have chec...
# 21  The console-based copy-paste-a-token flow has ...
# 22  #### Is your feature request related to a prob...
# 23  - [x] closes #46187 (Replace xxxx with the Git...
# 24  DataFrame `merge` has inconsistent behaviour d...
# 25  - [x] closes #46178 (Replace xxxx with the Git...
# 26  Tested the overloads with mypy and pyright:\r\...
# 27  ### Pandas version checks\n\n- [X] I have chec...
# 28  ### Pandas version checks\n\n- [X] I have chec...
# 29  ### Pandas version checks\r\n\r\n- [X] I have ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#     performed_via_github_app draft  \
# 0                        NaN   NaN
# 1                        NaN   0.0
# 2                        NaN   0.0
# 3                        NaN   0.0
# 4                        NaN   0.0
# 5                        NaN   1.0
# 6                        NaN   0.0
# 7                        NaN   0.0
# 8                        NaN   0.0
# 9                        NaN   NaN
# 10                       NaN   0.0
# 11                       NaN   NaN
# 12                       NaN   NaN
# 13                       NaN   NaN
# 14                       NaN   NaN
# 15                       NaN   0.0
# 16                       NaN   NaN
# 17                       NaN   NaN
# 18                       NaN   1.0
# 19                       NaN   NaN
# 20                       NaN   NaN
# 21                       NaN   0.0
# 22                       NaN   NaN
# 23                       NaN   0.0
# 24                       NaN   NaN
# 25                       NaN   0.0
# 26                       NaN   0.0
# 27                       NaN   NaN
# 28                       NaN   NaN
# 29                       NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 29 columns]

# %%
len(data)
# Out:
# 30

# %%
len(data.columns)
# Out:
# 29

# %%
for i in data.columns:
    print(i)
# Out:
# url
# repository_url
# labels_url
# comments_url
# events_url
# html_url
# id
# node_id
# number
# title
# user
# labels
# state
# locked
# assignee
# assignees
# milestone
# comments
# created_at
# updated_at
# closed_at
# author_association
# active_lock_reason
# body
# reactions
# timeline_url
# performed_via_github_app
# draft
# pull_request

# %%
a = pd.DataFrame()
for k in data.columns:
    for i in data[k]:
        if type(i) == dict:
            d = pd.json_normalize(data[k])
            u = pd.concat([a,d],axis=1)
            a = u
            
        else:
            d1 = pd.DataFrame(data[k])
            v = pd.concat([a,d1],axis=1)
            a = v

# %%
a.to_csv("allrecord.csv", index=False)

# %%
f = pd.read_csv('allrecord.csv')

# %%
f
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.1  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.2  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.3  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.4  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.5  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.6  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.7  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.8  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 url.9  ...  \
# 0   https://api.github.com/repos/pandas-dev/pandas...  ...
# 1   https://api.github.com/repos/pandas-dev/pandas...  ...
# 2   https://api.github.com/repos/pandas-dev/pandas...  ...
# 3   https://api.github.com/repos/pandas-dev/pandas...  ...
# 4   https://api.github.com/repos/pandas-dev/pandas...  ...
# 5   https://api.github.com/repos/pandas-dev/pandas...  ...
# 6   https://api.github.com/repos/pandas-dev/pandas...  ...
# 7   https://api.github.com/repos/pandas-dev/pandas...  ...
# 8   https://api.github.com/repos/pandas-dev/pandas...  ...
# 9   https://api.github.com/repos/pandas-dev/pandas...  ...
# 10  https://api.github.com/repos/pandas-dev/pandas...  ...
# 11  https://api.github.com/repos/pandas-dev/pandas...  ...
# 12  https://api.github.com/repos/pandas-dev/pandas...  ...
# 13  https://api.github.com/repos/pandas-dev/pandas...  ...
# 14  https://api.github.com/repos/pandas-dev/pandas...  ...
# 15  https://api.github.com/repos/pandas-dev/pandas...  ...
# 16  https://api.github.com/repos/pandas-dev/pandas...  ...
# 17  https://api.github.com/repos/pandas-dev/pandas...  ...
# 18  https://api.github.com/repos/pandas-dev/pandas...  ...
# 19  https://api.github.com/repos/pandas-dev/pandas...  ...
# 20  https://api.github.com/repos/pandas-dev/pandas...  ...
# 21  https://api.github.com/repos/pandas-dev/pandas...  ...
# 22  https://api.github.com/repos/pandas-dev/pandas...  ...
# 23  https://api.github.com/repos/pandas-dev/pandas...  ...
# 24  https://api.github.com/repos/pandas-dev/pandas...  ...
# 25  https://api.github.com/repos/pandas-dev/pandas...  ...
# 26  https://api.github.com/repos/pandas-dev/pandas...  ...
# 27  https://api.github.com/repos/pandas-dev/pandas...  ...
# 28  https://api.github.com/repos/pandas-dev/pandas...  ...
# 29  https://api.github.com/repos/pandas-dev/pandas...  ...
#
#                                          patch_url.13 merged_at.13  \
# 0                                                 NaN          NaN
# 1   https://github.com/pandas-dev/pandas/pull/4635...          NaN
# 2   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 3   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 4   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 5   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 6   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 7   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 8   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 9                                                 NaN          NaN
# 10  https://github.com/pandas-dev/pandas/pull/4633...          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15  https://github.com/pandas-dev/pandas/pull/4633...          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18  https://github.com/pandas-dev/pandas/pull/4632...          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21  https://github.com/pandas-dev/pandas/pull/4631...          NaN
# 22                                                NaN          NaN
# 23  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 24                                                NaN          NaN
# 25  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 26  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
#
#                                               url.111  \
# 0                                                 NaN
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9                                                 NaN
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16                                                NaN
# 17                                                NaN
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22                                                NaN
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24                                                NaN
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                         html_url.81  \
# 0                                               NaN
# 1   https://github.com/pandas-dev/pandas/pull/46350
# 2   https://github.com/pandas-dev/pandas/pull/46349
# 3   https://github.com/pandas-dev/pandas/pull/46348
# 4   https://github.com/pandas-dev/pandas/pull/46347
# 5   https://github.com/pandas-dev/pandas/pull/46346
# 6   https://github.com/pandas-dev/pandas/pull/46343
# 7   https://github.com/pandas-dev/pandas/pull/46342
# 8   https://github.com/pandas-dev/pandas/pull/46341
# 9                                               NaN
# 10  https://github.com/pandas-dev/pandas/pull/46338
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15  https://github.com/pandas-dev/pandas/pull/46330
# 16                                              NaN
# 17                                              NaN
# 18  https://github.com/pandas-dev/pandas/pull/46321
# 19                                              NaN
# 20                                              NaN
# 21  https://github.com/pandas-dev/pandas/pull/46312
# 22                                              NaN
# 23  https://github.com/pandas-dev/pandas/pull/46308
# 24                                              NaN
# 25  https://github.com/pandas-dev/pandas/pull/46304
# 26  https://github.com/pandas-dev/pandas/pull/46300
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
#
#                                           diff_url.14  \
# 0                                                 NaN
# 1   https://github.com/pandas-dev/pandas/pull/4635...
# 2   https://github.com/pandas-dev/pandas/pull/4634...
# 3   https://github.com/pandas-dev/pandas/pull/4634...
# 4   https://github.com/pandas-dev/pandas/pull/4634...
# 5   https://github.com/pandas-dev/pandas/pull/4634...
# 6   https://github.com/pandas-dev/pandas/pull/4634...
# 7   https://github.com/pandas-dev/pandas/pull/4634...
# 8   https://github.com/pandas-dev/pandas/pull/4634...
# 9                                                 NaN
# 10  https://github.com/pandas-dev/pandas/pull/4633...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://github.com/pandas-dev/pandas/pull/4633...
# 16                                                NaN
# 17                                                NaN
# 18  https://github.com/pandas-dev/pandas/pull/4632...
# 19                                                NaN
# 20                                                NaN
# 21  https://github.com/pandas-dev/pandas/pull/4631...
# 22                                                NaN
# 23  https://github.com/pandas-dev/pandas/pull/4630...
# 24                                                NaN
# 25  https://github.com/pandas-dev/pandas/pull/4630...
# 26  https://github.com/pandas-dev/pandas/pull/4630...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                          patch_url.14 merged_at.14  \
# 0                                                 NaN          NaN
# 1   https://github.com/pandas-dev/pandas/pull/4635...          NaN
# 2   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 3   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 4   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 5   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 6   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 7   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 8   https://github.com/pandas-dev/pandas/pull/4634...          NaN
# 9                                                 NaN          NaN
# 10  https://github.com/pandas-dev/pandas/pull/4633...          NaN
# 11                                                NaN          NaN
# 12                                                NaN          NaN
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15  https://github.com/pandas-dev/pandas/pull/4633...          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18  https://github.com/pandas-dev/pandas/pull/4632...          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21  https://github.com/pandas-dev/pandas/pull/4631...          NaN
# 22                                                NaN          NaN
# 23  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 24                                                NaN          NaN
# 25  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 26  https://github.com/pandas-dev/pandas/pull/4630...          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
#
#                                       pull_request.12  \
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                       pull_request.13  \
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                       pull_request.14
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 1934 columns]

# %%
f.columns
# Out:
# Index(['url', 'url.1', 'url.2', 'url.3', 'url.4', 'url.5', 'url.6', 'url.7',
#        'url.8', 'url.9',
#        ...
#        'patch_url.13', 'merged_at.13', 'url.111', 'html_url.81', 'diff_url.14',
#        'patch_url.14', 'merged_at.14', 'pull_request.12', 'pull_request.13',
#        'pull_request.14'],
#       dtype='object', length=1934)

# %%
len(f.columns)
# Out:
# 1934

# %%
pd.DataFrame(data).columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'draft', 'pull_request'],
#       dtype='object')

# %%
pd.json_normalize(data['user']).head(2)
# Out:
#           login       id               node_id  \
# 0    fangchenli  7614606  MDQ6VXNlcjc2MTQ2MDY=
# 1  jbrockmendel  8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/761460...
# 1  https://avatars.githubusercontent.com/u/807896...
#
#                                          url                         html_url  \
# 0    https://api.github.com/users/fangchenli    https://github.com/fangchenli
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
#
#                                        followers_url  \
# 0  https://api.github.com/users/fangchenli/followers
# 1  https://api.github.com/users/jbrockmendel/foll...
#
#                                        following_url  \
# 0  https://api.github.com/users/fangchenli/follow...
# 1  https://api.github.com/users/jbrockmendel/foll...
#
#                                            gists_url  \
# 0  https://api.github.com/users/fangchenli/gists{...
# 1  https://api.github.com/users/jbrockmendel/gist...
#
#                                          starred_url  \
# 0  https://api.github.com/users/fangchenli/starre...
# 1  https://api.github.com/users/jbrockmendel/star...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/fangchenli/subscr...
# 1  https://api.github.com/users/jbrockmendel/subs...
#
#                                 organizations_url  \
# 0    https://api.github.com/users/fangchenli/orgs
# 1  https://api.github.com/users/jbrockmendel/orgs
#
#                                          repos_url  \
# 0    https://api.github.com/users/fangchenli/repos
# 1  https://api.github.com/users/jbrockmendel/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/fangchenli/events...
# 1  https://api.github.com/users/jbrockmendel/even...
#
#                                  received_events_url  type  site_admin
# 0  https://api.github.com/users/fangchenli/receiv...  User       False
# 1  https://api.github.com/users/jbrockmendel/rece...  User       False

# %%
pd.DataFrame(data['url']).head(2)
# Out:
#                                                  url
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...

# %%
a = pd.DataFrame(data['body'])

# %%
b = pd.json_normalize(data['user'])

# %%
type([a,b])
# Out:
# list

# %%
b.head(2)
# Out:
#           login       id               node_id  \
# 0    fangchenli  7614606  MDQ6VXNlcjc2MTQ2MDY=
# 1  jbrockmendel  8078968  MDQ6VXNlcjgwNzg5Njg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/761460...
# 1  https://avatars.githubusercontent.com/u/807896...
#
#                                          url                         html_url  \
# 0    https://api.github.com/users/fangchenli    https://github.com/fangchenli
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
#
#                                        followers_url  \
# 0  https://api.github.com/users/fangchenli/followers
# 1  https://api.github.com/users/jbrockmendel/foll...
#
#                                        following_url  \
# 0  https://api.github.com/users/fangchenli/follow...
# 1  https://api.github.com/users/jbrockmendel/foll...
#
#                                            gists_url  \
# 0  https://api.github.com/users/fangchenli/gists{...
# 1  https://api.github.com/users/jbrockmendel/gist...
#
#                                          starred_url  \
# 0  https://api.github.com/users/fangchenli/starre...
# 1  https://api.github.com/users/jbrockmendel/star...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/fangchenli/subscr...
# 1  https://api.github.com/users/jbrockmendel/subs...
#
#                                 organizations_url  \
# 0    https://api.github.com/users/fangchenli/orgs
# 1  https://api.github.com/users/jbrockmendel/orgs
#
#                                          repos_url  \
# 0    https://api.github.com/users/fangchenli/repos
# 1  https://api.github.com/users/jbrockmendel/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/fangchenli/events...
# 1  https://api.github.com/users/jbrockmendel/even...
#
#                                  received_events_url  type  site_admin
# 0  https://api.github.com/users/fangchenli/receiv...  User       False
# 1  https://api.github.com/users/jbrockmendel/rece...  User       False

# %%
pd.concat([a,b],axis=1)
# Out:
#                                                  body             login  \
# 0   Do we have any plan for PyCon US 2022?\r\n\r\n...        fangchenli
# 1   I had hoped  to go further and get rid of one ...      jbrockmendel
# 2   xref https://github.com/pandas-dev/pandas/pull...           jreback
# 3   ### Pandas version checks\n\n- [X] I have chec...     Diwakar-Gupta
# 4   - [x] closes #46306\r\n- [x] [Tests added and ...        lukemanley
# 5   ### Pandas version checks\r\n\r\n- [X] I have ...             vyasr
# 6   ### Pandas version checks\r\n\r\n- [X] I have ...         idanhazan
# 7   - [x] [Tests added and passed](https://pandas....        lukemanley
# 8   ### Pandas version checks\n\n- [X] I have chec...  brandon-b-miller
# 9   ### Pandas version checks\n\n- [X] I have chec...        panda-byte
# 10  Why do all my PRs not build anymore? Ref #4631...         jonashaag
# 11  ### Pandas version checks\n\n- [X] I have chec...            smarie
# 12  ### Pandas version checks\n\n- [X] I have chec...          ivirshup
# 13  The console-based copy-paste-a-token flow has ...            tswast
# 14  #### Is your feature request related to a prob...            janosh
# 15  - [x] closes #46187 (Replace xxxx with the Git...             phofl
# 16  ### Pandas version checks\r\n\r\n- [X] I have ...             zymon
# 17  DataFrame `merge` has inconsistent behaviour d...             jloxh
# 18  - [x] closes #46178 (Replace xxxx with the Git...             phofl
# 19  - [x] closes #46185 (Replace xxxx with the Git...             phofl
# 20  Tested the overloads with mypy and pyright:\r\...        twoertwein
# 21  ### Pandas version checks\n\n- [X] I have chec...            TouriM
# 22  ### Pandas version checks\n\n- [X] I have chec...         pjireland
# 23  ### Pandas version checks\r\n\r\n- [X] I have ...            agural
# 24  #### Is your feature request related to a prob...       MarkPundurs
# 25  ### Pandas version checks\r\n\r\n- [X] I have ...     chrisprobably
# 26  I have the following `df`:\r\n\r\n```\r\nimpor...          Hadi2525
# 27  ### Pandas version checks\n\n- [X] I have chec...         Freakwill
# 28  - [x] [Tests added and passed](https://pandas....        lukemanley
# 29  - [x] closes #46285 \r\n- [x] [Tests added and...       ELHoussineT
#
#           id               node_id  \
# 0    7614606  MDQ6VXNlcjc2MTQ2MDY=
# 1    8078968  MDQ6VXNlcjgwNzg5Njg=
# 2     953992  MDQ6VXNlcjk1Mzk5Mg==
# 3   39624018  MDQ6VXNlcjM5NjI0MDE4
# 4    8519523  MDQ6VXNlcjg1MTk1MjM=
# 5    1538165  MDQ6VXNlcjE1MzgxNjU=
# 6   19217750  MDQ6VXNlcjE5MjE3NzUw
# 7    8519523  MDQ6VXNlcjg1MTk1MjM=
# 8   53796099  MDQ6VXNlcjUzNzk2MDk5
# 9   41342515  MDQ6VXNlcjQxMzQyNTE1
# 10    175722  MDQ6VXNlcjE3NTcyMg==
# 11   3236794  MDQ6VXNlcjMyMzY3OTQ=
# 12   8238804  MDQ6VXNlcjgyMzg4MDQ=
# 13    247555  MDQ6VXNlcjI0NzU1NQ==
# 14  30958850  MDQ6VXNlcjMwOTU4ODUw
# 15  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 16   3421892  MDQ6VXNlcjM0MjE4OTI=
# 17  73829711  MDQ6VXNlcjczODI5NzEx
# 18  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 19  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 20   6618166  MDQ6VXNlcjY2MTgxNjY=
# 21    726951  MDQ6VXNlcjcyNjk1MQ==
# 22  16693035  MDQ6VXNlcjE2NjkzMDM1
# 23   1474669  MDQ6VXNlcjE0NzQ2Njk=
# 24   4326861  MDQ6VXNlcjQzMjY4NjE=
# 25   1543608  MDQ6VXNlcjE1NDM2MDg=
# 26  23264077  MDQ6VXNlcjIzMjY0MDc3
# 27  30965609  MDQ6VXNlcjMwOTY1NjA5
# 28   8519523  MDQ6VXNlcjg1MTk1MjM=
# 29  20634657  MDQ6VXNlcjIwNjM0NjU3
#
#                                            avatar_url gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/761460...
# 1   https://avatars.githubusercontent.com/u/807896...
# 2   https://avatars.githubusercontent.com/u/953992...
# 3   https://avatars.githubusercontent.com/u/396240...
# 4   https://avatars.githubusercontent.com/u/851952...
# 5   https://avatars.githubusercontent.com/u/153816...
# 6   https://avatars.githubusercontent.com/u/192177...
# 7   https://avatars.githubusercontent.com/u/851952...
# 8   https://avatars.githubusercontent.com/u/537960...
# 9   https://avatars.githubusercontent.com/u/413425...
# 10  https://avatars.githubusercontent.com/u/175722...
# 11  https://avatars.githubusercontent.com/u/323679...
# 12  https://avatars.githubusercontent.com/u/823880...
# 13  https://avatars.githubusercontent.com/u/247555...
# 14  https://avatars.githubusercontent.com/u/309588...
# 15  https://avatars.githubusercontent.com/u/619347...
# 16  https://avatars.githubusercontent.com/u/342189...
# 17  https://avatars.githubusercontent.com/u/738297...
# 18  https://avatars.githubusercontent.com/u/619347...
# 19  https://avatars.githubusercontent.com/u/619347...
# 20  https://avatars.githubusercontent.com/u/661816...
# 21  https://avatars.githubusercontent.com/u/726951...
# 22  https://avatars.githubusercontent.com/u/166930...
# 23  https://avatars.githubusercontent.com/u/147466...
# 24  https://avatars.githubusercontent.com/u/432686...
# 25  https://avatars.githubusercontent.com/u/154360...
# 26  https://avatars.githubusercontent.com/u/232640...
# 27  https://avatars.githubusercontent.com/u/309656...
# 28  https://avatars.githubusercontent.com/u/851952...
# 29  https://avatars.githubusercontent.com/u/206346...
#
#                                               url  \
# 0         https://api.github.com/users/fangchenli
# 1       https://api.github.com/users/jbrockmendel
# 2            https://api.github.com/users/jreback
# 3      https://api.github.com/users/Diwakar-Gupta
# 4         https://api.github.com/users/lukemanley
# 5              https://api.github.com/users/vyasr
# 6          https://api.github.com/users/idanhazan
# 7         https://api.github.com/users/lukemanley
# 8   https://api.github.com/users/brandon-b-miller
# 9         https://api.github.com/users/panda-byte
# 10         https://api.github.com/users/jonashaag
# 11            https://api.github.com/users/smarie
# 12          https://api.github.com/users/ivirshup
# 13            https://api.github.com/users/tswast
# 14            https://api.github.com/users/janosh
# 15             https://api.github.com/users/phofl
# 16             https://api.github.com/users/zymon
# 17             https://api.github.com/users/jloxh
# 18             https://api.github.com/users/phofl
# 19             https://api.github.com/users/phofl
# 20        https://api.github.com/users/twoertwein
# 21            https://api.github.com/users/TouriM
# 22         https://api.github.com/users/pjireland
# 23            https://api.github.com/users/agural
# 24       https://api.github.com/users/MarkPundurs
# 25     https://api.github.com/users/chrisprobably
# 26          https://api.github.com/users/Hadi2525
# 27         https://api.github.com/users/Freakwill
# 28        https://api.github.com/users/lukemanley
# 29       https://api.github.com/users/ELHoussineT
#
#                                html_url  \
# 0         https://github.com/fangchenli
# 1       https://github.com/jbrockmendel
# 2            https://github.com/jreback
# 3      https://github.com/Diwakar-Gupta
# 4         https://github.com/lukemanley
# 5              https://github.com/vyasr
# 6          https://github.com/idanhazan
# 7         https://github.com/lukemanley
# 8   https://github.com/brandon-b-miller
# 9         https://github.com/panda-byte
# 10         https://github.com/jonashaag
# 11            https://github.com/smarie
# 12          https://github.com/ivirshup
# 13            https://github.com/tswast
# 14            https://github.com/janosh
# 15             https://github.com/phofl
# 16             https://github.com/zymon
# 17             https://github.com/jloxh
# 18             https://github.com/phofl
# 19             https://github.com/phofl
# 20        https://github.com/twoertwein
# 21            https://github.com/TouriM
# 22         https://github.com/pjireland
# 23            https://github.com/agural
# 24       https://github.com/MarkPundurs
# 25     https://github.com/chrisprobably
# 26          https://github.com/Hadi2525
# 27         https://github.com/Freakwill
# 28        https://github.com/lukemanley
# 29       https://github.com/ELHoussineT
#
#                                         followers_url  \
# 0   https://api.github.com/users/fangchenli/followers
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2      https://api.github.com/users/jreback/followers
# 3   https://api.github.com/users/Diwakar-Gupta/fol...
# 4   https://api.github.com/users/lukemanley/followers
# 5        https://api.github.com/users/vyasr/followers
# 6    https://api.github.com/users/idanhazan/followers
# 7   https://api.github.com/users/lukemanley/followers
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/followers
# 10   https://api.github.com/users/jonashaag/followers
# 11      https://api.github.com/users/smarie/followers
# 12    https://api.github.com/users/ivirshup/followers
# 13      https://api.github.com/users/tswast/followers
# 14      https://api.github.com/users/janosh/followers
# 15       https://api.github.com/users/phofl/followers
# 16       https://api.github.com/users/zymon/followers
# 17       https://api.github.com/users/jloxh/followers
# 18       https://api.github.com/users/phofl/followers
# 19       https://api.github.com/users/phofl/followers
# 20  https://api.github.com/users/twoertwein/followers
# 21      https://api.github.com/users/TouriM/followers
# 22   https://api.github.com/users/pjireland/followers
# 23      https://api.github.com/users/agural/followers
# 24  https://api.github.com/users/MarkPundurs/follo...
# 25  https://api.github.com/users/chrisprobably/fol...
# 26    https://api.github.com/users/Hadi2525/followers
# 27   https://api.github.com/users/Freakwill/followers
# 28  https://api.github.com/users/lukemanley/followers
# 29  https://api.github.com/users/ELHoussineT/follo...
#
#                                         following_url  \
# 0   https://api.github.com/users/fangchenli/follow...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users/jreback/following...
# 3   https://api.github.com/users/Diwakar-Gupta/fol...
# 4   https://api.github.com/users/lukemanley/follow...
# 5   https://api.github.com/users/vyasr/following{/...
# 6   https://api.github.com/users/idanhazan/followi...
# 7   https://api.github.com/users/lukemanley/follow...
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/follow...
# 10  https://api.github.com/users/jonashaag/followi...
# 11  https://api.github.com/users/smarie/following{...
# 12  https://api.github.com/users/ivirshup/followin...
# 13  https://api.github.com/users/tswast/following{...
# 14  https://api.github.com/users/janosh/following{...
# 15  https://api.github.com/users/phofl/following{/...
# 16  https://api.github.com/users/zymon/following{/...
# 17  https://api.github.com/users/jloxh/following{/...
# 18  https://api.github.com/users/phofl/following{/...
# 19  https://api.github.com/users/phofl/following{/...
# 20  https://api.github.com/users/twoertwein/follow...
# 21  https://api.github.com/users/TouriM/following{...
# 22  https://api.github.com/users/pjireland/followi...
# 23  https://api.github.com/users/agural/following{...
# 24  https://api.github.com/users/MarkPundurs/follo...
# 25  https://api.github.com/users/chrisprobably/fol...
# 26  https://api.github.com/users/Hadi2525/followin...
# 27  https://api.github.com/users/Freakwill/followi...
# 28  https://api.github.com/users/lukemanley/follow...
# 29  https://api.github.com/users/ELHoussineT/follo...
#
#                                             gists_url  \
# 0   https://api.github.com/users/fangchenli/gists{...
# 1   https://api.github.com/users/jbrockmendel/gist...
# 2   https://api.github.com/users/jreback/gists{/gi...
# 3   https://api.github.com/users/Diwakar-Gupta/gis...
# 4   https://api.github.com/users/lukemanley/gists{...
# 5   https://api.github.com/users/vyasr/gists{/gist...
# 6   https://api.github.com/users/idanhazan/gists{/...
# 7   https://api.github.com/users/lukemanley/gists{...
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/gists{...
# 10  https://api.github.com/users/jonashaag/gists{/...
# 11  https://api.github.com/users/smarie/gists{/gis...
# 12  https://api.github.com/users/ivirshup/gists{/g...
# 13  https://api.github.com/users/tswast/gists{/gis...
# 14  https://api.github.com/users/janosh/gists{/gis...
# 15  https://api.github.com/users/phofl/gists{/gist...
# 16  https://api.github.com/users/zymon/gists{/gist...
# 17  https://api.github.com/users/jloxh/gists{/gist...
# 18  https://api.github.com/users/phofl/gists{/gist...
# 19  https://api.github.com/users/phofl/gists{/gist...
# 20  https://api.github.com/users/twoertwein/gists{...
# 21  https://api.github.com/users/TouriM/gists{/gis...
# 22  https://api.github.com/users/pjireland/gists{/...
# 23  https://api.github.com/users/agural/gists{/gis...
# 24  https://api.github.com/users/MarkPundurs/gists...
# 25  https://api.github.com/users/chrisprobably/gis...
# 26  https://api.github.com/users/Hadi2525/gists{/g...
# 27  https://api.github.com/users/Freakwill/gists{/...
# 28  https://api.github.com/users/lukemanley/gists{...
# 29  https://api.github.com/users/ELHoussineT/gists...
#
#                                           starred_url  \
# 0   https://api.github.com/users/fangchenli/starre...
# 1   https://api.github.com/users/jbrockmendel/star...
# 2   https://api.github.com/users/jreback/starred{/...
# 3   https://api.github.com/users/Diwakar-Gupta/sta...
# 4   https://api.github.com/users/lukemanley/starre...
# 5   https://api.github.com/users/vyasr/starred{/ow...
# 6   https://api.github.com/users/idanhazan/starred...
# 7   https://api.github.com/users/lukemanley/starre...
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/starre...
# 10  https://api.github.com/users/jonashaag/starred...
# 11  https://api.github.com/users/smarie/starred{/o...
# 12  https://api.github.com/users/ivirshup/starred{...
# 13  https://api.github.com/users/tswast/starred{/o...
# 14  https://api.github.com/users/janosh/starred{/o...
# 15  https://api.github.com/users/phofl/starred{/ow...
# 16  https://api.github.com/users/zymon/starred{/ow...
# 17  https://api.github.com/users/jloxh/starred{/ow...
# 18  https://api.github.com/users/phofl/starred{/ow...
# 19  https://api.github.com/users/phofl/starred{/ow...
# 20  https://api.github.com/users/twoertwein/starre...
# 21  https://api.github.com/users/TouriM/starred{/o...
# 22  https://api.github.com/users/pjireland/starred...
# 23  https://api.github.com/users/agural/starred{/o...
# 24  https://api.github.com/users/MarkPundurs/starr...
# 25  https://api.github.com/users/chrisprobably/sta...
# 26  https://api.github.com/users/Hadi2525/starred{...
# 27  https://api.github.com/users/Freakwill/starred...
# 28  https://api.github.com/users/lukemanley/starre...
# 29  https://api.github.com/users/ELHoussineT/starr...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/fangchenli/subscr...
# 1   https://api.github.com/users/jbrockmendel/subs...
# 2   https://api.github.com/users/jreback/subscript...
# 3   https://api.github.com/users/Diwakar-Gupta/sub...
# 4   https://api.github.com/users/lukemanley/subscr...
# 5    https://api.github.com/users/vyasr/subscriptions
# 6   https://api.github.com/users/idanhazan/subscri...
# 7   https://api.github.com/users/lukemanley/subscr...
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/subscr...
# 10  https://api.github.com/users/jonashaag/subscri...
# 11  https://api.github.com/users/smarie/subscriptions
# 12  https://api.github.com/users/ivirshup/subscrip...
# 13  https://api.github.com/users/tswast/subscriptions
# 14  https://api.github.com/users/janosh/subscriptions
# 15   https://api.github.com/users/phofl/subscriptions
# 16   https://api.github.com/users/zymon/subscriptions
# 17   https://api.github.com/users/jloxh/subscriptions
# 18   https://api.github.com/users/phofl/subscriptions
# 19   https://api.github.com/users/phofl/subscriptions
# 20  https://api.github.com/users/twoertwein/subscr...
# 21  https://api.github.com/users/TouriM/subscriptions
# 22  https://api.github.com/users/pjireland/subscri...
# 23  https://api.github.com/users/agural/subscriptions
# 24  https://api.github.com/users/MarkPundurs/subsc...
# 25  https://api.github.com/users/chrisprobably/sub...
# 26  https://api.github.com/users/Hadi2525/subscrip...
# 27  https://api.github.com/users/Freakwill/subscri...
# 28  https://api.github.com/users/lukemanley/subscr...
# 29  https://api.github.com/users/ELHoussineT/subsc...
#
#                                     organizations_url  \
# 0        https://api.github.com/users/fangchenli/orgs
# 1      https://api.github.com/users/jbrockmendel/orgs
# 2           https://api.github.com/users/jreback/orgs
# 3     https://api.github.com/users/Diwakar-Gupta/orgs
# 4        https://api.github.com/users/lukemanley/orgs
# 5             https://api.github.com/users/vyasr/orgs
# 6         https://api.github.com/users/idanhazan/orgs
# 7        https://api.github.com/users/lukemanley/orgs
# 8   https://api.github.com/users/brandon-b-miller/...
# 9        https://api.github.com/users/panda-byte/orgs
# 10        https://api.github.com/users/jonashaag/orgs
# 11           https://api.github.com/users/smarie/orgs
# 12         https://api.github.com/users/ivirshup/orgs
# 13           https://api.github.com/users/tswast/orgs
# 14           https://api.github.com/users/janosh/orgs
# 15            https://api.github.com/users/phofl/orgs
# 16            https://api.github.com/users/zymon/orgs
# 17            https://api.github.com/users/jloxh/orgs
# 18            https://api.github.com/users/phofl/orgs
# 19            https://api.github.com/users/phofl/orgs
# 20       https://api.github.com/users/twoertwein/orgs
# 21           https://api.github.com/users/TouriM/orgs
# 22        https://api.github.com/users/pjireland/orgs
# 23           https://api.github.com/users/agural/orgs
# 24      https://api.github.com/users/MarkPundurs/orgs
# 25    https://api.github.com/users/chrisprobably/orgs
# 26         https://api.github.com/users/Hadi2525/orgs
# 27        https://api.github.com/users/Freakwill/orgs
# 28       https://api.github.com/users/lukemanley/orgs
# 29      https://api.github.com/users/ELHoussineT/orgs
#
#                                             repos_url  \
# 0       https://api.github.com/users/fangchenli/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2          https://api.github.com/users/jreback/repos
# 3    https://api.github.com/users/Diwakar-Gupta/repos
# 4       https://api.github.com/users/lukemanley/repos
# 5            https://api.github.com/users/vyasr/repos
# 6        https://api.github.com/users/idanhazan/repos
# 7       https://api.github.com/users/lukemanley/repos
# 8   https://api.github.com/users/brandon-b-miller/...
# 9       https://api.github.com/users/panda-byte/repos
# 10       https://api.github.com/users/jonashaag/repos
# 11          https://api.github.com/users/smarie/repos
# 12        https://api.github.com/users/ivirshup/repos
# 13          https://api.github.com/users/tswast/repos
# 14          https://api.github.com/users/janosh/repos
# 15           https://api.github.com/users/phofl/repos
# 16           https://api.github.com/users/zymon/repos
# 17           https://api.github.com/users/jloxh/repos
# 18           https://api.github.com/users/phofl/repos
# 19           https://api.github.com/users/phofl/repos
# 20      https://api.github.com/users/twoertwein/repos
# 21          https://api.github.com/users/TouriM/repos
# 22       https://api.github.com/users/pjireland/repos
# 23          https://api.github.com/users/agural/repos
# 24     https://api.github.com/users/MarkPundurs/repos
# 25   https://api.github.com/users/chrisprobably/repos
# 26        https://api.github.com/users/Hadi2525/repos
# 27       https://api.github.com/users/Freakwill/repos
# 28      https://api.github.com/users/lukemanley/repos
# 29     https://api.github.com/users/ELHoussineT/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/fangchenli/events...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/jreback/events{/p...
# 3   https://api.github.com/users/Diwakar-Gupta/eve...
# 4   https://api.github.com/users/lukemanley/events...
# 5   https://api.github.com/users/vyasr/events{/pri...
# 6   https://api.github.com/users/idanhazan/events{...
# 7   https://api.github.com/users/lukemanley/events...
# 8   https://api.github.com/users/brandon-b-miller/...
# 9   https://api.github.com/users/panda-byte/events...
# 10  https://api.github.com/users/jonashaag/events{...
# 11  https://api.github.com/users/smarie/events{/pr...
# 12  https://api.github.com/users/ivirshup/events{/...
# 13  https://api.github.com/users/tswast/events{/pr...
# 14  https://api.github.com/users/janosh/events{/pr...
# 15  https://api.github.com/users/phofl/events{/pri...
# 16  https://api.github.com/users/zymon/events{/pri...
# 17  https://api.github.com/users/jloxh/events{/pri...
# 18  https://api.github.com/users/phofl/events{/pri...
# 19  https://api.github.com/users/phofl/events{/pri...
# 20  https://api.github.com/users/twoertwein/events...
# 21  https://api.github.com/users/TouriM/events{/pr...
# 22  https://api.github.com/users/pjireland/events{...
# 23  https://api.github.com/users/agural/events{/pr...
# 24  https://api.github.com/users/MarkPundurs/event...
# 25  https://api.github.com/users/chrisprobably/eve...
# 26  https://api.github.com/users/Hadi2525/events{/...
# 27  https://api.github.com/users/Freakwill/events{...
# 28  https://api.github.com/users/lukemanley/events...
# 29  https://api.github.com/users/ELHoussineT/event...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/fangchenli/receiv...  User       False
# 1   https://api.github.com/users/jbrockmendel/rece...  User       False
# 2   https://api.github.com/users/jreback/received_...  User       False
# 3   https://api.github.com/users/Diwakar-Gupta/rec...  User       False
# 4   https://api.github.com/users/lukemanley/receiv...  User       False
# 5   https://api.github.com/users/vyasr/received_ev...  User       False
# 6   https://api.github.com/users/idanhazan/receive...  User       False
# 7   https://api.github.com/users/lukemanley/receiv...  User       False
# 8   https://api.github.com/users/brandon-b-miller/...  User       False
# 9   https://api.github.com/users/panda-byte/receiv...  User       False
# 10  https://api.github.com/users/jonashaag/receive...  User       False
# 11  https://api.github.com/users/smarie/received_e...  User       False
# 12  https://api.github.com/users/ivirshup/received...  User       False
# 13  https://api.github.com/users/tswast/received_e...  User       False
# 14  https://api.github.com/users/janosh/received_e...  User       False
# 15  https://api.github.com/users/phofl/received_ev...  User       False
# 16  https://api.github.com/users/zymon/received_ev...  User       False
# 17  https://api.github.com/users/jloxh/received_ev...  User       False
# 18  https://api.github.com/users/phofl/received_ev...  User       False
# 19  https://api.github.com/users/phofl/received_ev...  User       False
# 20  https://api.github.com/users/twoertwein/receiv...  User       False
# 21  https://api.github.com/users/TouriM/received_e...  User       False
# 22  https://api.github.com/users/pjireland/receive...  User       False
# 23  https://api.github.com/users/agural/received_e...  User       False
# 24  https://api.github.com/users/MarkPundurs/recei...  User       False
# 25  https://api.github.com/users/chrisprobably/rec...  User       False
# 26  https://api.github.com/users/Hadi2525/received...  User       False
# 27  https://api.github.com/users/Freakwill/receive...  User       False
# 28  https://api.github.com/users/lukemanley/receiv...  User       False
# 29  https://api.github.com/users/ELHoussineT/recei...  User       False

# %% [raw]
# 1 . Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# 1. Find out how many male and female passenger was onboarded .

total_number_of_female = len(data[data['Sex'] == 'female'])
print("total_number_of_female passenger was onboard = ",total_number_of_female)
total_number_of_male = len(data[data['Sex'] == 'male'])
print("total_number_of_male passenger was onboard = ",total_number_of_male)
# Out:
# total_number_of_female passenger was onboard =  314
# total_number_of_male passenger was onboard =  577

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
data.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
# 2. how many survived we have .
total_number_of_survived = len(data[data['Survived'] == 1])
print("total_number_of_survived = ",total_number_of_survived)
# Out:
# total_number_of_survived =  342

# %%
# 3. how many casuality we have
total_number_of_casuality = len(data[data['Survived'] == 0])
print("total_number_of_casuality = ",total_number_of_casuality)
# Out:
# total_number_of_casuality =  549

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
# 4. what is name of a person who is the eldest one .
data[data["Age"] == max(data["Age"])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
data[data["Age"] == data["Age"].max()]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
# 5. how many passenger do we have in first , second and third class 
total_number_of_passenger_in_first_class = len(data[data["Pclass"] == 1])
print("total_number_of_passenger_in_first_class = ",total_number_of_passenger_in_first_class)

total_number_of_passenger_in_second_class = len(data[data["Pclass"] == 2])
print("total_number_of_passenger_in_second_class = ",total_number_of_passenger_in_second_class)

total_number_of_passenger_in_third_class = len(data[data["Pclass"] == 3])
print("total_number_of_passenger_in_third_class = ",total_number_of_passenger_in_third_class)
# Out:
# total_number_of_passenger_in_first_class =  216
# total_number_of_passenger_in_second_class =  184
# total_number_of_passenger_in_third_class =  491

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
# 6. how many person we have whose name starts with "s"
def get_count(data):
    count = 0
    for name in data["Name"]:
        if name[0] == "S" or name[0] == "s" :
            count +=1  
    return count       

get_count(data)
# Out:
# 86

# %%
len(data[data['Name'].str.startswith("S")])
# Out:
# 86

# %%
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
data["summation_of_SibSp_and_parch"] = data['SibSp'] + data['Parch']
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
#
#      summation_of_SibSp_and_parch
# 886                             0
# 887                             0
# 888                             3
# 889                             0
# 890                             0

# %%
# 8 . how many person do we have below age of 25 .
total_number_person_below_25 = len(data[data['Age'] < 25])
print("total_number_person_below_25 = ",total_number_person_below_25)
# Out:
# total_number_person_below_25 =  278

# %%
# 9 . how many person died whose age was less then 40 
total_number_person_died_whose_age_is_below_40 = len(data[(data["Survived"] == 0) & (data["Age"]< 40)])
print("total_number_person_died_whose_age_is_below_40 = ", total_number_person_died_whose_age_is_below_40)
# Out:
# total_number_person_died_whose_age_is_below_40 =  322

# %%
# 10 . from a  cabin column seperate text and numeric value . 

import re

replace = re.compile("([a-zA-Z]+)")
data["string_from_cabin_list"] = data['Cabin'].str.extract(replace)
data["number_from_cabin_list"] = data['Cabin'].str.replace(replace, "")

# %%
data["string_from_cabin_list"]
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_from_cabin_list, Length: 891, dtype: object

# %%
data["number_from_cabin_list"]
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: number_from_cabin_list, Length: 891, dtype: object

# %%
data = pd.read_csv('bank.csv',sep=";")

# %% [raw]
# 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .

# %%
# 1 . how many campaign available in this dataset . 
total_number_of_campaign = len(set(data['campaign']))
print("total_number_of_campaign = ",total_number_of_campaign)
# Out:
# total_number_of_campaign =  32

# %%
len(data['campaign'].unique())
# Out:
# 32

# %%
# 2 . how many users do we have with housing and personal loan . 
total_number_of_people_with_housing_and_personal_loan = len(data[(data['housing'] == "yes") & (data['loan'] == "yes")])
print("total_number_of_people_with_housing_and_personal_loan = ", total_number_of_people_with_housing_and_personal_loan)
# Out:
# total_number_of_people_with_housing_and_personal_loan =  406

# %%
# 3. how many person do we have whose age is 60+ . 
total_number_of_person_age_60_plus = len(data[data["age"]>60])
print("total_number_of_person_age_60_plus = ",total_number_of_person_age_60_plus)
# Out:
# total_number_of_person_age_60_plus =  127

# %%
# 4 . in which month we have trageted most of the customer . 
def get_month_count(data):
    month_count = {}
    for m in data['month']:
        if m in month_count:
            month_count[m] = month_count[m] + 1
        else:
            month_count[m] = 1
    print(month_count)
    
    frequency = 0
    month = ""
    for mo,count in month_count.items():
        if count>frequency:
            frequency = count
            month = mo
    return month        

get_month_count(data)
# Out:
# {'oct': 80, 'may': 1398, 'apr': 293, 'jun': 531, 'feb': 222, 'aug': 633, 'jan': 148, 'jul': 706, 'nov': 389, 'sep': 52, 'mar': 49, 'dec': 20}
# 'may'

# %%
data["month"].value_counts().max()
# Out:
# 1398

# %%
data["month"].value_counts().index[0]
# Out:
# 'may'

# %%
# 5 . which mode of call is giving you more result
def get_contact_success_mode(data):
    count = {}
    contact_modes = list(set(data['contact']))
    for mode in contact_modes:
        a = len(data[(data['contact']==mode) & (data['poutcome']=="success")])
        if mode not in count:
            count[mode] = a
    print(count) 
    frequency = 0
    contact_type = ""
    for mode,count in count.items():
        if count>frequency:
            frequency = count
            contact_type = mode
    return contact_type, frequency        
        
get_contact_success_mode(data)
# Out:
# {'telephone': 13, 'cellular': 114, 'unknown': 2}
# ('cellular', 114)

# %%
df_groupby = data.groupby(['contact', "y"]).count()

# %%
df_groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
#           yes    61    61     61        61        61     61        61
#
#                poutcome
# contact   y
# cellular  no       2480
#           yes       416
# telephone no        257
#           yes        44
# unknown   no       1263
#           yes        61

# %%
d = [df_groupby.loc['cellular','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0]]
max(d)
# Out:
# 416

# %%
# 6 . how many enterpeures do we have in this list 
total_number_of_entrepreneur = len(data[data['job'] == "entrepreneur"])
print("total_number_of_entrepreneur = ", total_number_of_entrepreneur)
# Out:
# total_number_of_entrepreneur =  168

# %%
# 7 . how many customers do we have with negative balance 
total_number_of_person_with_negative_balance = len(data[data['balance'] <0 ])
print("total_number_of_person_with_negative_balance = ", total_number_of_person_with_negative_balance)
# Out:
# total_number_of_person_with_negative_balance =  366

# %%
# 8. prepare a group of data based on education level .
data.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
level_of_education = list(data['education'].unique())
level_of_education
# Out:
# ['primary', 'secondary', 'tertiary', 'unknown']

# %%
l = []
for level in level_of_education:
    level = pd.DataFrame(data[data['education'] == level])
    l.append(level)

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4480   cellular   16   apr       743         1     -1         0  unknown   no
# 4485   cellular   11   may       238         2    361         5  failure   no
# 4486    unknown    9   may       514         1     -1         0  unknown   no
# 4499   cellular   21   nov       362         1     -1         0  unknown   no
# 4503   cellular   29   jul       816         6     -1         0  unknown  yes
#
# [678 rows x 17 columns]

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1     cellular   11   may       220         1    339         4  failure  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 10     unknown   20   may       273         1     -1         0  unknown  no
# 11    cellular   17   apr       113         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4514  cellular   20   apr        45         4    153         1  failure  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
#
# [2306 rows x 17 columns]

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 5     cellular   23   feb       141         2    176         3  failure  no
# 6     cellular   14   may       341         1    330         2    other  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4501  cellular   26   aug        63         4     -1         0  unknown  no
# 4506  cellular   29   aug        85         4     -1         0  unknown  no
# 4509  cellular   30   nov       210         3     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [1350 rows x 17 columns]

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 20     cellular   18   nov        96         2     -1         0  unknown   no
# 27    telephone   17   aug       119         1    105         2  failure   no
# 49     cellular   27   jan       181         1     92         1  success  yes
# 132     unknown   30   may        67         3     -1         0  unknown   no
# 133    cellular    8   may        85         1    168         2  failure   no
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4337  telephone   16   oct       434         1     57         1  failure  yes
# 4342  telephone   31   jul      1088        17     -1         0  unknown  yes
# 4428   cellular    2   feb       212         1    249         2    other   no
# 4471   cellular   21   nov       216         4     -1         0  unknown   no
# 4508    unknown   16   may       509         2     -1         0  unknown   no
#
# [187 rows x 17 columns]
