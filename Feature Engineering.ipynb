# %% [markdown]
# we will be performing the below steps
#
# 1. Handling Missing values
# 2. Temporal Varibles
# 3. Handle Categorical Variables: remove rare labels
# 4. Standardize the values of the variable to the ame range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset.shape
# Out:
# (1460, 81)

# %%
X = dataset.iloc[:,1:80]
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1041          60       RL          NaN     9130   Pave   NaN      Reg
# 645           20       RL          NaN    10530   Pave   NaN      IR1
# 641           60       FV          NaN     7050   Pave   NaN      Reg
# 599          160       RM         24.0     1950   Pave   NaN      Reg
# 118           60       RL         90.0    12376   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 880           20       RL         60.0     7024   Pave   NaN      Reg
# 597          120       RL         53.0     3922   Pave   NaN      Reg
# 1377          50       RL         60.0    10998   Pave  Grvl      Reg
# 1073          60       RL         75.0     7950   Pave   NaN      IR1
# 1241          20       RL         83.0     9849   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
#Missing Values
feature_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]
for feature in feature_nan:
    print("the feature is {} and missing values in {}%".format(feature,np.round(dataset[feature].isnull().mean()*100,4)))
# Out:
# the feature is LotFrontage and missing values in 17.7397%
# the feature is Alley and missing values in 93.7671%
# the feature is MasVnrType and missing values in 0.5479%
# the feature is MasVnrArea and missing values in 0.5479%
# the feature is BsmtQual and missing values in 2.5342%
# the feature is BsmtCond and missing values in 2.5342%
# the feature is BsmtExposure and missing values in 2.6027%
# the feature is BsmtFinType1 and missing values in 2.5342%
# the feature is BsmtFinType2 and missing values in 2.6027%
# the feature is Electrical and missing values in 0.0685%
# the feature is FireplaceQu and missing values in 47.2603%
# the feature is GarageType and missing values in 5.5479%
# the feature is GarageYrBlt and missing values in 5.5479%
# the feature is GarageFinish and missing values in 5.5479%
# the feature is GarageQual and missing values in 5.5479%
# the feature is GarageCond and missing values in 5.5479%
# the feature is PoolQC and missing values in 99.5205%
# ...

# %%
# Replacing categorical features
categorical_features = [feature for feature in dataset.columns if dataset[feature].dtypes=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
data = dataset.copy()
def replace_cat_feature(datset,categorical_features):
    data[categorical_features] = data[categorical_features].fillna('Missing')
    return data
replace_cat_feature(data, categorical_features)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  Missing
# 1        2          20       RL         80.0     9600   Pave  Missing
# 2        3          60       RL         68.0    11250   Pave  Missing
# 3        4          70       RL         60.0     9550   Pave  Missing
# 4        5          60       RL         84.0    14260   Pave  Missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Missing
# 1456  1457          20       RL         85.0    13175   Pave  Missing
# 1457  1458          70       RL         66.0     9042   Pave  Missing
# 1458  1459          20       RL         68.0     9717   Pave  Missing
# 1459  1460          20       RL         75.0     9937   Pave  Missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
data = dataset.copy()
def replace_cat_feature_with_mode(datset,categorical_features):
    data[categorical_features] = data[categorical_features].fillna(data[categorical_features].mode())
    return data
replace_cat_feature_with_mode(data, categorical_features)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
numerical_features_nan = [feature for feature in dataset.columns if dataset[feature].dtypes!='O' and dataset[feature].isnull().sum()>=1]
numerical_features_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for feature in numerical_features_nan:
    # since there are outlier we are going to replace with median
    median_values = dataset[feature].median()
    # crate a new feature to capture nan value
    dataset[feature+'_nan'] = np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_values,inplace=True)

# %%
dataset['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
# Temporal variables (date time variables)
for feature in ['YearBuilt' ,'YearRemodAdd','GarageYrBlt']:
    dataset[feature+'_age_of_house'] = dataset['YrSold']-dataset[feature]

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL         69.0    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...
