# %% [markdown]
# we will be performing the below steps
#
# 1. Handling Missing values
# 2. Temporal Varibles
# 3. Handle Categorical Variables: remove rare labels
# 4. Standardize the values of the variable to the ame range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
X = dataset.iloc[:,1:81]
y = dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1103          20       RL         79.0     8910   Pave   NaN      Reg
# 974           70       RL         60.0    11414   Pave   NaN      IR1
# 435           60       RL         43.0    10667   Pave   NaN      IR2
# 193          160       RM         24.0     2522   Pave   NaN      Reg
# 1409          60       RL         46.0    20544   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 889           20       RL        128.0    12160   Pave   NaN      Reg
# 314           70       RM         60.0     9600   Pave  Grvl      Reg
# 1417          60       RL          NaN    16545   Pave   NaN      IR1
# 946           80       RL         70.0     8163   Pave   NaN      Reg
# 204           50       RM         50.0     3500   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1103         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 974          Lvl    AllPub    Corner       Gtl      BrkSide       RRAn
# 435          Lvl    AllPub   CulDSac       Gtl      CollgCr       PosN
# 193          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1409         Lvl    AllPub   CulDSac       Gtl       NWAmes       Norm
# ...          ...       ...       ...       ...          ...        ...
# 889          Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 314          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1417         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 946          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 204          Lvl    AllPub    Inside       Gtl      OldTown       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1103       Norm     1Fam     1Story            6            6       1959
# 974       Feedr     1Fam     2Story            7            8       1910
# 435        Norm     1Fam     2Story            7            6       1996
# 193        Norm    Twnhs     2Story            7            5       2004
# 1409       Norm     1Fam     2Story            7            6       1986
# ...         ...      ...        ...          ...          ...        ...
# 889        Norm     1Fam     1Story            6            4       1953
# 314        Norm     1Fam     2Story            7            7       1925
# 1417       Norm     1Fam     2Story            8            5       1998
# 946        Norm     1Fam       SLvl            5            6       1959
# 204        Norm     1Fam     1.5Fin            5            7       1947
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1103          1959       Hip  CompShg     BrkFace     BrkFace       None
# 974           1993     Gable  CompShg     HdBoard     HdBoard       None
# 435           1996     Gable  CompShg     VinylSd     VinylSd       None
# 193           2004     Gable  CompShg     VinylSd     VinylSd      Stone
# 1409          1991     Gable  CompShg     Plywood     Plywood    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 889           1953       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 314           1990     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1417          1998     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 946           1959     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 204           1950     Gable  CompShg     AsbShng     AsbShng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1103         0.0        TA        TA     CBlock       TA       TA
# 974          0.0        TA        Gd     BrkTil       Gd       TA
# 435          0.0        Gd        TA      PConc       Gd       TA
# 193         50.0        Gd        TA      PConc       Gd       TA
# 1409       123.0        TA        Gd     CBlock       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 889         90.0        TA        TA     CBlock       TA       TA
# 314          0.0        TA        TA     BrkTil       TA       Gd
# 1417       731.0        Gd        TA      PConc       Gd       TA
# 946        128.0        TA        Gd     CBlock       TA       TA
# 204          0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1103           Mn          ALQ         655          Unf           0
# 974            No          Unf           0          Unf           0
# 435            Av          GLQ         385          ALQ         344
# 193            No          Unf           0          Unf           0
# 1409           No          Unf           0          Unf           0
# ...           ...          ...         ...          ...         ...
# 889            No          BLQ        1024          Unf           0
# 314            No          LwQ          16          Unf           0
# 1417           Mn          GLQ         781          Unf           0
# 946            Av          ALQ         748          BLQ         294
# 204            No          LwQ         312          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1103          0          655    GasA        Ex          Y      SBrkr
# 974         728          728    GasA        TA          N      SBrkr
# 435          70          799    GasA        Ex          Y      SBrkr
# 193         970          970    GasA        Ex          Y      SBrkr
# 1409        791          791    GasA        Gd          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 889         481         1505    GasA        Ex          Y      SBrkr
# 314         712          728    GasA        Ex          Y      SBrkr
# 1417        503         1284    GasA        Ex          Y      SBrkr
# 946         102         1144    GasA        TA          Y      SBrkr
# 204         408          720    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1103      1194         0             0       1194             0             1
# 974       1136       883             0       2019             0             0
# 435        827       834             0       1661             1             0
# 193        970       739             0       1709             0             0
# 1409      1236       857             0       2093             0             0
# ...        ...       ...           ...        ...           ...           ...
# 889       1505         0             0       1505             1             0
# 314        832       809             0       1641             0             1
# 1417      1310      1140             0       2450             1             0
# 946       1144         0             0       1144             1             0
# 204        720       564             0       1284             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1103         1         0             3             1          TA
# 974          1         0             3             1          Gd
# 435          2         1             3             1          Gd
# 193          2         0             3             1          Gd
# 1409         2         1             3             1          TA
# ...        ...       ...           ...           ...         ...
# 889          1         0             2             1          TA
# 314          1         1             3             1          Ex
# 1417         2         1             3             1          Gd
# 946          1         0             3             1          TA
# 204          1         1             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1103             6        Typ           1          Fa    BuiltIn       1954.0
# 974              8        Typ           0         NaN     Detchd       1997.0
# 435              6        Typ           1          TA     Attchd       1996.0
# 193              7       Maj1           0         NaN     Detchd       2004.0
# 1409             7        Typ           1          TA     Attchd       1986.0
# ...            ...        ...         ...         ...        ...          ...
# 889              6        Typ           1          TA     Attchd       1953.0
# 314              6        Typ           1          Gd     Detchd       1925.0
# 1417             7        Typ           1          TA     Attchd       1998.0
# 946              6        Typ           1          TA     Attchd       1959.0
# 204              5        Typ           0         NaN     Detchd       1948.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1103          Fin           2         539         TA         TA          Y
# 974           Unf           2         532         TA         TA          Y
# 435           RFn           2         550         TA         TA          Y
# 193           Unf           2         380         TA         TA          Y
# 1409          Fin           2         542         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 889           RFn           2         505         TA         TA          Y
# 314           Unf           2         546         Fa         TA          Y
# 1417          Fin           3        1069         TA         TA          Y
# 946           RFn           1         796         TA         TA          Y
# 204           Unf           1         240         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1103           0            0            192          0            0
# 974          509          135              0          0            0
# 435          158           61              0          0            0
# 193            0           40              0          0            0
# 1409         364           63              0          0            0
# ...          ...          ...            ...        ...          ...
# 889            0            0              0        162            0
# 314            0            0            234          0            0
# 1417           0          126              0          0            0
# 946           86            0              0          0            0
# 204            0           35              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1103         0    NaN    NaN         NaN        0       7    2006       WD
# 974          0    NaN  GdPrv         NaN        0      10    2009       WD
# 435          0    NaN    NaN         NaN        0       4    2009    ConLw
# 193          0    NaN    NaN         NaN        0       5    2006       WD
# 1409         0    NaN  MnPrv         NaN        0      11    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 889          0    NaN    NaN         NaN        0       2    2009       WD
# 314          0    NaN    NaN         NaN        0       8    2006       WD
# 1417         0    NaN    NaN         NaN        0       5    2009       WD
# 946          0    NaN    NaN         NaN        0       3    2006       WD
# 204          0    NaN   MnWw         NaN        0       4    2009       WD
#
#      SaleCondition  SalePrice
# 1103        Normal     159500
# 974         Normal     167500
# 435         Normal     212000
# 193         Normal     130000
# 1409        Normal     215000
# ...            ...        ...
# 889         Normal     149500
# 314         Normal     178000
# 1417        Normal     340000
# 946         Normal     143000
# 204         Normal     110000
#
# [1314 rows x 80 columns]

# %%
#Missing Values
feature_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]
for feature in feature_nan:
    print("the feature is {} and missing values in {}%").format(feature,np.round(dataset[feature].isnull().mean()*100,4))
    print(feature, np.round(dataset[feature].isnull().mean()*100,4),'% missing values')
# Out:
# the feature is {} and missing values in {}%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13756/2130973416.py in <module>
#       2 feature_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]
#       3 for feature in feature_nan:
# ----> 4     print("the feature is {} and missing values in {}%").format(feature,np.round(dataset[feature].isnull().mean()*100,4))
#       5     print(feature, np.round(dataset[feature].isnull().mean()*100,4),'% missing values')
#
# AttributeError: 'NoneType' object has no attribute 'format'

# %%
data = dataset.copy()
def replace_cat_features(dataset,categorical_features):
    data[categorical_features] = data[categorical_features].fillna("Missing")
    return data
