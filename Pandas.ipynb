# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BEC0-260A
#
#  Directory of C:\Users\fazlu\Working_space\class\python-Labraries
#
# 13-03-2022  18:06    <DIR>          .
# 13-03-2022  18:06    <DIR>          ..
# 27-02-2022  12:54             1,926 .gitignore
# 13-03-2022  15:38    <DIR>          .ipynb_checkpoints
# 26-02-2022  13:56            23,015 0DA8B230
# 26-02-2022  13:56            23,008 8D49B230
# 12-02-2022  07:29             1,173 addresses.csv
# 13-03-2022  08:01         3,398,351 allrecord.csv
# 14-02-2012  14:38           461,474 bank.csv
# 14-02-2012  14:40         4,610,348 bank-full.csv
# 14-02-2012  15:10             3,864 bank-names.txt
# 12-02-2022  07:29             1,589 contacts.csv
# 13-03-2022  18:07             5,658 cricket.csv
# 26-02-2022  12:35               177 data.csv
# 12-02-2022  07:29               277 holiday_schedules.csv
# 27-02-2022  12:15            34,355 jsonResponse.csv
# 12-02-2022  07:29            18,015 locations.csv
# 12-02-2022  07:29             1,610 mail_addresses.csv
# 26-02-2022  13:57            23,021 MyPersonalData.xlsx
# 13-03-2022  18:07            81,551 NBA.csv
# 13-03-2022  18:07            78,960 NBA2.csv
# 13-03-2022  15:43            75,942 Numpy.ipynb
# 12-02-2022  07:29             2,281 organizations.csv
# 13-03-2022  18:06           339,044 Pandas Tasks.ipynb
# 13-03-2022  08:59         1,041,732 Pandas.ipynb
# 12-02-2022  07:29             2,092 phones.csv
# 12-02-2022  07:29                60 programs.csv
# 27-02-2022  12:38                30 README.md
# 12-02-2022  07:29               350 regular_schedules.csv
# 12-02-2022  07:29            19,128 services.csv
# 12-02-2022  07:29            14,618 taxonomy.csv
#               28 File(s)     10,263,649 bytes
#                3 Dir(s)  379,670,089,728 bytes free

# %%
pd.read_csv('addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 0          Redwood City             CA       94063      US
# 1             San Mateo             CA       94401      US
# 2             San Mateo             CA       94403      US
# 3             San Mateo             CA       94401      US
# 4             San Mateo             CA       94401      US
# 5            Menlo Park             CA  94025-9881      US
# 6            Menlo Park             CA       94025      US
# 7            Menlo Park             CA  94025-9881      US
# 8          Redwood City             CA       94063      US
# 9          Redwood City             CA       94063      US
# 10         Redwood City             CA       94061      US
# 11         Redwood City             CA       94063      US
# 12         Redwood City             CA       94065      US
# 13         Redwood City             CA       94063      US
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
pd.read_csv('services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# 16  17           17         NaN                       NaN
# 17  18           18         NaN                       NaN
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                                application_process  \
# 0                     NaN                         Walk in or apply by phone.
# 1                     NaN                 Apply by phone for an appointment.
# 2                     NaN        Phone for information (403-4300 Ext. 4322).
# 3                     NaN                                    Apply by phone.
# 4                     NaN                             Phone for information.
# 5                     NaN  Walk in or apply by phone for membership appli...
# 6                     NaN  Apply by phone or be referred by a doctor, soc...
# 7                     NaN                                    Apply by phone.
# 8                     NaN  Walk in. Proof of residency in California requ...
# 9                     NaN  Walk in. Proof of California residency to rece...
# 10                    NaN  Walk in. Proof of California residency require...
# 11                    NaN  Walk in or apply by phone, email or webpage re...
# 12                    NaN  Walk in. Proof of California residency require...
# 13                    NaN  Call for appointment. Referral from human serv...
# 14                    NaN          Walk in or through other agency referral.
# 15                    NaN  Walk in. Written application, identification r...
# 16                    NaN                              Call for information.
# 17                    NaN  Call for screening appointment. Medical visits...
# 18                    NaN     Call for screening appointment (650-347-3648).
# 19                    NaN                                           Walk in.
# 20                    NaN                    By phone during business hours.
# 21  Fotos para pasaportes                  Walk in or apply by phone or mail
# 22                    NaN                  Walk in or apply by phone or mail
#
#                                              audience  \
# 0   Older adults age 55 or over, ethnic minorities...
# 1        Residents of San Mateo County age 55 or over
# 2   Older adults age 55 or over who can benefit fr...
# 3   Parents, children, families with problems of c...
# 4   Low-income working families with children tran...
# 5                                             Any age
# 6   Older adults who have memory or sensory loss, ...
# 7   Senior citizens age 60 or over, disabled indiv...
# 8      Ethnic minorities, especially Spanish speaking
# 9                                                 NaN
# 10                                                NaN
# 11  Adults, parents, children in 1st-12th grades i...
# 12                                                NaN
# 13  Individuals or families with low or no income ...
# 14  Adult alcoholic/drug addictive men and women w...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description  \
# 0   A walk-in center for older adults that provide...
# 1   Provides training and job placement to eligibl...
# 2   Offers supportive counseling services to San M...
# 3   Provides supervised visitation services and a ...
# 4   Provides fixed 8% short term loans to eligible...
# 5   A multipurpose center offering a wide variety ...
# 6   Rosener House is a day center for older adults...
# 7   Delivers a hot meal to the home of persons age...
# 8   Provides general reading material, including b...
# 9   Provides general reading and media materials, ...
# 10  Provides general reading materials, including ...
# 11  Offers an intergenerational literacy program f...
# 12  Provides general reading materials, including ...
# 13  Provides food, clothing, bus tokens and shelte...
# 14  Provides a long-term (6-12 month) residential ...
# 15  Provides emergency assistance including food a...
# 16  Provides emergency food, clothing and furnitur...
# 17  By appointment only, Project Smile provides a ...
# 18  Provides free medical and dental care to those...
# 19              no unrequired fields for this service
# 20                                just a test service
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                                           eligibility                  email  \
# 0   Age 55 or over for most programs, age 60 or ov...                    NaN
# 1   Age 55 or over, county resident and willing an...                    NaN
# 2         Resident of San Mateo County age 55 or over                    NaN
# 3                                                None                    NaN
# 4   Eligibility: Low-income family with legal cust...                    NaN
# 5                                                None                    NaN
# 6                                      Age 18 or over                    NaN
# 7             Homebound person unable to cook or shop                    NaN
# 8     Resident of California to obtain a library card                    NaN
# 9             Resident of California to obtain a card                    NaN
# 10  Resident of California to obtain a library car...                    NaN
# 11  English-speaking adult reading at or below 7th...                    NaN
# 12    Resident of California to obtain a library card                    NaN
# 13  None for most services. For emergency assistan...                    NaN
# 14  Age 21-60, detoxed, physically able and willin...                    NaN
# 15                      None for emergency assistance                    NaN
# 16                                Low-income families                    NaN
# 17    Low-income person without access to health care                    NaN
# 18    Low-income person without access to health care                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                               None  passports@example.org
# 22                                               None                    NaN
#
#     ...                            interpretation_services  \
# 0   ...                                                NaN
# 1   ...                                                NaN
# 2   ...                                                NaN
# 3   ...                                                NaN
# 4   ...                                                NaN
# 5   ...                                                NaN
# 6   ...                                                NaN
# 7   ...                                                NaN
# 8   ...                                                NaN
# 9   ...                                                NaN
# 10  ...                                                NaN
# 11  ...                                                NaN
# 12  ...                                                NaN
# 13  ...                                                NaN
# 14  ...                                                NaN
# 15  ...                                                NaN
# 16  ...                                                NaN
# 17  ...                                                NaN
# 18  ...                                                NaN
# 19  ...                                                NaN
# 20  ...                                                NaN
# 21  ...  We offer 3-way interpretation services over th...
# 22  ...                                                NaN
#
#                                              keywords languages  \
# 0   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 1   EMPLOYMENT/TRAINING SERVICES, Job Development,...       NaN
# 2   Geriatric Counseling, Older Adults, Gay, Lesbi...       NaN
# 3   INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...       NaN
# 4      COMMUNITY SERVICES, Speakers, Automobile Loans       NaN
# 5   ADULT PROTECTION AND CARE SERVICES, In-Home Su...       NaN
# 6   ADULT PROTECTION AND CARE SERVICES, Adult Day ...       NaN
# 7   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 8   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 9   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 10  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 11  EDUCATION SERVICES, Adult, Alternative, Litera...       NaN
# 12  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 13  COMMUNITY SERVICES, Interpretation/Translation...       NaN
# 14  ALCOHOLISM SERVICES, Residential Care, DRUG AB...       NaN
# 15  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 16  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 17  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 18  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 19                                                NaN       NaN
# 20                                                NaN       NaN
# 21                                    Salud, Medicina   Spanish
# 22         Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# 22                  Example Service Name
#
#                           required_documents  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  Government-issued picture identification
# 22                                       NaN
#
#                             service_areas    status  \
# 0                                   Colma    active
# 1                        San Mateo County    active
# 2                        San Mateo County    active
# 3                        San Mateo County    active
# 4                        San Mateo County    active
# 5                        San Mateo County    active
# 6     Belmont, Burlingame, East Palo Alto    active
# 7                 Belmont, East Palo Alto    active
# 8                        San Mateo County    active
# 9                        San Mateo County    active
# 10                       San Mateo County    active
# 11                              Daly City    active
# 12                       San Mateo County    active
# 13    Belmont, Burlingame, East Palo Alto    active
# 14       Alameda County, San Mateo County    active
# 15                                    NaN    active
# 16  Colma, Daly City, South San Francisco    active
# 17                         East Palo Alto    active
# 18                    Belmont, Burlingame    active
# 19                                    NaN   defunct
# 20                       San Mateo County  inactive
# 21       Alameda County, San Mateo County    active
# 22       San Mateo County, Alameda County    active
#
#                                             wait_time                 website  \
# 0                                            No wait.                     NaN
# 1                                             Varies.                     NaN
# 2                                             Varies.                     NaN
# 3                                            No wait.                     NaN
# 4                                                 NaN                     NaN
# 5                                            No wait.                     NaN
# 6                                            No wait.                     NaN
# 7                                            No wait.                     NaN
# 8                                            No wait.                     NaN
# 9                                            No wait.                     NaN
# 10                                           No wait.                     NaN
# 11  Depends on availability of tutors for small gr...                     NaN
# 12                                           No wait.                     NaN
# 13                                  Up to 20 minutes.                     NaN
# 14  Varies according to available beds for men and...                     NaN
# 15                                           No wait.                     NaN
# 16                                                NaN                     NaN
# 17                                            Varies.                     NaN
# 18                                            Varies.                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                No wait to 2 weeks.  http://www.example.com
# 22                                 No wait to 2 weeks  http://www.example.com
#
#                                 taxonomy_ids
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  105, 108, 108-05, 108-05-01, 111, 111-05
# 22                                       NaN
#
# [23 rows x 22 columns]

# %%
df = pd.read_csv('taxonomy.csv', header=None)
df
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# 288                 Legal
# 289                 Legal
# 290                 Legal
#
# [291 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('taxonomy.csv',names=['A','B','C','D','E'])
# Out:
#                A                             B          C  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         D   E
# 0             parent_name NaN
# 1                     NaN NaN
# 2               Emergency NaN
# 3               Emergency NaN
# 4          Emergency Cash NaN
# ..                    ...  ..
# 286  Advocacy & Legal Aid NaN
# 287                 Legal NaN
# 288                 Legal NaN
# 289                 Legal NaN
# 290                 Legal NaN
#
# [291 rows x 5 columns]

# %%
pd.read_csv('taxonomy.csv',names=['A','B','C'])
# Out:
#                                         A          B                     C
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv('taxonomy.csv',names=['A','B'])
# Out:
#                                                   A                     B
# taxonomy_id name                          parent_id           parent_name
# 101         Emergency                           NaN                   NaN
# 101-01      Disaster Response                   101             Emergency
# 101-02      Emergency Cash                      101             Emergency
# 101-02-01   Help Pay for Food                101-02        Emergency Cash
# ...                                             ...                   ...
# 111-01-07   Workplace Rights                 111-01  Advocacy & Legal Aid
# 111-02      Mediation                           111                 Legal
# 111-03      Notary                              111                 Legal
# 111-04      Representation                      111                 Legal
# 111-05      Translation & Interpretation        111                 Legal
#
# [291 rows x 2 columns]

# %%
pd.read_csv('data.csv',sep='|', skiprows=[1,3])
# Out:
#     Name          EmailId   Address  pincode sirname
# 0  krish  krish@gmail.com  banglore   560085    naik

# %%
df = pd.read_csv('services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes # in pandas string value is call object
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
#
#   languages                              name required_documents  \
# 0       NaN   Fair Oaks Adult Activity Center                NaN
# 1       NaN  Second Career Employment Program                NaN
#
#       service_areas  status wait_time website taxonomy_ids
# 0             Colma  active  No wait.     NaN          NaN
# 1  San Mateo County  active   Varies.     NaN          NaN
#
# [2 rows x 22 columns]

# %%
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# 22                                                NaN
#
#                                       keywords languages  \
# 21                             Salud, Medicina   Spanish
# 22  Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                     name                        required_documents  \
# 21       Passport Photos  Government-issued picture identification
# 22  Example Service Name                                       NaN
#
#                        service_areas  status            wait_time  \
# 21  Alameda County, San Mateo County  active  No wait to 2 weeks.
# 22  San Mateo County, Alameda County  active   No wait to 2 weeks
#
#                    website                              taxonomy_ids
# 21  http://www.example.com  105, 108, 108-05, 108-05-01, 111, 111-05
# 22  http://www.example.com                                       NaN
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df['email']
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21    passports@example.org
# 22                      NaN
# Name: email, dtype: object

# %%
df['keywords']
# Out:
# 0     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1     EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2     Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3     INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4        COMMUNITY SERVICES, Speakers, Automobile Loans
# 5     ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6     ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7     ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8     EDUCATION SERVICES, Library, Libraries, Public...
# 9     EDUCATION SERVICES, Library, Libraries, Public...
# 10    EDUCATION SERVICES, Library, Libraries, Public...
# 11    EDUCATION SERVICES, Adult, Alternative, Litera...
# 12    EDUCATION SERVICES, Library, Libraries, Public...
# 13    COMMUNITY SERVICES, Interpretation/Translation...
# 14    ALCOHOLISM SERVICES, Residential Care, DRUG AB...
# 15    COMMODITY SERVICES, Clothing/Personal Items, C...
# 16    COMMODITY SERVICES, Clothing/Personal Items, C...
# 17    HEALTH SERVICES, Outpatient Care, Community Cl...
# 18    HEALTH SERVICES, Outpatient Care, Community Cl...
# 19                                                  NaN
# 20                                                  NaN
# 21                                      Salud, Medicina
# 22           Ruby on Rails/Postgres/Redis, testing, wic
# Name: keywords, dtype: object

# %%
df['name']
# Out:
# 0          Fair Oaks Adult Activity Center
# 1         Second Career Employment Program
# 2                   Senior Peer Counseling
# 3                 Family Visitation Center
# 4        Economic Self-Sufficiency Program
# 5     Little House Recreational Activities
# 6         Rosener House Adult Day Services
# 7           Meals on Wheels - South County
# 8                         Fair Oaks Branch
# 9                             Main Library
# 10                         Schaberg Branch
# 11                            Project Read
# 12                   Redwood Shores Branch
# 13                      Redwood City Corps
# 14             Adult Rehabilitation Center
# 15                         Sunnyvale Corps
# 16       South San Francisco Citadel Corps
# 17                           Project Smile
# 18           San Mateo Free Medical Clinic
# 19               Service with blank fields
# 20         Service for Admin Test Location
# 21                         Passport Photos
# 22                    Example Service Name
# Name: name, dtype: object

# %%
a = df['name']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df[['name','location_id','email']]
# Out:
#                                     name  location_id                  email
# 0        Fair Oaks Adult Activity Center            1                    NaN
# 1       Second Career Employment Program            2                    NaN
# 2                 Senior Peer Counseling            3                    NaN
# 3               Family Visitation Center            4                    NaN
# 4      Economic Self-Sufficiency Program            5                    NaN
# 5   Little House Recreational Activities            6                    NaN
# 6       Rosener House Adult Day Services            7                    NaN
# 7         Meals on Wheels - South County            8                    NaN
# 8                       Fair Oaks Branch            9                    NaN
# 9                           Main Library           10                    NaN
# 10                       Schaberg Branch           11                    NaN
# 11                          Project Read           12                    NaN
# 12                 Redwood Shores Branch           13                    NaN
# 13                    Redwood City Corps           14                    NaN
# 14           Adult Rehabilitation Center           15                    NaN
# 15                       Sunnyvale Corps           16                    NaN
# 16     South San Francisco Citadel Corps           17                    NaN
# 17                         Project Smile           18                    NaN
# 18         San Mateo Free Medical Clinic           19                    NaN
# 19             Service with blank fields           20                    NaN
# 20       Service for Admin Test Location           21                    NaN
# 21                       Passport Photos           22  passports@example.org
# 22                  Example Service Name           22                    NaN

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel('MyPersonalData.xlsx',sheet_name=0)
df
# Out:
#    Topic to be covered                     Unnamed: 1
# 0                  NaN                            NaN
# 1                S No.                       Subject
# 2                    1  Data structure and Algorithms
# 3                    2    Data Base Management System
# 4                    3                    statistics
# 5                    4                          Flask
# 6                    5             Data Visualization
# 7                    6      Exploratory Data Analysis
# 8                    7               Machine learning
# 9                    8                  Deep Learning
# 10                   9                Computer Vision
# 11                  10   Natural Language Processing
# 12                  11                          Excel
# 13                  12                       Tableaue
# 14                  13                       Power BI
# 15                  14                      Aptitude
# 16                  15                            GIT
# 17                  16                             ..

# %%
pd.read_excel('MyPersonalData.xlsx',sheet_name=1)
# Out:
#   Data structure and Algorithms Unnamed: 1     Unnamed: 2          Unnamed: 3  \
# 0                           NaN        NaN            NaN                 NaN
# 1                         S No.     Topics  started date   expected to finish
# 2                             1        NaN            NaN                 NaN
# 3                             2        NaN            NaN                 NaN
# 4                             3        NaN            NaN                 NaN
# 5                             4        NaN            NaN                 NaN
# 6                             5        NaN            NaN                 NaN
# 7                             6        NaN            NaN                 NaN
# 8                             7        NaN            NaN                 NaN
# 9                             8        NaN            NaN                 NaN
#
#   Unnamed: 4  Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  \
# 0        NaN         NaN            NaN                 NaN        NaN
# 1     status  Revision 1  started date   expected to finish     status
# 2        NaN         NaN            NaN                 NaN        NaN
# 3        NaN         NaN            NaN                 NaN        NaN
# 4        NaN         NaN            NaN                 NaN        NaN
# 5        NaN         NaN            NaN                 NaN        NaN
# 6        NaN         NaN            NaN                 NaN        NaN
# 7        NaN         NaN            NaN                 NaN        NaN
# 8        NaN         NaN            NaN                 NaN        NaN
# 9        NaN         NaN            NaN                 NaN        NaN
#
#    Unnamed: 9    Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0         NaN            NaN                 NaN         NaN
# 1  revision 2  started date   expected to finish      status
# 2         NaN            NaN                 NaN         NaN
# 3         NaN            NaN                 NaN         NaN
# 4         NaN            NaN                 NaN         NaN
# 5         NaN            NaN                 NaN         NaN
# 6         NaN            NaN                 NaN         NaN
# 7         NaN            NaN                 NaN         NaN
# 8         NaN            NaN                 NaN         NaN
# 9         NaN            NaN                 NaN         NaN

# %%
pd.read_excel('MyPersonalData.xlsx',sheet_name=2)
# Out:
#    Statistics Unnamed: 1     Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN            NaN                 NaN        NaN
# 1       S No.     Topics  started date   expected to finish     status
# 2           1        NaN            NaN                 NaN        NaN
# 3           2        NaN            NaN                 NaN        NaN
# 4           3        NaN            NaN                 NaN        NaN
# 5           4        NaN            NaN                 NaN        NaN
# 6           5        NaN            NaN                 NaN        NaN
# 7           6        NaN            NaN                 NaN        NaN
# 8           7        NaN            NaN                 NaN        NaN
# 9           8        NaN            NaN                 NaN        NaN
# 10          9        NaN            NaN                 NaN        NaN
#
#     Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0          NaN            NaN                 NaN        NaN         NaN
# 1   Revision 1  started date   expected to finish     status  revision 2
# 2          NaN            NaN                 NaN        NaN         NaN
# 3          NaN            NaN                 NaN        NaN         NaN
# 4          NaN            NaN                 NaN        NaN         NaN
# 5          NaN            NaN                 NaN        NaN         NaN
# 6          NaN            NaN                 NaN        NaN         NaN
# 7          NaN            NaN                 NaN        NaN         NaN
# 8          NaN            NaN                 NaN        NaN         NaN
# 9          NaN            NaN                 NaN        NaN         NaN
# 10         NaN            NaN                 NaN        NaN         NaN
#
#       Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0             NaN                 NaN         NaN
# 1   started date   expected to finish      status
# 2             NaN                 NaN         NaN
# 3             NaN                 NaN         NaN
# 4             NaN                 NaN         NaN
# 5             NaN                 NaN         NaN
# 6             NaN                 NaN         NaN
# 7             NaN                 NaN         NaN
# 8             NaN                 NaN         NaN
# 9             NaN                 NaN         NaN
# 10            NaN                 NaN         NaN

# %%
pd.read_excel('MyPersonalData.xlsx',sheet_name=3)
# Out:
#   Database Management System Unnamed: 1     Unnamed: 2          Unnamed: 3  \
# 0                        NaN        NaN            NaN                 NaN
# 1                      S No.     Topics  started date   expected to finish
# 2                          1        SQL            NaN                 NaN
# 3                          2        NaN            NaN                 NaN
# 4                          3        NaN            NaN                 NaN
# 5                          4        NaN            NaN                 NaN
# 6                          5        NaN            NaN                 NaN
# 7                          6        NaN            NaN                 NaN
# 8                          7        NaN            NaN                 NaN
# 9                          8        NaN            NaN                 NaN
#
#   Unnamed: 4  Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  \
# 0        NaN         NaN            NaN                 NaN        NaN
# 1     status  Revision 1  started date   expected to finish     status
# 2        NaN         NaN            NaN                 NaN        NaN
# 3        NaN         NaN            NaN                 NaN        NaN
# 4        NaN         NaN            NaN                 NaN        NaN
# 5        NaN         NaN            NaN                 NaN        NaN
# 6        NaN         NaN            NaN                 NaN        NaN
# 7        NaN         NaN            NaN                 NaN        NaN
# 8        NaN         NaN            NaN                 NaN        NaN
# 9        NaN         NaN            NaN                 NaN        NaN
#
#    Unnamed: 9    Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0         NaN            NaN                 NaN         NaN
# 1  revision 2  started date   expected to finish      status
# 2         NaN            NaN                 NaN         NaN
# 3         NaN            NaN                 NaN         NaN
# 4         NaN            NaN                 NaN         NaN
# 5         NaN            NaN                 NaN         NaN
# 6         NaN            NaN                 NaN         NaN
# 7         NaN            NaN                 NaN         NaN
# 8         NaN            NaN                 NaN         NaN
# 9         NaN            NaN                 NaN         NaN

# %%
pd.read_excel('MyPersonalData.xlsx',sheet_name=4)
# Out:
#    Daily Routine           Unnamed: 1                   Unnamed: 2  \
# 0            NaN                  NaN                          NaN
# 1            Day                 date                      Topics
# 2         Monday  2022-01-31 00:00:00                  Linked List
# 3        Tuesday  2022-02-01 00:00:00            Linked List, tree
# 4      Wednesday  2022-02-02 00:00:00                         tree
# 5       Thursday  2022-02-03 00:00:00            sorting,searching
# 6         Friday  2022-02-04 00:00:00                    searching
# 7       Saturday  2022-02-05 00:00:00                         heap
# 8         Sunday  2022-02-06 00:00:00                         heap
# 9         Monday  2022-02-07 00:00:00              stack and queue
# 10       Tuesday  2022-02-08 00:00:00                Greedy, array
# 11     Wednesday  2022-02-09 00:00:00                        array
# 12      Thursday  2022-02-10 00:00:00                       string
# 13        Friday  2022-02-11 00:00:00                 string,grapg
# 14      Saturday  2022-02-12 00:00:00                graph,hashing
# 15        Sunday  2022-02-13 00:00:00         dynammic programming
# 16           NaN                  NaN                          NaN
# 17           NaN                  NaN                          NaN
# 18        Monday  2022-02-14 00:00:00                          NaN
# 19       Tuesday  2022-02-15 00:00:00                          NaN
# 20     Wednesday  2022-02-16 00:00:00                          NaN
# 21      Thursday  2022-02-17 00:00:00                          NaN
# 22        Friday  2022-02-18 00:00:00                          NaN
# 23      Saturday  2022-02-19 00:00:00                          NaN
# 24        Sunday  2022-02-20 00:00:00                          NaN
# 25        Monday  2022-02-21 00:00:00                          NaN
# 26       Tuesday  2022-02-22 00:00:00                         git
# 27     Wednesday  2022-02-23 00:00:00  python functions Assignment
# 28      Thursday  2022-02-24 00:00:00  SQL and MongoDB assignments
# 29        Friday  2022-02-25 00:00:00  andvanced Python and Flask
# 30      Saturday  2022-02-26 00:00:00                          NaN
# 31        Sunday  2022-02-27 00:00:00                          NaN
# 32        Monday  2022-02-28 00:00:00                          NaN
# 33       Tuesday  2022-03-01 00:00:00                          NaN
# 34     Wednesday  2022-03-02 00:00:00                          NaN
# 35      Thursday  2022-03-03 00:00:00                          NaN
# 36        Friday  2022-03-04 00:00:00                          NaN
# 37      Saturday  2022-03-05 00:00:00                          NaN
# 38        Sunday  2022-03-06 00:00:00                          NaN
# 39        Monday  2022-03-07 00:00:00                          NaN
# 40       Tuesday  2022-03-08 00:00:00                          NaN
# 41     Wednesday  2022-03-09 00:00:00                          NaN
# 42      Thursday  2022-03-10 00:00:00                          NaN
# 43        Friday  2022-03-11 00:00:00                          NaN
# 44      Saturday  2022-03-12 00:00:00                          NaN
# 45        Sunday  2022-03-13 00:00:00                          NaN
# 46        Monday  2022-03-14 00:00:00                          NaN
# 47       Tuesday  2022-03-15 00:00:00                          NaN
# 48     Wednesday  2022-03-16 00:00:00                          NaN
# 49      Thursday  2022-03-17 00:00:00                          NaN
# 50        Friday  2022-03-18 00:00:00                          NaN
#
#                   Unnamed: 3           Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                        NaN                  NaN         NaN         NaN
# 1                        NaN                  NaN         NaN         NaN
# 2            time complexity                  NaN         NaN         NaN
# 3                        SQL     space complexity         NaN         NaN
# 4                        SQL                maths         NaN         NaN
# 5                        SQL                maths         NaN         NaN
# 6                        SQL                maths         NaN         NaN
# 7                        NaN                maths         NaN         NaN
# 8                        NaN           Statistics         NaN         NaN
# 9                        NaN                  NaN         NaN         NaN
# 10                       NaN                  NaN         NaN         NaN
# 11                       NaN                  NaN         NaN         NaN
# 12          bit manipulation                  NaN         NaN         NaN
# 13      dynammic programming                  NaN         NaN         NaN
# 14                       NaN                  NaN         NaN         NaN
# 15                       NaN                  NaN         NaN         NaN
# 16                       NaN                  NaN         NaN         NaN
# 17                       NaN                  NaN         NaN         NaN
# 18                       NaN                  NaN         NaN         NaN
# 19                       NaN                  NaN         NaN         NaN
# 20                       NaN                  NaN         NaN         NaN
# 21                       NaN                  NaN         NaN         NaN
# 22                       GIT                  NaN         NaN         NaN
# 23                       GIT                  NaN         NaN         NaN
# 24                       NaN                  NaN         NaN         NaN
# 25                       NaN                  NaN         NaN         NaN
# 26                statistics            Recursion         NaN         NaN
# 27  python Module Assignment                Array         NaN         NaN
# 28              Assignment 3                Array         NaN         NaN
# 29              Assignment 4               String         NaN         NaN
# 30                 Aptitude                String         NaN         NaN
# 31                 Aptitude               Sorting         NaN         NaN
# 32                 Aptitude               Sorting         NaN         NaN
# 33                 Aptitude                   NaN         NaN         NaN
# 34                 Aptitude                   NaN         NaN         NaN
# 35                       NaN      Stack and Queue         NaN         NaN
# 36                 Aptitude       Stack and Queue         NaN         NaN
# 37                 Aptitude                Greedy         NaN         NaN
# 38                 Aptitude                Greedy         NaN         NaN
# 39                 Aptitude                   NaN         NaN         NaN
# 40                 Aptitude                 Graph         NaN         NaN
# 41                       NaN                Graph         NaN         NaN
# 42                 Aptitude               Hashing         NaN         NaN
# 43                 Aptitude               Hashing         NaN         NaN
# 44                 Aptitude        Maths Programs         NaN         NaN
# 45                 Aptitude        Maths Programs         NaN         NaN
# 46                 Aptitude                   NaN         NaN         NaN
# 47                       NaN  Dynamic Programming         NaN         NaN
# 48                 Aptitude   Dynamic Programming         NaN         NaN
# 49                 Aptitude      Bit Manupulation         NaN         NaN
# 50                 Aptitude      Bit Manupulation         NaN         NaN
#
#            Unnamed: 7   Unnamed: 8
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4                 NaN          NaN
# 5                 NaN          NaN
# 6                 NaN          NaN
# 7                 NaN          NaN
# 8                 NaN          NaN
# 9                 NaN          NaN
# 10                NaN          NaN
# 11                NaN          NaN
# 12                NaN          NaN
# 13                NaN          NaN
# 14                NaN          NaN
# 15                NaN          NaN
# 16         Rough Idea          NaN
# 17                NaN          NaN
# 18               Date        Topic
# 19                NaN          NaN
# 20        21---25 Feb          NaN
# 21     28 Feb - 4 Mar          NaN
# 22  7 - 11,14,15 Mar           NaN
# 23  16 - 18,21-25 Mar          NaN
# 24                NaN          NaN
# 25                NaN          NaN
# 26                NaN          NaN
# 27                NaN          NaN
# 28                NaN          NaN
# 29                NaN          NaN
# 30                NaN          NaN
# 31                NaN    Searching
# 32                NaN    Searching
# 33                NaN  Linked List
# 34                NaN  Linked List
# 35                NaN         Tree
# 36                NaN         Tree
# 37                NaN         Heap
# 38                NaN         Heap
# 39                NaN          NaN
# 40                NaN          NaN
# 41                NaN          NaN
# 42                NaN          NaN
# 43                NaN          NaN
# 44                NaN          NaN
# 45                NaN          NaN
# 46                NaN          NaN
# 47                NaN          NaN
# 48                NaN          NaN
# 49                NaN          NaN
# 50                NaN          NaN

# %%
pd.read_excel('MyPersonalData.xlsx',sheet_name=5)
# Out:
#    Daily Work           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0         NaN                  NaN        NaN        NaN        NaN
# 1         NaN                  NaN        NaN        NaN        NaN
# 2         NaN                  NaN        NaN        NaN        NaN
# 3         Day                 Date     Topic1     Topic2     Topic3
# 4      Monday  2022-02-21 00:00:00        NaN        NaN        NaN
# ..        ...                  ...        ...        ...        ...
# 65   Saturday  2022-04-23 00:00:00        NaN        NaN        NaN
# 66     Sunday  2022-04-24 00:00:00        NaN        NaN        NaN
# 67     Monday  2022-04-25 00:00:00        NaN        NaN        NaN
# 68    Tuesday  2022-04-26 00:00:00        NaN        NaN        NaN
# 69  Wednesday  2022-04-27 00:00:00        NaN        NaN        NaN
#
# [70 rows x 5 columns]

# %%
df = pd.ExcelFile('MyPersonalData.xlsx')

# %%
df.sheet_names
# Out:
# ['Topics', 'DSA', 'Stat', 'DBMS', 'Daily target', 'Sheet1']

# %%
for i in df.sheet_names:
    data = pd.read_excel('MyPersonalData.xlsx',sheet_name=i)
    print(data)
# Out:
#    Topic to be covered                     Unnamed: 1
# 0                  NaN                            NaN
# 1                S No.                       Subject
# 2                    1  Data structure and Algorithms
# 3                    2    Data Base Management System
# 4                    3                    statistics
# 5                    4                          Flask
# 6                    5             Data Visualization
# 7                    6      Exploratory Data Analysis
# 8                    7               Machine learning
# 9                    8                  Deep Learning
# 10                   9                Computer Vision
# 11                  10   Natural Language Processing
# 12                  11                          Excel
# 13                  12                       Tableaue
# 14                  13                       Power BI
# 15                  14                      Aptitude
# 16                  15                            GIT
# 17                  16                             ..
#   Data structure and Algorithms Unnamed: 1     Unnamed: 2          Unnamed: 3  \
# 0                           NaN        NaN            NaN                 NaN
# 1                         S No.     Topics  started date   expected to finish
# 2                             1        NaN            NaN                 NaN
# 3                             2        NaN            NaN                 NaN
# 4                             3        NaN            NaN                 NaN
# 5                             4        NaN            NaN                 NaN
# 6                             5        NaN            NaN                 NaN
# 7                             6        NaN            NaN                 NaN
# 8                             7        NaN            NaN                 NaN
# 9                             8        NaN            NaN                 NaN
#
#   Unnamed: 4  Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  \
# 0        NaN         NaN            NaN                 NaN        NaN
# 1     status  Revision 1  started date   expected to finish     status
# 2        NaN         NaN            NaN                 NaN        NaN
# 3        NaN         NaN            NaN                 NaN        NaN
# 4        NaN         NaN            NaN                 NaN        NaN
# 5        NaN         NaN            NaN                 NaN        NaN
# 6        NaN         NaN            NaN                 NaN        NaN
# 7        NaN         NaN            NaN                 NaN        NaN
# 8        NaN         NaN            NaN                 NaN        NaN
# 9        NaN         NaN            NaN                 NaN        NaN
#
#    Unnamed: 9    Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0         NaN            NaN                 NaN         NaN
# 1  revision 2  started date   expected to finish      status
# 2         NaN            NaN                 NaN         NaN
# 3         NaN            NaN                 NaN         NaN
# 4         NaN            NaN                 NaN         NaN
# 5         NaN            NaN                 NaN         NaN
# 6         NaN            NaN                 NaN         NaN
# 7         NaN            NaN                 NaN         NaN
# 8         NaN            NaN                 NaN         NaN
# 9         NaN            NaN                 NaN         NaN
#    Statistics Unnamed: 1     Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN            NaN                 NaN        NaN
# 1       S No.     Topics  started date   expected to finish     status
# 2           1        NaN            NaN                 NaN        NaN
# 3           2        NaN            NaN                 NaN        NaN
# 4           3        NaN            NaN                 NaN        NaN
# 5           4        NaN            NaN                 NaN        NaN
# 6           5        NaN            NaN                 NaN        NaN
# 7           6        NaN            NaN                 NaN        NaN
# 8           7        NaN            NaN                 NaN        NaN
# 9           8        NaN            NaN                 NaN        NaN
# 10          9        NaN            NaN                 NaN        NaN
#
#     Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0          NaN            NaN                 NaN        NaN         NaN
# 1   Revision 1  started date   expected to finish     status  revision 2
# 2          NaN            NaN                 NaN        NaN         NaN
# 3          NaN            NaN                 NaN        NaN         NaN
# 4          NaN            NaN                 NaN        NaN         NaN
# 5          NaN            NaN                 NaN        NaN         NaN
# 6          NaN            NaN                 NaN        NaN         NaN
# 7          NaN            NaN                 NaN        NaN         NaN
# 8          NaN            NaN                 NaN        NaN         NaN
# 9          NaN            NaN                 NaN        NaN         NaN
# 10         NaN            NaN                 NaN        NaN         NaN
#
#       Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0             NaN                 NaN         NaN
# 1   started date   expected to finish      status
# 2             NaN                 NaN         NaN
# 3             NaN                 NaN         NaN
# 4             NaN                 NaN         NaN
# 5             NaN                 NaN         NaN
# 6             NaN                 NaN         NaN
# 7             NaN                 NaN         NaN
# 8             NaN                 NaN         NaN
# 9             NaN                 NaN         NaN
# 10            NaN                 NaN         NaN
#   Database Management System Unnamed: 1     Unnamed: 2          Unnamed: 3  \
# 0                        NaN        NaN            NaN                 NaN
# 1                      S No.     Topics  started date   expected to finish
# 2                          1        SQL            NaN                 NaN
# 3                          2        NaN            NaN                 NaN
# 4                          3        NaN            NaN                 NaN
# 5                          4        NaN            NaN                 NaN
# 6                          5        NaN            NaN                 NaN
# 7                          6        NaN            NaN                 NaN
# 8                          7        NaN            NaN                 NaN
# 9                          8        NaN            NaN                 NaN
#
#   Unnamed: 4  Unnamed: 5     Unnamed: 6          Unnamed: 7 Unnamed: 8  \
# 0        NaN         NaN            NaN                 NaN        NaN
# 1     status  Revision 1  started date   expected to finish     status
# 2        NaN         NaN            NaN                 NaN        NaN
# 3        NaN         NaN            NaN                 NaN        NaN
# 4        NaN         NaN            NaN                 NaN        NaN
# 5        NaN         NaN            NaN                 NaN        NaN
# 6        NaN         NaN            NaN                 NaN        NaN
# 7        NaN         NaN            NaN                 NaN        NaN
# 8        NaN         NaN            NaN                 NaN        NaN
# 9        NaN         NaN            NaN                 NaN        NaN
#
#    Unnamed: 9    Unnamed: 10         Unnamed: 11 Unnamed: 12
# 0         NaN            NaN                 NaN         NaN
# 1  revision 2  started date   expected to finish      status
# 2         NaN            NaN                 NaN         NaN
# 3         NaN            NaN                 NaN         NaN
# 4         NaN            NaN                 NaN         NaN
# 5         NaN            NaN                 NaN         NaN
# 6         NaN            NaN                 NaN         NaN
# 7         NaN            NaN                 NaN         NaN
# 8         NaN            NaN                 NaN         NaN
# 9         NaN            NaN                 NaN         NaN
#    Daily Routine           Unnamed: 1                   Unnamed: 2  \
# 0            NaN                  NaN                          NaN
# 1            Day                 date                      Topics
# 2         Monday  2022-01-31 00:00:00                  Linked List
# 3        Tuesday  2022-02-01 00:00:00            Linked List, tree
# 4      Wednesday  2022-02-02 00:00:00                         tree
# 5       Thursday  2022-02-03 00:00:00            sorting,searching
# 6         Friday  2022-02-04 00:00:00                    searching
# 7       Saturday  2022-02-05 00:00:00                         heap
# 8         Sunday  2022-02-06 00:00:00                         heap
# 9         Monday  2022-02-07 00:00:00              stack and queue
# 10       Tuesday  2022-02-08 00:00:00                Greedy, array
# 11     Wednesday  2022-02-09 00:00:00                        array
# 12      Thursday  2022-02-10 00:00:00                       string
# 13        Friday  2022-02-11 00:00:00                 string,grapg
# 14      Saturday  2022-02-12 00:00:00                graph,hashing
# 15        Sunday  2022-02-13 00:00:00         dynammic programming
# 16           NaN                  NaN                          NaN
# 17           NaN                  NaN                          NaN
# 18        Monday  2022-02-14 00:00:00                          NaN
# 19       Tuesday  2022-02-15 00:00:00                          NaN
# 20     Wednesday  2022-02-16 00:00:00                          NaN
# 21      Thursday  2022-02-17 00:00:00                          NaN
# 22        Friday  2022-02-18 00:00:00                          NaN
# 23      Saturday  2022-02-19 00:00:00                          NaN
# 24        Sunday  2022-02-20 00:00:00                          NaN
# 25        Monday  2022-02-21 00:00:00                          NaN
# 26       Tuesday  2022-02-22 00:00:00                         git
# 27     Wednesday  2022-02-23 00:00:00  python functions Assignment
# 28      Thursday  2022-02-24 00:00:00  SQL and MongoDB assignments
# 29        Friday  2022-02-25 00:00:00  andvanced Python and Flask
# 30      Saturday  2022-02-26 00:00:00                          NaN
# 31        Sunday  2022-02-27 00:00:00                          NaN
# 32        Monday  2022-02-28 00:00:00                          NaN
# 33       Tuesday  2022-03-01 00:00:00                          NaN
# 34     Wednesday  2022-03-02 00:00:00                          NaN
# 35      Thursday  2022-03-03 00:00:00                          NaN
# 36        Friday  2022-03-04 00:00:00                          NaN
# 37      Saturday  2022-03-05 00:00:00                          NaN
# 38        Sunday  2022-03-06 00:00:00                          NaN
# 39        Monday  2022-03-07 00:00:00                          NaN
# 40       Tuesday  2022-03-08 00:00:00                          NaN
# 41     Wednesday  2022-03-09 00:00:00                          NaN
# 42      Thursday  2022-03-10 00:00:00                          NaN
# 43        Friday  2022-03-11 00:00:00                          NaN
# 44      Saturday  2022-03-12 00:00:00                          NaN
# 45        Sunday  2022-03-13 00:00:00                          NaN
# 46        Monday  2022-03-14 00:00:00                          NaN
# 47       Tuesday  2022-03-15 00:00:00                          NaN
# 48     Wednesday  2022-03-16 00:00:00                          NaN
# 49      Thursday  2022-03-17 00:00:00                          NaN
# 50        Friday  2022-03-18 00:00:00                          NaN
#
#                   Unnamed: 3           Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                        NaN                  NaN         NaN         NaN
# 1                        NaN                  NaN         NaN         NaN
# 2            time complexity                  NaN         NaN         NaN
# 3                        SQL     space complexity         NaN         NaN
# 4                        SQL                maths         NaN         NaN
# 5                        SQL                maths         NaN         NaN
# 6                        SQL                maths         NaN         NaN
# 7                        NaN                maths         NaN         NaN
# 8                        NaN           Statistics         NaN         NaN
# 9                        NaN                  NaN         NaN         NaN
# 10                       NaN                  NaN         NaN         NaN
# 11                       NaN                  NaN         NaN         NaN
# 12          bit manipulation                  NaN         NaN         NaN
# 13      dynammic programming                  NaN         NaN         NaN
# 14                       NaN                  NaN         NaN         NaN
# 15                       NaN                  NaN         NaN         NaN
# 16                       NaN                  NaN         NaN         NaN
# 17                       NaN                  NaN         NaN         NaN
# 18                       NaN                  NaN         NaN         NaN
# 19                       NaN                  NaN         NaN         NaN
# 20                       NaN                  NaN         NaN         NaN
# 21                       NaN                  NaN         NaN         NaN
# 22                       GIT                  NaN         NaN         NaN
# 23                       GIT                  NaN         NaN         NaN
# 24                       NaN                  NaN         NaN         NaN
# 25                       NaN                  NaN         NaN         NaN
# 26                statistics            Recursion         NaN         NaN
# 27  python Module Assignment                Array         NaN         NaN
# 28              Assignment 3                Array         NaN         NaN
# 29              Assignment 4               String         NaN         NaN
# 30                 Aptitude                String         NaN         NaN
# 31                 Aptitude               Sorting         NaN         NaN
# 32                 Aptitude               Sorting         NaN         NaN
# 33                 Aptitude                   NaN         NaN         NaN
# 34                 Aptitude                   NaN         NaN         NaN
# 35                       NaN      Stack and Queue         NaN         NaN
# 36                 Aptitude       Stack and Queue         NaN         NaN
# 37                 Aptitude                Greedy         NaN         NaN
# 38                 Aptitude                Greedy         NaN         NaN
# 39                 Aptitude                   NaN         NaN         NaN
# 40                 Aptitude                 Graph         NaN         NaN
# 41                       NaN                Graph         NaN         NaN
# 42                 Aptitude               Hashing         NaN         NaN
# 43                 Aptitude               Hashing         NaN         NaN
# 44                 Aptitude        Maths Programs         NaN         NaN
# 45                 Aptitude        Maths Programs         NaN         NaN
# 46                 Aptitude                   NaN         NaN         NaN
# 47                       NaN  Dynamic Programming         NaN         NaN
# 48                 Aptitude   Dynamic Programming         NaN         NaN
# 49                 Aptitude      Bit Manupulation         NaN         NaN
# 50                 Aptitude      Bit Manupulation         NaN         NaN
#
#            Unnamed: 7   Unnamed: 8
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2                 NaN          NaN
# 3                 NaN          NaN
# 4                 NaN          NaN
# 5                 NaN          NaN
# 6                 NaN          NaN
# 7                 NaN          NaN
# 8                 NaN          NaN
# 9                 NaN          NaN
# 10                NaN          NaN
# 11                NaN          NaN
# 12                NaN          NaN
# 13                NaN          NaN
# 14                NaN          NaN
# 15                NaN          NaN
# 16         Rough Idea          NaN
# 17                NaN          NaN
# 18               Date        Topic
# 19                NaN          NaN
# 20        21---25 Feb          NaN
# 21     28 Feb - 4 Mar          NaN
# 22  7 - 11,14,15 Mar           NaN
# 23  16 - 18,21-25 Mar          NaN
# 24                NaN          NaN
# 25                NaN          NaN
# 26                NaN          NaN
# 27                NaN          NaN
# 28                NaN          NaN
# 29                NaN          NaN
# 30                NaN          NaN
# 31                NaN    Searching
# 32                NaN    Searching
# 33                NaN  Linked List
# 34                NaN  Linked List
# 35                NaN         Tree
# 36                NaN         Tree
# 37                NaN         Heap
# 38                NaN         Heap
# 39                NaN          NaN
# 40                NaN          NaN
# 41                NaN          NaN
# 42                NaN          NaN
# 43                NaN          NaN
# 44                NaN          NaN
# 45                NaN          NaN
# 46                NaN          NaN
# 47                NaN          NaN
# 48                NaN          NaN
# 49                NaN          NaN
# 50                NaN          NaN
#    Daily Work           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0         NaN                  NaN        NaN        NaN        NaN
# 1         NaN                  NaN        NaN        NaN        NaN
# 2         NaN                  NaN        NaN        NaN        NaN
# 3         Day                 Date     Topic1     Topic2     Topic3
# 4      Monday  2022-02-21 00:00:00        NaN        NaN        NaN
# ..        ...                  ...        ...        ...        ...
# 65   Saturday  2022-04-23 00:00:00        NaN        NaN        NaN
# 66     Sunday  2022-04-24 00:00:00        NaN        NaN        NaN
# 67     Monday  2022-04-25 00:00:00        NaN        NaN        NaN
# 68    Tuesday  2022-04-26 00:00:00        NaN        NaN        NaN
# 69  Wednesday  2022-04-27 00:00:00        NaN        NaN        NaN
#
# [70 rows x 5 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv')

# %%
df1.to_csv('NBA2.csv',index=False,)

# %%
data = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')
data
# Out:
# [               Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
#  0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
#  1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
#  2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
#  3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
#  4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
#  ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
#  92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
#  93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
#  94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
#  95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
#  96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#     100 50  0  4s  6s
#  0    0  0  0   2   0
#  1    0  0  0   0   0
#  2    -  -  -   -   -
#  3    0  0  0  14   1
#  4    -  -  -   -   -
#  ..  .. .. ..  ..  ..
#  92   0  0  0   0   0
#  93   0  0  3   4   3
#  94   0  4  1  32  20
#  95   0  0  0   0   0
#  96   0  8  1  77  74
#
#  [97 rows x 15 columns],
#                                                     0
#  0  By default, the shading indicates records from...
#  1  Adjust:  most recent  | past week  | past mont...,
#                                                     0
#  0  Records includes the following current or rece...
#  1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
#  2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
#  3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...]

# %%
len(data)
# Out:
# 3

# %%
data[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
data[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
data[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
data[0].to_csv('cricket.csv',index=False)

# %%
d = """{
    "name":"sudhanshu kumar",
    "email_id":"sskumar@gmail.com",
    "tech":["ML","DL","CV","NLP","RL","BD","DA"],
    "plateform":["techneuron","kidneuron","ineuron","github","youtube","linkedIn","internship"]
}"""

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8236/2567112034.py in <module>
# ----> 1 pd.DataFrame(d)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
import json

# %%
result = json.loads(d)
result
# Out:
# {'name': 'sudhanshu kumar',
#  'email_id': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'plateform': ['techneuron',
#   'kidneuron',
#   'ineuron',
#   'github',
#   'youtube',
#   'linkedIn',
#   'internship']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#               name           email_id tech   plateform
# 0  sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  sudhanshu kumar  sskumar@gmail.com   DL   kidneuron
# 2  sudhanshu kumar  sskumar@gmail.com   CV     ineuron
# 3  sudhanshu kumar  sskumar@gmail.com  NLP      github
# 4  sudhanshu kumar  sskumar@gmail.com   RL     youtube
# 5  sudhanshu kumar  sskumar@gmail.com   BD    linkedIn
# 6  sudhanshu kumar  sskumar@gmail.com   DA  internship

# %%
pd.read_json(d)
# Out:
#               name           email_id tech   plateform
# 0  sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  sudhanshu kumar  sskumar@gmail.com   DL   kidneuron
# 2  sudhanshu kumar  sskumar@gmail.com   CV     ineuron
# 3  sudhanshu kumar  sskumar@gmail.com  NLP      github
# 4  sudhanshu kumar  sskumar@gmail.com   RL     youtube
# 5  sudhanshu kumar  sskumar@gmail.com   BD    linkedIn
# 6  sudhanshu kumar  sskumar@gmail.com   DA  internship

# %%
d1 =""" {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}"""

# %%
result1 = pd.read_json(d1)
result1
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/46353  1167498221
# 1   https://github.com/pandas-dev/pandas/issues/46352  1167470919
# 2   https://github.com/pandas-dev/pandas/issues/46351  1167422549
# 3     https://github.com/pandas-dev/pandas/pull/46350  1167422110
# 4     https://github.com/pandas-dev/pandas/pull/46349  1167417912
# 5     https://github.com/pandas-dev/pandas/pull/46348  1167412829
# 6     https://github.com/pandas-dev/pandas/pull/46347  1167404425
# 7     https://github.com/pandas-dev/pandas/pull/46346  1167386303
# 8     https://github.com/pandas-dev/pandas/pull/46343  1167366731
# 9     https://github.com/pandas-dev/pandas/pull/46342  1167331327
# 10    https://github.com/pandas-dev/pandas/pull/46341  1167329989
# 11  https://github.com/pandas-dev/pandas/issues/46339  1167181077
# 12    https://github.com/pandas-dev/pandas/pull/46338  1167165103
# 13  https://github.com/pandas-dev/pandas/issues/46337  1167162310
# 14  https://github.com/pandas-dev/pandas/issues/46336  1167160890
# 15  https://github.com/pandas-dev/pandas/issues/46332  1166971186
# 16  https://github.com/pandas-dev/pandas/issues/46331  1166957820
# 17    https://github.com/pandas-dev/pandas/pull/46330  1166865454
# 18  https://github.com/pandas-dev/pandas/issues/46326  1166612234
# 19  https://github.com/pandas-dev/pandas/issues/46324  1166353036
# 20    https://github.com/pandas-dev/pandas/pull/46321  1166312846
# 21  https://github.com/pandas-dev/pandas/issues/46319  1166255061
# 22  https://github.com/pandas-dev/pandas/issues/46313  1165672382
# 23    https://github.com/pandas-dev/pandas/pull/46312  1165636565
# 24  https://github.com/pandas-dev/pandas/issues/46310  1165554305
# 25    https://github.com/pandas-dev/pandas/pull/46308  1165401382
# 26  https://github.com/pandas-dev/pandas/issues/46305  1165243629
# 27    https://github.com/pandas-dev/pandas/pull/46304  1165164366
# 28    https://github.com/pandas-dev/pandas/pull/46300  1164717212
# 29  https://github.com/pandas-dev/pandas/issues/46298  1164620575
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85Flpvt   46353
# 1    I_kwDOAA0YD85FljFH   46352
# 2    I_kwDOAA0YD85FlXRV   46351
# 3   PR_kwDOAA0YD840WVgz   46350
# 4   PR_kwDOAA0YD840WUvE   46349
# 5   PR_kwDOAA0YD840WT3e   46348
# 6   PR_kwDOAA0YD840WSZR   46347
# 7   PR_kwDOAA0YD840WO50   46346
# 8   PR_kwDOAA0YD840WLMs   46343
# 9   PR_kwDOAA0YD840WEz_   46342
# 10  PR_kwDOAA0YD840WEmO   46341
# 11   I_kwDOAA0YD85FkcUV   46339
# 12  PR_kwDOAA0YD840VmSV   46338
# 13   I_kwDOAA0YD85FkXvG   46337
# 14   I_kwDOAA0YD85FkXY6   46336
# 15   I_kwDOAA0YD85FjpEy   46332
# 16   I_kwDOAA0YD85Fjlz8   46331
# 17  PR_kwDOAA0YD840UmcA   46330
# 18   I_kwDOAA0YD85FiRcK   46326
# 19   I_kwDOAA0YD85FhSKM   46324
# 20  PR_kwDOAA0YD840SzrD   46321
# 21   I_kwDOAA0YD85Fg6PV   46319
# 22   I_kwDOAA0YD85Fer--   46313
# 23  PR_kwDOAA0YD840QmJ_   46312
# 24   I_kwDOAA0YD85FePKB   46310
# 25  PR_kwDOAA0YD840P1BQ   46308
# 26   I_kwDOAA0YD85FdDTt   46305
# 27  PR_kwDOAA0YD840PCL-   46304
# 28  PR_kwDOAA0YD840Nj7j   46300
# 29   I_kwDOAA0YD85FarMf   46298
#
#                                                 title  ...  \
# 0   DOC: Document that astype() for Series and Dat...  ...
# 1   ENH: read_excel should assume engine when pass...  ...
# 2                     Question: why use Azure for CI?  ...
# 3   TST: xfail(strict=False) flaky hashtable test ...  ...
# 4                            PERF: Index[StringArray]  ...
# 5   Series.map Performance Improvement When Using ...  ...
# 6                                  Fix snappy version  ...
# 7                   WIP Use provision-with-micromamba  ...
# 8   TYP: Add typing for pd.to_timedelta, fix Timed...  ...
# 9              Bug fix -  groupby sum removed columns  ...
# 10            PERF: use bisect_right_i8 in vectorized  ...
# 11                                      PyCon US 2022  ...
# 12             REF: de-duplicate hard-coded unit code  ...
# 13                   TYP: returning None for __init__  ...
# 14  BUG: dataframe.rename function shows no warnin...  ...
# 15  BUG: Binary operations with empty string array...  ...
# 16  BUG: the behavior of "date_range" function wit...  ...
# 17  REF/PERF: MultiIndex.get_locs to use boolean a...  ...
# 18  BUG: `isin` propagates nulls for DataFrame but...  ...
# 19  BUG: core.groupby.GroupBy.apply unexpected beh...  ...
# 20                     WIP Add ccache to Azure builds  ...
# 21  BUG: `UnicodeError` when using `Period.strftim...  ...
# 22  BUG: Categorical of booleans has object .categ...  ...
# 23         BUG: avoid OOB flow in read_gbq and to_gbq  ...
# 24      ENH: Add `subset` param to `add_(pre|suf)fix`  ...
# 25                    DOC: Add TextFileReader to docs  ...
# 26  ENH: merging using DataFrame index should rais...  ...
# 27  BUG: merge raising for Int64 and int64 dtype w...  ...
# 28                                    TYP: sort_index  ...
# 29           BUG:  "data type 'Int64' not understood"  ...
#
#                   updated_at closed_at author_association  active_lock_reason  \
# 0  2022-03-13 06:52:08+00:00       NaT               NONE                 NaN
# 1  2022-03-13 03:51:41+00:00       NaT               NONE                 NaN
# 2  2022-03-12 23:13:37+00:00       NaT        CONTRIBUTOR                 NaN
# 3  2022-03-13 00:56:30+00:00       NaT             MEMBER                 NaN
# 4  2022-03-12 22:40:13+00:00       NaT             MEMBER                 NaN
# 5  2022-03-12 23:36:30+00:00       NaT               NONE                 NaN
# 6  2022-03-13 00:23:34+00:00       NaT        CONTRIBUTOR                 NaN
# 7  2022-03-12 21:42:38+00:00       NaT        CONTRIBUTOR                 NaN
# 8  2022-03-13 00:05:22+00:00       NaT        CONTRIBUTOR                 NaN
# 9  2022-03-13 08:04:26+00:00       NaT        CONTRIBUTOR                 NaN
# 10 2022-03-13 01:27:44+00:00       NaT             MEMBER                 NaN
# 11 2022-03-12 05:00:28+00:00       NaT             MEMBER                 NaN
# 12 2022-03-13 01:34:01+00:00       NaT             MEMBER                 NaN
# 13 2022-03-12 18:37:12+00:00       NaT        CONTRIBUTOR                 NaN
# 14 2022-03-12 14:48:33+00:00       NaT               NONE                 NaN
# 15 2022-03-11 23:15:26+00:00       NaT               NONE                 NaN
# 16 2022-03-13 07:51:43+00:00       NaT               NONE                 NaN
# 17 2022-03-12 21:07:45+00:00       NaT             MEMBER                 NaN
# 18 2022-03-11 16:53:06+00:00       NaT               NONE                 NaN
# 19 2022-03-11 12:19:20+00:00       NaT               NONE                 NaN
# 20 2022-03-12 19:10:13+00:00       NaT        CONTRIBUTOR                 NaN
# 21 2022-03-11 10:51:46+00:00       NaT        CONTRIBUTOR                 NaN
# 22 2022-03-11 12:32:13+00:00       NaT        CONTRIBUTOR                 NaN
# 23 2022-03-11 01:30:39+00:00       NaT        CONTRIBUTOR                 NaN
# 24 2022-03-11 00:46:10+00:00       NaT        CONTRIBUTOR                 NaN
# 25 2022-03-11 23:48:13+00:00       NaT             MEMBER                 NaN
# 26 2022-03-10 13:42:15+00:00       NaT               NONE                 NaN
# 27 2022-03-10 19:40:21+00:00       NaT             MEMBER                 NaN
# 28 2022-03-13 12:28:32+00:00       NaT        CONTRIBUTOR                 NaN
# 29 2022-03-10 09:32:52+00:00       NaT               NONE                 NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   #### Is your feature request related to a prob...
# 2   What’s the reason that pandas uses GHA alongsi...
# 3   - [x] [Tests added and passed](https://pandas....
# 4   - [x] closes #45652 (Replace xxxx with the Git...
# 5   - [x] closes #46248\r\n- [ ] [Tests added and ...
# 6   Fix for https://github.com/pandas-dev/pandas/p...
# 7   Based on #45701\r\n\r\n- [ ] closes #xxxx (Rep...
# 8   Add typing for pd.to_timedelta\r\nChange opera...
# 9   - [x] closes #44132 \r\n- [ ] [Tests added and...
# 10  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 11  Do we have any plan for PyCon US 2022?\r\n\r\n...
# 12  I had hoped  to go further and get rid of one ...
# 13  xref https://github.com/pandas-dev/pandas/pull...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  ### Pandas version checks\r\n\r\n- [X] I have ...
# 17  - [x] [Tests added and passed](https://pandas....
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  Save around 5-10 minutes on Azure\r\n\r\nWhy d...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  The console-based copy-paste-a-token flow has ...
# 24  #### Is your feature request related to a prob...
# 25  - [x] closes #46187 (Replace xxxx with the Git...
# 26  DataFrame `merge` has inconsistent behaviour d...
# 27  - [x] closes #46178 (Replace xxxx with the Git...
# 28  Tested the overloads with mypy and pyright:\r\...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#     performed_via_github_app draft  \
# 0                        NaN   NaN
# 1                        NaN   NaN
# 2                        NaN   NaN
# 3                        NaN   0.0
# 4                        NaN   0.0
# 5                        NaN   0.0
# 6                        NaN   0.0
# 7                        NaN   1.0
# 8                        NaN   0.0
# 9                        NaN   0.0
# 10                       NaN   0.0
# 11                       NaN   NaN
# 12                       NaN   0.0
# 13                       NaN   NaN
# 14                       NaN   NaN
# 15                       NaN   NaN
# 16                       NaN   NaN
# 17                       NaN   0.0
# 18                       NaN   NaN
# 19                       NaN   NaN
# 20                       NaN   1.0
# 21                       NaN   NaN
# 22                       NaN   NaN
# 23                       NaN   0.0
# 24                       NaN   NaN
# 25                       NaN   0.0
# 26                       NaN   NaN
# 27                       NaN   0.0
# 28                       NaN   0.0
# 29                       NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19                                                NaN
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 29 columns]

# %%
import requests

# %%
data = requests.get(url)
data
# Out:
# <Response [200]>

# %%
data1 = data.json()
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46353',
#   'id': 1167498221,
#   'node_id': 'I_kwDOAA0YD85Flpvt',
#   'number': 46353,
#   'title': 'DOC: Document that astype() for Series and Dataframe can accept a series of dtypes',
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-13T06:52:08Z',
#   'updated_at': '2022-03-13T06:52:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html\r\n\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.Series.astype.html\n\n### Documentation problem\n\nThe documentation for `DataFrame` states that `dtype` can be a `dict` mapping from column label to new type, or a scalar type. However, `dtype` can also be a `pd.Series` whose index contains a subset of the dataframe\'s labels (though perhaps in a different order) and whose values are dtypes. For example:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2]])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nIn case the frame has duplicate column labels, the index of the new series of dtypes may still be a subset of the column labels. However, it appears that the only way that the new series can have a non-unique index is if that index is exactly equal to the dataframe\'s `columns`. For example, this works:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nbut giving the series an index with all the columns in a different order\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nraises `ValueError: cannot reindex on an axis with duplicate labels`:\r\n\r\n<details>\r\n<summary>Show stack trace</summary>\r\n\r\n```\r\nValueError                                Traceback (most recent call last)\r\nInput In [14], in <module>\r\n      3 df = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\n      4 print(f"original dtypes:\\n{df.dtypes}")\r\n----> 5 new_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\n      6 print(f"new dtypes:\\n{new_df.dtypes}")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)\r\n   5895 from pandas import Series\r\n   5897 dtype_ser = Series(dtype, dtype=object)\r\n-> 5898 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)\r\n   5900 results = []\r\n   5901 for i, (col_name, col) in enumerate(self.items()):\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)\r\n   4668         raise TypeError(\r\n   4669             "\'index\' passed as both positional and keyword argument"\r\n   4670         )\r\n   4671     kwargs.update({"index": index})\r\n-> 4672 return super().reindex(**kwargs)\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4974, in NDFrame.reindex(self, *args, **kwargs)\r\n   4971     return self._reindex_multi(axes, copy, fill_value)\r\n   4973 # perform the reindex on the axes\r\n-> 4974 return self._reindex_axes(\r\n   4975     axes, level, limit, tolerance, method, fill_value, copy\r\n   4976 ).__finalize__(self, method="reindex")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4994, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)\r\n   4989 new_index, indexer = ax.reindex(\r\n   4990     labels, level=level, limit=limit, tolerance=tolerance, method=method\r\n   4991 )\r\n   4993 axis = self._get_axis_number(a)\r\n-> 4994 obj = obj._reindex_with_indexers(\r\n   4995     {axis: [new_index, indexer]},\r\n   4996     fi ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46352',
#   'id': 1167470919,
#   'node_id': 'I_kwDOAA0YD85FljFH',
#   'number': 46352,
#   'title': 'ENH: read_excel should assume engine when passing openpyxl.Workbook object',
#   'user': {'login': 'scotscotmcc',
#    'id': 83373712,
#    'node_id': 'MDQ6VXNlcjgzMzczNzEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83373712?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scotscotmcc',
#    'html_url': 'https://github.com/scotscotmcc',
#    'followers_url': 'https://api.github.com/users/scotscotmcc/followers',
#    'following_url': 'https://api.github.com/users/scotscotmcc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/scotscotmcc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/scotscotmcc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/scotscotmcc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/scotscotmcc/orgs',
#    'repos_url': 'https://api.github.com/users/scotscotmcc/repos',
#    'events_url': 'https://api.github.com/users/scotscotmcc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/scotscotmcc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-13T03:51:41Z',
#   'updated_at': '2022-03-13T03:51:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nWhen your `io` parameter for `pd.read_excel()` is an openpyxl.Workbook object, the function should assume that `engine=\'openpyxl\'`. Right now, if you don\'t specify the engine, you will get a `ValueError: Invalid file path or buffer object type: <class \'openpyxl.workbook.workbook.Workbook\'>`. However, if you explicitly pass the engine, it will load fine.\r\n\r\nIt seems like passing in the specific workbook object would only ever be done if you want it to read it with that engine, so we should just assume that engine.\r\n\r\nThe current documentation for `read_excel()` specifies that you can use an `xlrd.Book`, and that works fine without an explicit `engine`. It doesn\'t say that you can use an `openpyxl.Workbook` at all, but it does work when you declare the `engine`.\r\n\r\nThis has come up as a small inconvenience for me a few times. I have a script where I am pulling some data out of Excel that is not a table at all, and so I\'m using opening it as an `openpyxl.Workbook` and using some of the tools from that library, and then also want to pull another table using pandas. I want to do this without opening the workbook multiple times, so I use the same workbook to pass into `pd.read_excel()`. It then throws and error and I say "Oh yea, I need the engine."\r\n\r\n#### Describe the solution you\'d like\r\n\r\nOne should be able to do\r\n\r\n```python\r\nimport pandas as pd\r\nimport openpyxl\r\n\r\nwb = openpyxl.load_Workbook(filepath,...)\r\ndf = pd.read_excel(wb,...) # and not include engine\r\nwb.close()\r\n```\r\n\r\nThis should work the same as just `df = pd.read_excel(filepath,...)`\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\nAlternatives seem to be (1) explicitly pass `engine` or (2) don\'t use `openpyxl.Workbook` objects.\r\n\r\n#### Potential Solution\r\n\r\n```python\r\n# starting line 1466 or so of pandas.io.excel_base.py\r\nif isinstance(path_or_buffer, openpyxl.Workbook):\r\n    if engine == "openpyxl":\r\n        pass\r\n    elif engine is None:\r\n        engine = "openpyxl"\r\n    else:\r\n        raise ValueError(f"Excel object is openpyxl.Workbook, but engine is {engine}")\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46351',
#   'id': 1167422549,
#   'node_id': 'I_kwDOAA0YD85FlXRV',
#   'number': 46351,
#   'title': 'Question: why use Azure for CI?',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-03-12T22:58:55Z',
#   'updated_at': '2022-03-12T23:13:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'What’s the reason that pandas uses GHA alongside Azure? What does Azure provide that GHA doesn’t?',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46350',
#   'id': 1167422110,
#   'node_id': 'PR_kwDOAA0YD840WVgz',
#   'number': 46350,
#   'title': 'TST: xfail(strict=False) flaky hashtable test on ARM',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T22:56:27Z',
#   'updated_at': '2022-03-13T00:56:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46350',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46350',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46350.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46350.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nExample: https://app.circleci.com/pipelines/github/pandas-dev/pandas/8766/workflows/4a9ce4f4-0e1c-49aa-b035-ffcb6334be45/jobs/39610\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46349',
#   'id': 1167417912,
#   'node_id': 'PR_kwDOAA0YD840WUvE',
#   'number': 46349,
#   'title': 'PERF: Index[StringArray]',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-03-12T22:32:11Z',
#   'updated_at': '2022-03-12T22:40:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46349',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46349',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46349.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46349.patch',
#    'merged_at': None},
#   'body': '- [x] closes #45652 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nbandaid until we can improve perf in ExtensionEngine',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46348',
#   'id': 1167412829,
#   'node_id': 'PR_kwDOAA0YD840WT3e',
#   'number': 46348,
#   'title': 'Series.map Performance Improvement When Using Dictionaries',
#   'user': {'login': 'ryansdowning',
#    'id': 20880292,
#    'node_id': 'MDQ6VXNlcjIwODgwMjky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20880292?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryansdowning',
#    'html_url': 'https://github.com/ryansdowning',
#    'followers_url': 'https://api.github.com/users/ryansdowning/followers',
#    'following_url': 'https://api.github.com/users/ryansdowning/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ryansdowning/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ryansdowning/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ryansdowning/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ryansdowning/orgs',
#    'repos_url': 'https://api.github.com/users/ryansdowning/repos',
#    'events_url': 'https://api.github.com/users/ryansdowning/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ryansdowning/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T22:05:25Z',
#   'updated_at': '2022-03-12T23:36:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46348',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46348',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46348.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46348.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46248\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nHello, first time contributing to pandas so if I did something wrong, please let me know!\r\n\r\nIn the discussion for #46248 I proposed a very simple solution using `collections.defaultdict`. However, after implementing the change, I found a performance improvement of 10x, but that was still a far stretch from the 1000-10000x improvement I was expecting. After more testing I found that the majority of the time was now being spent by copying the dictionary to the `defaultdict`. To avoid unnecessarily copying the dictionary\'s data, I use `dict.get` with a default of `np.nan` for dictionaries that do not implement the `__missing__` method ~~added `ReadOnlyNanDefaultDict` which gives us the behavior of `defaultdict(lambda: np.nan, dictionary_object)` without copying the data. As given by the name, it is also read only since that is all that is needed by `IndexOpsMixin._map_values`.~~  With this change, I see the huge performance boost of 1000-10000x.\r\n\r\nThis is a slight deviation from the `defaultdict` solution proposed in the issue, but it performs much better and behaves in the same way.\r\n\r\nLastly, I tried to add type hints for `IndexOpsMixin._map_values` but could not find the proper way of typing `Series` without causing a circular import. Is `"Series"` the way to go, or is there something better?',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46347',
#   'id': 1167404425,
#   'node_id': 'PR_kwDOAA0YD840WSZR',
#   'number': 46347,
#   'title': 'Fix snappy version',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-13T00:20:47Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-03-12T21:28:08Z',
#   'updated_at': '2022-03-13T00:23:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46347',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46347',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46347.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46347.patch',
#    'merged_at': None},
#   'body': 'Fix for https://github.com/pandas-dev/pandas/pull/46260\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#   'id': 1167386303,
#   'node_id': 'PR_kwDOAA0YD840WO50',
#   'number': 46346,
#   'title': 'WIP Use provision-with-micromamba',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T20:11:26Z',
#   'updated_at': '2022-03-12T21:42:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46346',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46346.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46346.patch',
#    'merged_at': None},
#   'body': 'Based on #45701\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#   'id': 1167366731,
#   'node_id': 'PR_kwDOAA0YD840WLMs',
#   'number': 46343,
#   'title': 'TYP: Add typing for pd.to_timedelta, fix Timedelta operator return types',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T18:43:38Z',
#   'updated_at': '2022-03-13T00:05:22Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46343',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46343.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46343.patch',
#    'merged_at': None},
#   'body': 'Add typing for pd.to_timedelta\r\nChange operators on `Timedelta` to return `Timedelta` rather than `timedelta`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#   'id': 1167331327,
#   'node_id': 'PR_kwDOAA0YD840WEz_',
#   'number': 46342,
#   'title': 'Bug fix -  groupby sum removed columns',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T16:20:35Z',
#   'updated_at': '2022-03-13T08:04:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46342',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46342.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46342.patch',
#    'merged_at': None},
#   'body': '- [x] closes #44132 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#   'id': 1167329989,
#   'node_id': 'PR_kwDOAA0YD840WEmO',
#   'number': 46341,
#   'title': 'PERF: use bisect_right_i8 in vectorized',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-13T00:20:47Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-03-12T16:15:36Z',
#   'updated_at': '2022-03-13T01:27:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46341',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46341.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46341.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46339',
#   'id': 1167181077,
#   'node_id': 'I_kwDOAA0YD85FkcUV',
#   'number': 46339,
#   'title': 'PyCon US 2022',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2187005593,
#     'node_id': 'MDU6TGFiZWwyMTg3MDA1NTkz',
# ...
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T13:42:15Z',
#   'updated_at': '2022-03-10T13:42:15Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "DataFrame `merge` has inconsistent behaviour depending on whether joining using the index or using columns. This means the user might experience unexpected results when using the `merge` method.\r\n\r\nFor a minimal example, consider that the following:\r\n\r\n```python\r\nimport pandas as pd\r\ndf_a = pd.DataFrame({'a': 1}, index=[1])\r\ndf_b = pd.DataFrame({'c': 1}, index=['1'])\r\ndf_c = df_a.merge(df_b, left_index=True, right_index=True)\r\n```\r\n\r\nwill result in `df_c` being an empty DataFrame with pandas `1.3.5`.\r\n\r\n_However_, attempting to perform a similar operation but using named columns:\r\n\r\n```python\r\nimport pandas as pd\r\ndf_a = pd.DataFrame({'a': 1, 'index': '1'}, index=[1])\r\ndf_b = pd.DataFrame({'index': 1, 'c': 1}, index=[1])\r\ndf_c = df_a.merge(df_b, left_on='index', right_on='index')\r\n```\r\n\r\nwill produce the appropriate `ValueError` (since the dtypes of the target columns do not match).\r\n\r\n**Desired Behaviour:**\r\nIt would be helpful to issue either some type of warning or a `ValueError` (consistent with the case using named columns) when attempting to merge on an index/indices with different dtypes.\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46305/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46305/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46304',
#   'id': 1165164366,
#   'node_id': 'PR_kwDOAA0YD840PCL-',
#   'number': 46304,
#   'title': 'BUG: merge raising for Int64 and int64 dtype with missing values',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T12:31:22Z',
#   'updated_at': '2022-03-10T19:40:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46304',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46304',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46304.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46304.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46178 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46300',
#   'id': 1164717212,
#   'node_id': 'PR_kwDOAA0YD840Nj7j',
#   'number': 46300,
#   'title': 'TYP: sort_index',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T03:50:51Z',
#   'updated_at': '2022-03-13T12:28:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46300',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46300',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46300.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46300.patch',
#    'merged_at': None},
#   'body': 'Tested the overloads with mypy and pyright:\r\n\r\n```py\r\nimport pandas as pd\r\n\r\ndef bool_() -> bool:\r\n    ...\r\n\r\nframe = pd.DataFrame()\r\nreveal_type(frame.sort_index()) # DataFrame\r\nreveal_type(frame.sort_index(inplace=True)) # None\r\nreveal_type(frame.sort_index(inplace=False)) # DataFrame\r\nreveal_type(frame.sort_index(inplace=bool_())) # DataFrame | None\r\n\r\nseries = pd.Series()\r\nreveal_type(series.sort_index()) # Series\r\nreveal_type(series.sort_index(inplace=True)) # None\r\nreveal_type(series.sort_index(inplace=False)) # Series\r\nreveal_type(series.sort_index(inplace=bool_())) # Series | None\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46298',
#   'id': 1164620575,
#   'node_id': 'I_kwDOAA0YD85FarMf',
#   'number': 46298,
#   'title': 'BUG:  "data type \'Int64\' not understood"',
#   'user': {'login': 'TouriM',
#    'id': 726951,
#    'node_id': 'MDQ6VXNlcjcyNjk1MQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/726951?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TouriM',
#    'html_url': 'https://github.com/TouriM',
#    'followers_url': 'https://api.github.com/users/TouriM/followers',
#    'following_url': 'https://api.github.com/users/TouriM/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TouriM/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TouriM/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TouriM/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TouriM/orgs',
#    'repos_url': 'https://api.github.com/users/TouriM/repos',
#    'events_url': 'https://api.github.com/users/TouriM/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TouriM/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-10T01:03:36Z',
#   'updated_at': '2022-03-10T09:32:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndf = pd.DataFrame(data={"test": [20.222, 1.01]})\r\ndf[\'test\'][1].round(0).astype("Int64")\r\n\r\n<details>\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\nInput In [3], in <cell line: 3>()\r\n      1 import pandas as pd\r\n      2 df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n----> 3 df[\'test\'][1].round(0).astype("Int64")\r\n\r\nTypeError: data type \'Int64\' not understood\r\n</details>\n```\n\n\n### Issue Description\n\nWhile investigating another problem with Int64, I ran into this unexpected behaviour. \r\n\r\nCasting to int64 works:\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1].round(0).astype("int64")\r\n1\r\n```\r\n\r\n\r\nSlicing works:\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1:2].round(0).astype("Int64")\r\n1    1\r\nName: test, dtype: Int64\r\n```\r\n\r\n\r\n\r\ndf[\'test\'].round(0).astype("Int64")\n\n### Expected Behavior\n\nI would expect, that Int64 would return "1" in the \r\n\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1].round(0).astype("Int64")\r\n 1   # Would be the result I expect\r\n```\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.3.0\r\nVersion          : Darwin Kernel Version 21.3.0: Wed Jan  5 21:37:58 PST 2022; root:xnu-8019.80.24~20/RELEASE_ARM64_T8101\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 58.1.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.3\r\nIPython          : 8.1.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : 1.4.31\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/timeline',
#   'performed_via_github_app': None}]

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/46353  1167498221
# 1   https://github.com/pandas-dev/pandas/issues/46352  1167470919
# 2   https://github.com/pandas-dev/pandas/issues/46351  1167422549
# 3     https://github.com/pandas-dev/pandas/pull/46350  1167422110
# 4     https://github.com/pandas-dev/pandas/pull/46349  1167417912
# 5     https://github.com/pandas-dev/pandas/pull/46348  1167412829
# 6     https://github.com/pandas-dev/pandas/pull/46347  1167404425
# 7     https://github.com/pandas-dev/pandas/pull/46346  1167386303
# 8     https://github.com/pandas-dev/pandas/pull/46343  1167366731
# 9     https://github.com/pandas-dev/pandas/pull/46342  1167331327
# 10    https://github.com/pandas-dev/pandas/pull/46341  1167329989
# 11  https://github.com/pandas-dev/pandas/issues/46339  1167181077
# 12    https://github.com/pandas-dev/pandas/pull/46338  1167165103
# 13  https://github.com/pandas-dev/pandas/issues/46337  1167162310
# 14  https://github.com/pandas-dev/pandas/issues/46336  1167160890
# 15  https://github.com/pandas-dev/pandas/issues/46332  1166971186
# 16  https://github.com/pandas-dev/pandas/issues/46331  1166957820
# 17    https://github.com/pandas-dev/pandas/pull/46330  1166865454
# 18  https://github.com/pandas-dev/pandas/issues/46326  1166612234
# 19  https://github.com/pandas-dev/pandas/issues/46324  1166353036
# 20    https://github.com/pandas-dev/pandas/pull/46321  1166312846
# 21  https://github.com/pandas-dev/pandas/issues/46319  1166255061
# 22  https://github.com/pandas-dev/pandas/issues/46313  1165672382
# 23    https://github.com/pandas-dev/pandas/pull/46312  1165636565
# 24  https://github.com/pandas-dev/pandas/issues/46310  1165554305
# 25    https://github.com/pandas-dev/pandas/pull/46308  1165401382
# 26  https://github.com/pandas-dev/pandas/issues/46305  1165243629
# 27    https://github.com/pandas-dev/pandas/pull/46304  1165164366
# 28    https://github.com/pandas-dev/pandas/pull/46300  1164717212
# 29  https://github.com/pandas-dev/pandas/issues/46298  1164620575
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85Flpvt   46353
# 1    I_kwDOAA0YD85FljFH   46352
# 2    I_kwDOAA0YD85FlXRV   46351
# 3   PR_kwDOAA0YD840WVgz   46350
# 4   PR_kwDOAA0YD840WUvE   46349
# 5   PR_kwDOAA0YD840WT3e   46348
# 6   PR_kwDOAA0YD840WSZR   46347
# 7   PR_kwDOAA0YD840WO50   46346
# 8   PR_kwDOAA0YD840WLMs   46343
# 9   PR_kwDOAA0YD840WEz_   46342
# 10  PR_kwDOAA0YD840WEmO   46341
# 11   I_kwDOAA0YD85FkcUV   46339
# 12  PR_kwDOAA0YD840VmSV   46338
# 13   I_kwDOAA0YD85FkXvG   46337
# 14   I_kwDOAA0YD85FkXY6   46336
# 15   I_kwDOAA0YD85FjpEy   46332
# 16   I_kwDOAA0YD85Fjlz8   46331
# 17  PR_kwDOAA0YD840UmcA   46330
# 18   I_kwDOAA0YD85FiRcK   46326
# 19   I_kwDOAA0YD85FhSKM   46324
# 20  PR_kwDOAA0YD840SzrD   46321
# 21   I_kwDOAA0YD85Fg6PV   46319
# 22   I_kwDOAA0YD85Fer--   46313
# 23  PR_kwDOAA0YD840QmJ_   46312
# 24   I_kwDOAA0YD85FePKB   46310
# 25  PR_kwDOAA0YD840P1BQ   46308
# 26   I_kwDOAA0YD85FdDTt   46305
# 27  PR_kwDOAA0YD840PCL-   46304
# 28  PR_kwDOAA0YD840Nj7j   46300
# 29   I_kwDOAA0YD85FarMf   46298
#
#                                                 title  ...  \
# 0   DOC: Document that astype() for Series and Dat...  ...
# 1   ENH: read_excel should assume engine when pass...  ...
# 2                     Question: why use Azure for CI?  ...
# 3   TST: xfail(strict=False) flaky hashtable test ...  ...
# 4                            PERF: Index[StringArray]  ...
# 5   Series.map Performance Improvement When Using ...  ...
# 6                                  Fix snappy version  ...
# 7                   WIP Use provision-with-micromamba  ...
# 8   TYP: Add typing for pd.to_timedelta, fix Timed...  ...
# 9              Bug fix -  groupby sum removed columns  ...
# 10            PERF: use bisect_right_i8 in vectorized  ...
# 11                                      PyCon US 2022  ...
# 12             REF: de-duplicate hard-coded unit code  ...
# 13                   TYP: returning None for __init__  ...
# 14  BUG: dataframe.rename function shows no warnin...  ...
# 15  BUG: Binary operations with empty string array...  ...
# 16  BUG: the behavior of "date_range" function wit...  ...
# 17  REF/PERF: MultiIndex.get_locs to use boolean a...  ...
# 18  BUG: `isin` propagates nulls for DataFrame but...  ...
# 19  BUG: core.groupby.GroupBy.apply unexpected beh...  ...
# 20                     WIP Add ccache to Azure builds  ...
# 21  BUG: `UnicodeError` when using `Period.strftim...  ...
# 22  BUG: Categorical of booleans has object .categ...  ...
# 23         BUG: avoid OOB flow in read_gbq and to_gbq  ...
# 24      ENH: Add `subset` param to `add_(pre|suf)fix`  ...
# 25                    DOC: Add TextFileReader to docs  ...
# 26  ENH: merging using DataFrame index should rais...  ...
# 27  BUG: merge raising for Int64 and int64 dtype w...  ...
# 28                                    TYP: sort_index  ...
# 29           BUG:  "data type 'Int64' not understood"  ...
#
#               updated_at closed_at author_association  active_lock_reason  \
# 0   2022-03-13T06:52:08Z      None               NONE                None
# 1   2022-03-13T03:51:41Z      None               NONE                None
# 2   2022-03-12T23:13:37Z      None        CONTRIBUTOR                None
# 3   2022-03-13T00:56:30Z      None             MEMBER                None
# 4   2022-03-12T22:40:13Z      None             MEMBER                None
# 5   2022-03-12T23:36:30Z      None               NONE                None
# 6   2022-03-13T00:23:34Z      None        CONTRIBUTOR                None
# 7   2022-03-12T21:42:38Z      None        CONTRIBUTOR                None
# 8   2022-03-13T00:05:22Z      None        CONTRIBUTOR                None
# 9   2022-03-13T08:04:26Z      None        CONTRIBUTOR                None
# 10  2022-03-13T01:27:44Z      None             MEMBER                None
# 11  2022-03-12T05:00:28Z      None             MEMBER                None
# 12  2022-03-13T01:34:01Z      None             MEMBER                None
# 13  2022-03-12T18:37:12Z      None        CONTRIBUTOR                None
# 14  2022-03-12T14:48:33Z      None               NONE                None
# 15  2022-03-11T23:15:26Z      None               NONE                None
# 16  2022-03-13T07:51:43Z      None               NONE                None
# 17  2022-03-12T21:07:45Z      None             MEMBER                None
# 18  2022-03-11T16:53:06Z      None               NONE                None
# 19  2022-03-11T12:19:20Z      None               NONE                None
# 20  2022-03-12T19:10:13Z      None        CONTRIBUTOR                None
# 21  2022-03-11T10:51:46Z      None        CONTRIBUTOR                None
# 22  2022-03-11T12:32:13Z      None        CONTRIBUTOR                None
# 23  2022-03-11T01:30:39Z      None        CONTRIBUTOR                None
# 24  2022-03-11T00:46:10Z      None        CONTRIBUTOR                None
# 25  2022-03-11T23:48:13Z      None             MEMBER                None
# 26  2022-03-10T13:42:15Z      None               NONE                None
# 27  2022-03-10T19:40:21Z      None             MEMBER                None
# 28  2022-03-13T12:28:32Z      None        CONTRIBUTOR                None
# 29  2022-03-10T09:32:52Z      None               NONE                None
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   #### Is your feature request related to a prob...
# 2   What’s the reason that pandas uses GHA alongsi...
# 3   - [x] [Tests added and passed](https://pandas....
# 4   - [x] closes #45652 (Replace xxxx with the Git...
# 5   - [x] closes #46248\r\n- [ ] [Tests added and ...
# 6   Fix for https://github.com/pandas-dev/pandas/p...
# 7   Based on #45701\r\n\r\n- [ ] closes #xxxx (Rep...
# 8   Add typing for pd.to_timedelta\r\nChange opera...
# 9   - [x] closes #44132 \r\n- [ ] [Tests added and...
# 10  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 11  Do we have any plan for PyCon US 2022?\r\n\r\n...
# 12  I had hoped  to go further and get rid of one ...
# 13  xref https://github.com/pandas-dev/pandas/pull...
# 14  ### Pandas version checks\n\n- [X] I have chec...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  ### Pandas version checks\r\n\r\n- [X] I have ...
# 17  - [x] [Tests added and passed](https://pandas....
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  Save around 5-10 minutes on Azure\r\n\r\nWhy d...
# 21  ### Pandas version checks\n\n- [X] I have chec...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  The console-based copy-paste-a-token flow has ...
# 24  #### Is your feature request related to a prob...
# 25  - [x] closes #46187 (Replace xxxx with the Git...
# 26  DataFrame `merge` has inconsistent behaviour d...
# 27  - [x] closes #46178 (Replace xxxx with the Git...
# 28  Tested the overloads with mypy and pyright:\r\...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#     performed_via_github_app  draft  \
# 0                       None    NaN
# 1                       None    NaN
# 2                       None    NaN
# 3                       None  False
# 4                       None  False
# 5                       None  False
# 6                       None  False
# 7                       None   True
# 8                       None  False
# 9                       None  False
# 10                      None  False
# 11                      None    NaN
# 12                      None  False
# 13                      None    NaN
# 14                      None    NaN
# 15                      None    NaN
# 16                      None    NaN
# 17                      None  False
# 18                      None    NaN
# 19                      None    NaN
# 20                      None   True
# 21                      None    NaN
# 22                      None    NaN
# 23                      None  False
# 24                      None    NaN
# 25                      None  False
# 26                      None    NaN
# 27                      None  False
# 28                      None  False
# 29                      None    NaN
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19                                                NaN
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 29 columns]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/46353',
#  'id': 1167498221,
#  'node_id': 'I_kwDOAA0YD85Flpvt',
#  'number': 46353,
#  'title': 'DOC: Document that astype() for Series and Dataframe can accept a series of dtypes',
#  'user': {'login': 'mvashishtha',
#   'id': 10712109,
#   'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mvashishtha',
#   'html_url': 'https://github.com/mvashishtha',
#   'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#   'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#   'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#   'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 134699,
#    'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#    'name': 'Docs',
#    'color': '3465A4',
#    'default': False,
#    'description': None},
#   {'id': 1954720290,
#    'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#    'name': 'Needs Triage',
#    'color': '0052cc',
#    'default': False,
#    'description': 'Issue that has not been reviewed by a pandas team member'}],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2022-03-13T06:52:08Z',
#  'updated_at': '2022-03-13T06:52:08Z',
#  'closed_at': None,
#  'author_association': 'NONE',
#  'active_lock_reason': None,
#  'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html\r\n\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.Series.astype.html\n\n### Documentation problem\n\nThe documentation for `DataFrame` states that `dtype` can be a `dict` mapping from column label to new type, or a scalar type. However, `dtype` can also be a `pd.Series` whose index contains a subset of the dataframe\'s labels (though perhaps in a different order) and whose values are dtypes. For example:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2]])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nIn case the frame has duplicate column labels, the index of the new series of dtypes may still be a subset of the column labels. However, it appears that the only way that the new series can have a non-unique index is if that index is exactly equal to the dataframe\'s `columns`. For example, this works:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nbut giving the series an index with all the columns in a different order\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nraises `ValueError: cannot reindex on an axis with duplicate labels`:\r\n\r\n<details>\r\n<summary>Show stack trace</summary>\r\n\r\n```\r\nValueError                                Traceback (most recent call last)\r\nInput In [14], in <module>\r\n      3 df = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\n      4 print(f"original dtypes:\\n{df.dtypes}")\r\n----> 5 new_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\n      6 print(f"new dtypes:\\n{new_df.dtypes}")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)\r\n   5895 from pandas import Series\r\n   5897 dtype_ser = Series(dtype, dtype=object)\r\n-> 5898 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)\r\n   5900 results = []\r\n   5901 for i, (col_name, col) in enumerate(self.items()):\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)\r\n   4668         raise TypeError(\r\n   4669             "\'index\' passed as both positional and keyword argument"\r\n   4670         )\r\n   4671     kwargs.update({"index": index})\r\n-> 4672 return super().reindex(**kwargs)\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4974, in NDFrame.reindex(self, *args, **kwargs)\r\n   4971     return self._reindex_multi(axes, copy, fill_value)\r\n   4973 # perform the reindex on the axes\r\n-> 4974 return self._reindex_axes(\r\n   4975     axes, level, limit, tolerance, method, fill_value, copy\r\n   4976 ).__finalize__(self, method="reindex")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4994, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)\r\n   4989 new_index, indexer = ax.reindex(\r\n   4990     labels, level=level, limit=limit, tolerance=tolerance, method=method\r\n   4991 )\r\n   4993 axis = self._get_axis_number(a)\r\n-> 4994 obj = obj._reindex_with_indexers(\r\n   4995     {axis: [new_index, indexer]},\r\n   4996     fil ...
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/timeline',
#  'performed_via_github_app': None}

# %%
for key,value in data1[0].items():
    if key == 'id':
        print(value)
# Out:
# 1167498221

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 10712109
# 83373712
# 175722
# 10647082
# 8078968
# 20880292
# 175722
# 175722
# 15113894
# 36619387
# 8078968
# 7614606
# 8078968
# 953992
# 39624018
# 1538165
# 19217750
# 8519523
# 53796099
# 41342515
# 175722
# 3236794
# 8238804
# 247555
# 30958850
# 61934744
# 73829711
# 61934744
# 6618166
# 726951

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46353',
#   'id': 1167498221,
#   'node_id': 'I_kwDOAA0YD85Flpvt',
#   'number': 46353,
#   'title': 'DOC: Document that astype() for Series and Dataframe can accept a series of dtypes',
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-13T06:52:08Z',
#   'updated_at': '2022-03-13T06:52:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html\r\n\r\nhttps://pandas.pydata.org/docs/reference/api/pandas.Series.astype.html\n\n### Documentation problem\n\nThe documentation for `DataFrame` states that `dtype` can be a `dict` mapping from column label to new type, or a scalar type. However, `dtype` can also be a `pd.Series` whose index contains a subset of the dataframe\'s labels (though perhaps in a different order) and whose values are dtypes. For example:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2]])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nIn case the frame has duplicate column labels, the index of the new series of dtypes may still be a subset of the column labels. However, it appears that the only way that the new series can have a non-unique index is if that index is exactly equal to the dataframe\'s `columns`. For example, this works:\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nbut giving the series an index with all the columns in a different order\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndf = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\nprint(f"original dtypes:\\n{df.dtypes}")\r\nnew_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\nprint(f"new dtypes:\\n{new_df.dtypes}")\r\n```\r\n\r\nraises `ValueError: cannot reindex on an axis with duplicate labels`:\r\n\r\n<details>\r\n<summary>Show stack trace</summary>\r\n\r\n```\r\nValueError                                Traceback (most recent call last)\r\nInput In [14], in <module>\r\n      3 df = pd.DataFrame([[1, 2, 3]], columns=[0, 0, 1])\r\n      4 print(f"original dtypes:\\n{df.dtypes}")\r\n----> 5 new_df = df.astype(pd.Series(["string", "object", "float"], index=df.columns[::-1]))\r\n      6 print(f"new dtypes:\\n{new_df.dtypes}")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)\r\n   5895 from pandas import Series\r\n   5897 dtype_ser = Series(dtype, dtype=object)\r\n-> 5898 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)\r\n   5900 results = []\r\n   5901 for i, (col_name, col) in enumerate(self.items()):\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)\r\n   4668         raise TypeError(\r\n   4669             "\'index\' passed as both positional and keyword argument"\r\n   4670         )\r\n   4671     kwargs.update({"index": index})\r\n-> 4672 return super().reindex(**kwargs)\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4974, in NDFrame.reindex(self, *args, **kwargs)\r\n   4971     return self._reindex_multi(axes, copy, fill_value)\r\n   4973 # perform the reindex on the axes\r\n-> 4974 return self._reindex_axes(\r\n   4975     axes, level, limit, tolerance, method, fill_value, copy\r\n   4976 ).__finalize__(self, method="reindex")\r\n\r\nFile /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:4994, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)\r\n   4989 new_index, indexer = ax.reindex(\r\n   4990     labels, level=level, limit=limit, tolerance=tolerance, method=method\r\n   4991 )\r\n   4993 axis = self._get_axis_number(a)\r\n-> 4994 obj = obj._reindex_with_indexers(\r\n   4995     {axis: [new_index, indexer]},\r\n   4996     fi ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46353/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46352',
#   'id': 1167470919,
#   'node_id': 'I_kwDOAA0YD85FljFH',
#   'number': 46352,
#   'title': 'ENH: read_excel should assume engine when passing openpyxl.Workbook object',
#   'user': {'login': 'scotscotmcc',
#    'id': 83373712,
#    'node_id': 'MDQ6VXNlcjgzMzczNzEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83373712?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scotscotmcc',
#    'html_url': 'https://github.com/scotscotmcc',
#    'followers_url': 'https://api.github.com/users/scotscotmcc/followers',
#    'following_url': 'https://api.github.com/users/scotscotmcc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/scotscotmcc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/scotscotmcc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/scotscotmcc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/scotscotmcc/orgs',
#    'repos_url': 'https://api.github.com/users/scotscotmcc/repos',
#    'events_url': 'https://api.github.com/users/scotscotmcc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/scotscotmcc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-13T03:51:41Z',
#   'updated_at': '2022-03-13T03:51:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nWhen your `io` parameter for `pd.read_excel()` is an openpyxl.Workbook object, the function should assume that `engine=\'openpyxl\'`. Right now, if you don\'t specify the engine, you will get a `ValueError: Invalid file path or buffer object type: <class \'openpyxl.workbook.workbook.Workbook\'>`. However, if you explicitly pass the engine, it will load fine.\r\n\r\nIt seems like passing in the specific workbook object would only ever be done if you want it to read it with that engine, so we should just assume that engine.\r\n\r\nThe current documentation for `read_excel()` specifies that you can use an `xlrd.Book`, and that works fine without an explicit `engine`. It doesn\'t say that you can use an `openpyxl.Workbook` at all, but it does work when you declare the `engine`.\r\n\r\nThis has come up as a small inconvenience for me a few times. I have a script where I am pulling some data out of Excel that is not a table at all, and so I\'m using opening it as an `openpyxl.Workbook` and using some of the tools from that library, and then also want to pull another table using pandas. I want to do this without opening the workbook multiple times, so I use the same workbook to pass into `pd.read_excel()`. It then throws and error and I say "Oh yea, I need the engine."\r\n\r\n#### Describe the solution you\'d like\r\n\r\nOne should be able to do\r\n\r\n```python\r\nimport pandas as pd\r\nimport openpyxl\r\n\r\nwb = openpyxl.load_Workbook(filepath,...)\r\ndf = pd.read_excel(wb,...) # and not include engine\r\nwb.close()\r\n```\r\n\r\nThis should work the same as just `df = pd.read_excel(filepath,...)`\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\nAlternatives seem to be (1) explicitly pass `engine` or (2) don\'t use `openpyxl.Workbook` objects.\r\n\r\n#### Potential Solution\r\n\r\n```python\r\n# starting line 1466 or so of pandas.io.excel_base.py\r\nif isinstance(path_or_buffer, openpyxl.Workbook):\r\n    if engine == "openpyxl":\r\n        pass\r\n    elif engine is None:\r\n        engine = "openpyxl"\r\n    else:\r\n        raise ValueError(f"Excel object is openpyxl.Workbook, but engine is {engine}")\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46352/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46351',
#   'id': 1167422549,
#   'node_id': 'I_kwDOAA0YD85FlXRV',
#   'number': 46351,
#   'title': 'Question: why use Azure for CI?',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-03-12T22:58:55Z',
#   'updated_at': '2022-03-12T23:13:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'What’s the reason that pandas uses GHA alongside Azure? What does Azure provide that GHA doesn’t?',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46351/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46350',
#   'id': 1167422110,
#   'node_id': 'PR_kwDOAA0YD840WVgz',
#   'number': 46350,
#   'title': 'TST: xfail(strict=False) flaky hashtable test on ARM',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 2628846204,
#     'node_id': 'MDU6TGFiZWwyNjI4ODQ2MjA0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ARM',
#     'name': 'ARM',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': 'aarch64 architecture'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T22:56:27Z',
#   'updated_at': '2022-03-13T00:56:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46350',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46350',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46350.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46350.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nExample: https://app.circleci.com/pipelines/github/pandas-dev/pandas/8766/workflows/4a9ce4f4-0e1c-49aa-b035-ffcb6334be45/jobs/39610\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46350/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46349',
#   'id': 1167417912,
#   'node_id': 'PR_kwDOAA0YD840WUvE',
#   'number': 46349,
#   'title': 'PERF: Index[StringArray]',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-03-12T22:32:11Z',
#   'updated_at': '2022-03-12T22:40:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46349',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46349',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46349.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46349.patch',
#    'merged_at': None},
#   'body': '- [x] closes #45652 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nbandaid until we can improve perf in ExtensionEngine',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46349/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46348',
#   'id': 1167412829,
#   'node_id': 'PR_kwDOAA0YD840WT3e',
#   'number': 46348,
#   'title': 'Series.map Performance Improvement When Using Dictionaries',
#   'user': {'login': 'ryansdowning',
#    'id': 20880292,
#    'node_id': 'MDQ6VXNlcjIwODgwMjky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20880292?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryansdowning',
#    'html_url': 'https://github.com/ryansdowning',
#    'followers_url': 'https://api.github.com/users/ryansdowning/followers',
#    'following_url': 'https://api.github.com/users/ryansdowning/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ryansdowning/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ryansdowning/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ryansdowning/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ryansdowning/orgs',
#    'repos_url': 'https://api.github.com/users/ryansdowning/repos',
#    'events_url': 'https://api.github.com/users/ryansdowning/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ryansdowning/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T22:05:25Z',
#   'updated_at': '2022-03-12T23:36:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46348',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46348',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46348.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46348.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46248\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nHello, first time contributing to pandas so if I did something wrong, please let me know!\r\n\r\nIn the discussion for #46248 I proposed a very simple solution using `collections.defaultdict`. However, after implementing the change, I found a performance improvement of 10x, but that was still a far stretch from the 1000-10000x improvement I was expecting. After more testing I found that the majority of the time was now being spent by copying the dictionary to the `defaultdict`. To avoid unnecessarily copying the dictionary\'s data, I use `dict.get` with a default of `np.nan` for dictionaries that do not implement the `__missing__` method ~~added `ReadOnlyNanDefaultDict` which gives us the behavior of `defaultdict(lambda: np.nan, dictionary_object)` without copying the data. As given by the name, it is also read only since that is all that is needed by `IndexOpsMixin._map_values`.~~  With this change, I see the huge performance boost of 1000-10000x.\r\n\r\nThis is a slight deviation from the `defaultdict` solution proposed in the issue, but it performs much better and behaves in the same way.\r\n\r\nLastly, I tried to add type hints for `IndexOpsMixin._map_values` but could not find the proper way of typing `Series` without causing a circular import. Is `"Series"` the way to go, or is there something better?',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46348/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46347',
#   'id': 1167404425,
#   'node_id': 'PR_kwDOAA0YD840WSZR',
#   'number': 46347,
#   'title': 'Fix snappy version',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-13T00:20:47Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-03-12T21:28:08Z',
#   'updated_at': '2022-03-13T00:23:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46347',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46347',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46347.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46347.patch',
#    'merged_at': None},
#   'body': 'Fix for https://github.com/pandas-dev/pandas/pull/46260\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46347/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#   'id': 1167386303,
#   'node_id': 'PR_kwDOAA0YD840WO50',
#   'number': 46346,
#   'title': 'WIP Use provision-with-micromamba',
#   'user': {'login': 'jonashaag',
#    'id': 175722,
#    'node_id': 'MDQ6VXNlcjE3NTcyMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonashaag',
#    'html_url': 'https://github.com/jonashaag',
#    'followers_url': 'https://api.github.com/users/jonashaag/followers',
#    'following_url': 'https://api.github.com/users/jonashaag/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonashaag/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonashaag/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonashaag/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonashaag/orgs',
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T20:11:26Z',
#   'updated_at': '2022-03-12T21:42:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46346',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46346.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46346.patch',
#    'merged_at': None},
#   'body': 'Based on #45701\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#   'id': 1167366731,
#   'node_id': 'PR_kwDOAA0YD840WLMs',
#   'number': 46343,
#   'title': 'TYP: Add typing for pd.to_timedelta, fix Timedelta operator return types',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T18:43:38Z',
#   'updated_at': '2022-03-13T00:05:22Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46343',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46343.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46343.patch',
#    'merged_at': None},
#   'body': 'Add typing for pd.to_timedelta\r\nChange operators on `Timedelta` to return `Timedelta` rather than `timedelta`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#   'id': 1167331327,
#   'node_id': 'PR_kwDOAA0YD840WEz_',
#   'number': 46342,
#   'title': 'Bug fix -  groupby sum removed columns',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T16:20:35Z',
#   'updated_at': '2022-03-13T08:04:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46342',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46342.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46342.patch',
#    'merged_at': None},
#   'body': '- [x] closes #44132 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#   'id': 1167329989,
#   'node_id': 'PR_kwDOAA0YD840WEmO',
#   'number': 46341,
#   'title': 'PERF: use bisect_right_i8 in vectorized',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-13T00:20:47Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-03-12T16:15:36Z',
#   'updated_at': '2022-03-13T01:27:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46341',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46341.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46341.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46339',
#   'id': 1167181077,
#   'node_id': 'I_kwDOAA0YD85FkcUV',
#   'number': 46339,
#   'title': 'PyCon US 2022',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2187005593,
#     'node_id': 'MDU6TGFiZWwyMTg3MDA1NTkz',
# ...
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T13:42:15Z',
#   'updated_at': '2022-03-10T13:42:15Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "DataFrame `merge` has inconsistent behaviour depending on whether joining using the index or using columns. This means the user might experience unexpected results when using the `merge` method.\r\n\r\nFor a minimal example, consider that the following:\r\n\r\n```python\r\nimport pandas as pd\r\ndf_a = pd.DataFrame({'a': 1}, index=[1])\r\ndf_b = pd.DataFrame({'c': 1}, index=['1'])\r\ndf_c = df_a.merge(df_b, left_index=True, right_index=True)\r\n```\r\n\r\nwill result in `df_c` being an empty DataFrame with pandas `1.3.5`.\r\n\r\n_However_, attempting to perform a similar operation but using named columns:\r\n\r\n```python\r\nimport pandas as pd\r\ndf_a = pd.DataFrame({'a': 1, 'index': '1'}, index=[1])\r\ndf_b = pd.DataFrame({'index': 1, 'c': 1}, index=[1])\r\ndf_c = df_a.merge(df_b, left_on='index', right_on='index')\r\n```\r\n\r\nwill produce the appropriate `ValueError` (since the dtypes of the target columns do not match).\r\n\r\n**Desired Behaviour:**\r\nIt would be helpful to issue either some type of warning or a `ValueError` (consistent with the case using named columns) when attempting to merge on an index/indices with different dtypes.\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46305/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46305/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46304',
#   'id': 1165164366,
#   'node_id': 'PR_kwDOAA0YD840PCL-',
#   'number': 46304,
#   'title': 'BUG: merge raising for Int64 and int64 dtype with missing values',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T12:31:22Z',
#   'updated_at': '2022-03-10T19:40:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46304',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46304',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46304.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46304.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46178 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46304/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46300',
#   'id': 1164717212,
#   'node_id': 'PR_kwDOAA0YD840Nj7j',
#   'number': 46300,
#   'title': 'TYP: sort_index',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-10T03:50:51Z',
#   'updated_at': '2022-03-13T12:28:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46300',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46300',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46300.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46300.patch',
#    'merged_at': None},
#   'body': 'Tested the overloads with mypy and pyright:\r\n\r\n```py\r\nimport pandas as pd\r\n\r\ndef bool_() -> bool:\r\n    ...\r\n\r\nframe = pd.DataFrame()\r\nreveal_type(frame.sort_index()) # DataFrame\r\nreveal_type(frame.sort_index(inplace=True)) # None\r\nreveal_type(frame.sort_index(inplace=False)) # DataFrame\r\nreveal_type(frame.sort_index(inplace=bool_())) # DataFrame | None\r\n\r\nseries = pd.Series()\r\nreveal_type(series.sort_index()) # Series\r\nreveal_type(series.sort_index(inplace=True)) # None\r\nreveal_type(series.sort_index(inplace=False)) # Series\r\nreveal_type(series.sort_index(inplace=bool_())) # Series | None\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46300/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46298',
#   'id': 1164620575,
#   'node_id': 'I_kwDOAA0YD85FarMf',
#   'number': 46298,
#   'title': 'BUG:  "data type \'Int64\' not understood"',
#   'user': {'login': 'TouriM',
#    'id': 726951,
#    'node_id': 'MDQ6VXNlcjcyNjk1MQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/726951?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TouriM',
#    'html_url': 'https://github.com/TouriM',
#    'followers_url': 'https://api.github.com/users/TouriM/followers',
#    'following_url': 'https://api.github.com/users/TouriM/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TouriM/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TouriM/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TouriM/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TouriM/orgs',
#    'repos_url': 'https://api.github.com/users/TouriM/repos',
#    'events_url': 'https://api.github.com/users/TouriM/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TouriM/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 2365504893,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0ODkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Closing%20Candidate',
#     'name': 'Closing Candidate',
#     'color': 'be21f2',
#     'default': False,
#     'description': 'May be closeable, needs more eyeballs'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-10T01:03:36Z',
#   'updated_at': '2022-03-10T09:32:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndf = pd.DataFrame(data={"test": [20.222, 1.01]})\r\ndf[\'test\'][1].round(0).astype("Int64")\r\n\r\n<details>\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\nInput In [3], in <cell line: 3>()\r\n      1 import pandas as pd\r\n      2 df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n----> 3 df[\'test\'][1].round(0).astype("Int64")\r\n\r\nTypeError: data type \'Int64\' not understood\r\n</details>\n```\n\n\n### Issue Description\n\nWhile investigating another problem with Int64, I ran into this unexpected behaviour. \r\n\r\nCasting to int64 works:\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1].round(0).astype("int64")\r\n1\r\n```\r\n\r\n\r\nSlicing works:\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1:2].round(0).astype("Int64")\r\n1    1\r\nName: test, dtype: Int64\r\n```\r\n\r\n\r\n\r\ndf[\'test\'].round(0).astype("Int64")\n\n### Expected Behavior\n\nI would expect, that Int64 would return "1" in the \r\n\r\n```python\r\n>>> import pandas as pd\r\n>>> df = pd.DataFrame(data={"test": [20.222, 1.01]})\r\n>>> df[\'test\'][1].round(0).astype("Int64")\r\n 1   # Would be the result I expect\r\n```\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.3.0\r\nVersion          : Darwin Kernel Version 21.3.0: Wed Jan  5 21:37:58 PST 2022; root:xnu-8019.80.24~20/RELEASE_ARM64_T8101\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 58.1.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.3\r\nIPython          : 8.1.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : 1.4.31\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46298/timeline',
#   'performed_via_github_app': None}]

# %%
pd.DataFrame(data1,columns=['url','repository_url','labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df2 = pd.DataFrame(data1,columns=['url','repository_url','labels_url','user'])
df2
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'mvashishtha', 'id': 10712109, 'node...
# 1   {'login': 'scotscotmcc', 'id': 83373712, 'node...
# 2   {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 3   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 4   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 5   {'login': 'ryansdowning', 'id': 20880292, 'nod...
# 6   {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 7   {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 8   {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 9   {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 11  {'login': 'fangchenli', 'id': 7614606, 'node_i...
# 12  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 13  {'login': 'jreback', 'id': 953992, 'node_id': ...
# 14  {'login': 'Diwakar-Gupta', 'id': 39624018, 'no...
# 15  {'login': 'vyasr', 'id': 1538165, 'node_id': '...
# 16  {'login': 'idanhazan', 'id': 19217750, 'node_i...
# 17  {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 18  {'login': 'brandon-b-miller', 'id': 53796099, ...
# 19  {'login': 'panda-byte', 'id': 41342515, 'node_...
# 20  {'login': 'jonashaag', 'id': 175722, 'node_id'...
# 21  {'login': 'smarie', 'id': 3236794, 'node_id': ...
# 22  {'login': 'ivirshup', 'id': 8238804, 'node_id'...
# 23  {'login': 'tswast', 'id': 247555, 'node_id': '...
# 24  {'login': 'janosh', 'id': 30958850, 'node_id':...
# 25  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 26  {'login': 'jloxh', 'id': 73829711, 'node_id': ...
# 27  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 28  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 29  {'login': 'TouriM', 'id': 726951, 'node_id': '...

# %%
df2.to_csv('jsonResponse.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
l = [4,5,6,7,8,9,0,"sudh","kumar"]

# %%
l[0]
# Out:
# 4

# %%
l[l==8]
# Out:
# 4

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
col_name = df.dtypes[df.dtypes == "object"].index

# %%
df[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df["ineuron"] = "sudh"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sudh
# 1        0          PC 17599  71.2833   C85        C    sudh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sudh
# 3        0            113803  53.1000  C123        S    sudh
# 4        0            373450   8.0500   NaN        S    sudh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sudh
# 887      0            112053  30.0000   B42        S    sudh
# 888      2        W./C. 6607  23.4500   NaN        S    sudh
# 889      0            111369  30.0000  C148        C    sudh
# 890      0            370376   7.7500   NaN        Q    sudh
#
# [891 rows x 13 columns]

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].head(15)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][::-1]
# Out:
# 890                                  Dooley, Mr. Patrick
# 889                                Behr, Mr. Karl Howell
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 887                         Graham, Miss. Margaret Edith
# 886                                Montvila, Rev. Juozas
#                              ...
# 4                               Allen, Mr. William Henry
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2                                 Heikkinen, Miss. Laina
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 0                                Braund, Mr. Owen Harris
# Name: Name, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sudh
# 1        0          PC 17599  71.2833   C85        C    sudh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sudh
# 3        0            113803  53.1000  C123        S    sudh
# 4        0            373450   8.0500   NaN        S    sudh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sudh
# 887      0            112053  30.0000   B42        S    sudh
# 888      2        W./C. 6607  23.4500   NaN        S    sudh
# 889      0            111369  30.0000  C148        C    sudh
# 890      0            370376   7.7500   NaN        Q    sudh
#
# [891 rows x 13 columns]

# %%
df[df['Age'].isnull() == True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 177

# %%
ind = df[df['Age'].isnull() == True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked ineuron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    sudh
# 17     male  NaN      0      0      244373  13.0000   NaN        S    sudh
# 19   female  NaN      0      0        2649   7.2250   NaN        C    sudh
# 26     male  NaN      0      0        2631   7.2250   NaN        C    sudh
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    sudh
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    sudh
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    sudh
# 868    male  NaN      0      0      345777   9.5000   NaN        S    sudh
# 878    male  NaN      0      0      349217   7.8958   NaN        S    sudh
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    sudh
#
# [177 rows x 13 columns]

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked ineuron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    sudh
# 17     male  NaN      0      0      244373  13.0000   NaN        S    sudh
# 19   female  NaN      0      0        2649   7.2250   NaN        C    sudh
# 26     male  NaN      0      0        2631   7.2250   NaN        C    sudh
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    sudh
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    sudh
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    sudh
# 868    male  NaN      0      0      345777   9.5000   NaN        S    sudh
# 878    male  NaN      0      0      349217   7.8958   NaN        S    sudh
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    sudh
#
# [177 rows x 13 columns]

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[df["Fare"] == df['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [raw]
# 1 . Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .

# %%
pd.read_csv('bank.csv',sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %% [raw]
# 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .

# %% [raw]
# Read all the resume form ineurno git in pdf , word , and try to create a dataframe with resume name as a index value , and
# in column i am expecting email id , linked in id , git id  , sills as a result .

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male      0      0
# 887                       Graham, Miss. Margaret Edith  female      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 889                              Behr, Mr. Karl Howell    male      0      0
# 890                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 9 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(axis=1,thresh=800)
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3, 6, 10, 11, 21, 23, 27, 52, 54, 62, 66, 75, 88, 92, 96, 97, 102, 110, 118, 123, 124, 136, 137, 139, 148, 151, 170, 174, 177, 183, 193, 194, 195, 205, 209, 215, 218, 224, 230, 245, 248, 251, 252, 257, 262, 263, 268, 269, 273, 275, 291, 292, 297, 299, 305, 307, 309, 310, 311, 318, 319, 325, 327, 329, 331, 332, 336, 337, 339, 340, 341, 345, 356, 366, 369, 370, 377, 390, 393, 394, 412, 429, 430, 434, 435, 438, 445, 449, 452, 453, 456, 460, 462, 473, 484, 486, 487, 492, 496, ...]
#
# [183 rows x 0 columns]

# %%
df.dropna(axis=1,how="all")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0          60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1         123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0

# %%
df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count      60.000000  123.000000
# mean      402.983333  480.918699
# std       252.917183  241.058955
# min         7.000000    2.000000
# 25%       174.000000  309.000000
# 50%       359.000000  497.000000
# 75%       634.500000  690.500000
# max       873.000000  890.000000

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count      60.000000  123.000000
# mean      402.983333  480.918699
# std       252.917183  241.058955
# min         7.000000    2.000000
# 25%       174.000000  309.000000
# 50%       359.000000  497.000000
# 75%       634.500000  690.500000
# max       873.000000  890.000000

# %%
df1 = pd.read_csv('bank.csv',sep=";")

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
l = []
for i in df1['education'].unique():
    l.append(df1[df1['education'] == i ])

# %%
df2 = l[0]

# %%
df2
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4480   cellular   16   apr       743         1     -1         0  unknown   no
# 4485   cellular   11   may       238         2    361         5  failure   no
# 4486    unknown    9   may       514         1     -1         0  unknown   no
# 4499   cellular   21   nov       362         1     -1         0  unknown   no
# 4503   cellular   29   jul       816         6     -1         0  unknown  yes
#
# [678 rows x 17 columns]

# %%
df3 = l[1]

# %%
df3
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1     cellular   11   may       220         1    339         4  failure  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 10     unknown   20   may       273         1     -1         0  unknown  no
# 11    cellular   17   apr       113         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4514  cellular   20   apr        45         4    153         1  failure  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
#
# [2306 rows x 17 columns]

# %%
pd.concat([df2,df3])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4514   cellular   20   apr        45         4    153         1  failure   no
# 4515   cellular    7   jul       624         5     -1         0  unknown   no
# 4516   cellular   30   jul       329         5     -1         0  unknown   no
# 4518   cellular   19   aug       151        11     -1         0  unknown   no
# 4519   cellular    6   feb       129         4    211         3    other   no
#
# [2984 rows x 17 columns]

# %%
df2 = df2.head()

# %%
df3 = df3.head()

# %%
pd.concat([df2,df3],axis=1)
# Out:
#      age          job   marital education default  balance housing loan  \
# 0   30.0   unemployed   married   primary      no   1787.0      no   no
# 9   43.0     services   married   primary      no    -88.0     yes  yes
# 18  25.0  blue-collar    single   primary      no   -221.0     yes   no
# 26  55.0  blue-collar   married   primary      no    627.0     yes   no
# 36  78.0      retired  divorced   primary      no    229.0      no   no
# 1    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 4    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 7    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 10   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 11   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
#
#       contact   day  ... loan   contact   day  month  duration campaign  \
# 0    cellular  19.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# 9    cellular  17.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# 18    unknown  23.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# 26    unknown   5.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# 36  telephone  22.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# 1         NaN   NaN  ...  yes  cellular  11.0    may     220.0      1.0
# 4         NaN   NaN  ...   no   unknown   5.0    may     226.0      1.0
# 7         NaN   NaN  ...   no  cellular   6.0    may     151.0      2.0
# 10        NaN   NaN  ...   no   unknown  20.0    may     273.0      1.0
# 11        NaN   NaN  ...   no  cellular  17.0    apr     113.0      2.0
#
#     pdays  previous poutcome    y
# 0     NaN       NaN      NaN  NaN
# 9     NaN       NaN      NaN  NaN
# 18    NaN       NaN      NaN  NaN
# 26    NaN       NaN      NaN  NaN
# 36    NaN       NaN      NaN  NaN
# 1   339.0       4.0  failure   no
# 4    -1.0       0.0  unknown   no
# 7    -1.0       0.0  unknown   no
# 10   -1.0       0.0  unknown   no
# 11   -1.0       0.0  unknown   no
#
# [10 rows x 34 columns]

# %%
df2.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df2 = df2[['age', 'job', 'marital']]

# %%
df3 = df3[['age', 'job', 'marital']]

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df5 = pd.concat([df2,df3],axis=1)

# %%
    df5
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
df5['age']
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
df5.iloc[:,3]
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df5.iloc[:,[3,4]]
# Out:
#      age          job
# 0    NaN          NaN
# 9    NaN          NaN
# 18   NaN          NaN
# 26   NaN          NaN
# 36   NaN          NaN
# 1   33.0     services
# 4   59.0  blue-collar
# 7   39.0   technician
# 10  39.0     services
# 11  43.0       admin.

# %%
df5.iloc[[4,5],[3,4]]
# Out:
#      age       job
# 36   NaN       NaN
# 1   33.0  services

# %%
df5.loc[[9,10]]
# Out:
#      age       job  marital   age       job  marital
# 9   43.0  services  married   NaN       NaN      NaN
# 10   NaN       NaN      NaN  39.0  services  married

# %%
df5.loc[[9,10],['age']]
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18],['job','marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[1:3,1:3]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[[1,2],[1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18],['marital']]
# Out:
#     marital
# 9   married
# 18   single

# %%
df2.iloc[[1,2],[2]]
# Out:
#     marital
# 9   married
# 18   single

# %%
pd.merge(df2,df3, on="age")
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2,df3, on="age",how='left')
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
pd.merge(df2,df3, on="age",how='right')
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
pd.merge(df2,df3, on="age",how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df2.join(df3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13648/2864750135.py in <module>
# ----> 1 df2.join(df3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9246         5  K1  A5   B1
#    9247         """
# -> 9248         return self._join_compat(
#    9249             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9250         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9277                     sort=sort,
#    9278                 )
# -> 9279             return merge(
#    9280                 self,
#    9281                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2311
#    2312     if not lsuffix and not rsuffix:
# -> 2313         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2314
#    2315     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['age', 'job', 'marital'], dtype='object')

# %%
df2.join(df3,on="age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13648/3530744838.py in <module>
# ----> 1 df2.join(df3,on="age")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9246         5  K1  A5   B1
#    9247         """
# -> 9248         return self._join_compat(
#    9249             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9250         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9277                     sort=sort,
#    9278                 )
# -> 9279             return merge(
#    9280                 self,
#    9281                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2311
#    2312     if not lsuffix and not rsuffix:
# -> 2313         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2314
#    2315     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['age', 'job', 'marital'], dtype='object')

# %%
df2 = df2.set_index('age')
df2
# Out:
#              job   marital
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3 = df3.set_index('age')
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13648/2864750135.py in <module>
# ----> 1 df2.join(df3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9246         5  K1  A5   B1
#    9247         """
# -> 9248         return self._join_compat(
#    9249             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9250         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9277                     sort=sort,
#    9278                 )
# -> 9279             return merge(
#    9280                 self,
#    9281                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     716         join_index, left_indexer, right_indexer = self._get_join_info()
#     717
# --> 718         llabels, rlabels = _items_overlap_with_suffix(
#     719             self.left._info_axis, self.right._info_axis, self.suffixes
#     720         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2311
#    2312     if not lsuffix and not rsuffix:
# -> 2313         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2314
#    2315     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['job', 'marital'], dtype='object')

# %%
df2.rename(columns={'job':'job1','marital':'marital1'},inplace=True)

# %%
df2
# Out:
#             job1  marital1
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df2.join(df3)
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df2.join(df3,how='inner')
# Out:
#          job1 marital1     job  marital
# age
# 43   services  married  admin.  married

# %%
pd.merge(df2,df3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13648/3652323198.py in <module>
# ----> 1 pd.merge(df2,df3)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     680             warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
#     681
# --> 682         self._validate_specification()
#     683
#     684         cross_col = None
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1347                 common_cols = left_cols.intersection(right_cols)
#    1348                 if len(common_cols) == 0:
# -> 1349                     raise MergeError(
#    1350                         "No common columns to perform merge on. "
#    1351                         f"Merge options: left_on={self.left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
df2.join(df3)
# Out:
#             job1  marital1     job  marital
# age
# 25   blue-collar    single     NaN      NaN
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
df3.reset_index()
# Out:
#    age          job  marital
# 0   33     services  married
# 1   59  blue-collar  married
# 2   39   technician  married
# 3   39     services  married
# 4   43       admin.  married

# %%
pd.merge(df3.reset_index(),df2.reset_index())
# Out:
#    age     job  marital      job1 marital1
# 0   43  admin.  married  services  married

# %%
pd.merge(df2,df3,left_on='job1',right_on='job')
# Out:
#           job1 marital1          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar   single  blue-collar  married
# 3  blue-collar  married  blue-collar  married

# %%
df3 = df3.reset_index()

# %%
df3
# Out:
#    age          job  marital
# 0   33     services  married
# 1   59  blue-collar  married
# 2   39   technician  married
# 3   39     services  married
# 4   43       admin.  married

# %%
df3.age
# Out:
# 0    33
# 1    59
# 2    39
# 3    39
# 4    43
# Name: age, dtype: int64

# %%
df3['age']
# Out:
# 0    33
# 1    59
# 2    39
# 3    39
# 4    43
# Name: age, dtype: int64

# %%
df = pd.DataFrame({'col1' : [1,2,3,4,5],
              'col2' : [45,56,67,34,34],
              'col3': "sudhanshu kumar krish ineuron one".split()
     })

# %%
"sudhanshu kumar krish ineuron one".split()
# Out:
# ['sudhanshu', 'kumar', 'krish', 'ineuron', 'one']

# %%
df
# Out:
#    col1  col2       col3
# 0     1    45  sudhanshu
# 1     2    56      kumar
# 2     3    67      krish
# 3     4    34    ineuron
# 4     5    34        one

# %%
df['col4'] = df['col1']**2

# %%
df
# Out:
#    col1  col2       col3  col4
# 0     1    45  sudhanshu     1
# 1     2    56      kumar     4
# 2     3    67      krish     9
# 3     4    34    ineuron    16
# 4     5    34        one    25

# %%
df['col5'] = df['col3'].str[0]

# %%
df
# Out:
#    col1  col2       col3  col4 col5
# 0     1    45  sudhanshu     1    s
# 1     2    56      kumar     4    k
# 2     3    67      krish     9    k
# 3     4    34    ineuron    16    i
# 4     5    34        one    25    o

# %%
def test(a) :
    return a**2

# %%
df['col4_4']  = df['col1'].apply(test)

# %%
df
# Out:
#    col1  col2       col3  col4 col5  col4_4
# 0     1    45  sudhanshu     1    s       1
# 1     2    56      kumar     4    k       4
# 2     3    67      krish     9    k       9
# 3     4    34    ineuron    16    i      16
# 4     5    34        one    25    o      25

# %%
def test1(a):
    if a =='s':
        return 's'
    else:
        return 'z'

# %%
df['col6'] = df['col5'].apply(test1)

# %%
df
# Out:
#    col1  col2       col3  col4 col5  col4_4 col6
# 0     1    45  sudhanshu     1    s       1    s
# 1     2    56      kumar     4    k       4    z
# 2     3    67      krish     9    k       9    z
# 3     4    34    ineuron    16    i      16    z
# 4     5    34        one    25    o      25    z

# %%
df['col6_6'] = df['col5'].apply(lambda a : 's' if a == 's' else 'z')

# %%
df
# Out:
#    col1  col2       col3  col4 col5  col4_4 col6 col6_6
# 0     1    45  sudhanshu     1    s       1    s      s
# 1     2    56      kumar     4    k       4    z      z
# 2     3    67      krish     9    k       9    z      z
# 3     4    34    ineuron    16    i      16    z      z
# 4     5    34        one    25    o      25    z      z

# %%
df['col7'] = df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2       col3  col4 col5  col4_4 col6 col6_6  col7
# 0     1    45  sudhanshu     1    s       1    s      s     9
# 1     2    56      kumar     4    k       4    z      z     5
# 2     3    67      krish     9    k       9    z      z     5
# 3     4    34    ineuron    16    i      16    z      z     7
# 4     5    34        one    25    o      25    z      z     3

# %%
import math

# %%
df['col8'] = df['col2'].apply(math.log)

# %%
df
# Out:
#    col1  col2       col3  col4 col5  col4_4 col6 col6_6  col7      col8
# 0     1    45  sudhanshu     1    s       1    s      s     9  3.806662
# 1     2    56      kumar     4    k       4    z      z     5  4.025352
# 2     3    67      krish     9    k       9    z      z     5  4.204693
# 3     4    34    ineuron    16    i      16    z      z     7  3.526361
# 4     5    34        one    25    o      25    z      z     3  3.526361
