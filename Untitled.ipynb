# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_excel('Data_Train.xlsx')
dataset.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
dataset['Date'] = dataset['Date_of_Journey'].str.split('/').str[0]
dataset['Month'] = dataset['Date_of_Journey'].str.split('/').str[1]
dataset['Year'] = dataset['Date_of_Journey'].str.split('/').str[2]

# %%
dataset['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset['Date'] = dataset['Date_of_Journey'].apply(lambda x:x.split('/')[0])
dataset['Month'] = dataset['Date_of_Journey'].apply(lambda x:x.split('/')[0])
dataset['Year'] = dataset['Date_of_Journey'].apply(lambda x:x.split('/')[0])

# %%
dataset['Date_of_Journey'].apply(lambda x:x.split('/')[0])
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset['Date'] = dataset['Date'].astype(int)
dataset['Month'] = dataset['Month'].astype(int)
dataset['Year'] = dataset['Year'].astype(int)

# %%
dataset['Date'].astype(int)
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4         1
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681     1
# 10682     9
# Name: Date, Length: 10683, dtype: int32

# %%
dataset
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Date             10683 non-null  int32
#  12  Month            10683 non-null  int32
#  13  Year             10683 non-null  int32
# dtypes: int32(3), int64(1), object(10)
# memory usage: 1.0+ MB

# %%
dataset.drop('Date_of_Journey',axis=1, inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# ...

# %%
dataset['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'].apply(lambda x:x.split(' ')[0])
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 10678    22:25
# 10679    23:20
# 10680    11:20
# 10681    14:10
# 10682    19:15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'].str.split(':').str[0]
# Out:
# 0        01
# 1        13
# 2        04
# 3        23
# 4        21
#          ..
# 10678    22
# 10679    23
# 10680    11
# 10681    14
# 10682    19
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'].str.split(':').str[1]
# Out:
# 0        10 22 Mar
# 1               15
# 2        25 10 Jun
# 3               30
# 4               35
#            ...
# 10678           25
# 10679           20
# 10680           20
# 10681           10
# 10682           15
# Name: Arrival_Time, Length: 10683, dtype: object

# %%
dataset['Arrival_Time'] = dataset['Arrival_Time'].apply(lambda x:x.split(' ')[0])
dataset['Arrival_hour'] = dataset['Arrival_Time'].str.split(':').str[0]
dataset['Arrival_min'] = dataset['Arrival_Time'].str.split(':').str[1]

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price  Date  Month  \
# ...

# %%
dataset['Arrival_hour'] = dataset['Arrival_hour'].astype(int)
dataset['Arrival_min'] = dataset['Arrival_min'].astype(int)

# %%
dataset.drop('Arrival_Time',axis=1, inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#       Duration Total_Stops Additional_Info  Price  Date  Month  Year  \
# ...

# %%
dataset['Dep_Time'].str.split(':').str[0]
# Out:
# 0        22
# 1        05
# 2        09
# 3        18
# 4        16
#          ..
# 10678    19
# 10679    20
# 10680    08
# 10681    11
# 10682    10
# Name: Dep_Time, Length: 10683, dtype: object

# %%
dataset['Dep_Time'].str.split(':').str[1]
# Out:
# 0        20
# 1        50
# 2        25
# 3        05
# 4        50
#          ..
# 10678    55
# 10679    45
# 10680    20
# 10681    30
# 10682    55
# Name: Dep_Time, Length: 10683, dtype: object

# %%
dataset['Dep_Time']
# Out:
# 0        22:20
# 1        05:50
# 2        09:25
# 3        18:05
# 4        16:50
#          ...
# 10678    19:55
# 10679    20:45
# 10680    08:20
# 10681    11:30
# 10682    10:55
# Name: Dep_Time, Length: 10683, dtype: object

# %%
dataset['Dep_hour'] = dataset['Dep_Time'].str.split(':').str[0]
dataset['Dep_min'] = dataset['Dep_Time'].str.split(':').str[1]

# %%
dataset['Dep_hour'] = dataset['Dep_hour'].astype(int)
dataset['Dep_min'] = dataset['Dep_min'].astype(int)

# %%
dataset.drop('Dep_Time',axis=1,inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
#  8   Date             10683 non-null  int32
#  9   Month            10683 non-null  int32
#  10  Year             10683 non-null  int32
#  11  Arrival_hour     10683 non-null  int32
#  12  Arrival_min      10683 non-null  int32
#  13  Dep_min          10683 non-null  int32
#  14  Dep_hour         10683 non-null  int32
# dtypes: int32(7), int64(1), object(7)
# memory usage: 959.9+ KB

# %%
dataset['Duration']
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680        3h
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10683, dtype: object

# %%
dataset['Duration'].str[0]
# Out:
# 0        2
# 1        7
# 2        1
# 3        5
# 4        4
#         ..
# 10678    2
# 10679    2
# 10680    3
# 10681    2
# 10682    8
# Name: Duration, Length: 10683, dtype: object

# %%
dataset['Duration'].str[3:5]
# Out:
# 0        50
# 1        25
# 2
# 3        25
# 4        45
#          ..
# 10678    30
# 10679    35
# 10680
# 10681    40
# 10682    20
# Name: Duration, Length: 10683, dtype: object

# %%
dataset['Duration'].str.split(' ').str[0].str.split('h').str[0]
# Out:
# 0         2
# 1         7
# 2        19
# 3         5
# 4         4
#          ..
# 10678     2
# 10679     2
# 10680     3
# 10681     2
# 10682     8
# Name: Duration, Length: 10683, dtype: object

# %%
dataset[dataset['Duration']=='5m']
# Out:
#         Airline  Source Destination                  Route Duration  \
# 6474  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD       5m
#
#      Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 6474     2 stops         No info  17327     6      6     6            16
#
#       Arrival_min  Dep_min  Dep_hour Duration_hour Duration_min
# 6474           55       50        16            5m          NaN

# %%
dataset.drop(6474,axis=0,inplace=True)

# %%
dataset['Duration'].str[3:5]
# Out:
# 0        50
# 1        25
# 3        25
# 4        45
# 5        25
#          ..
# 10678    30
# 10679    35
# 10680
# 10681    40
# 10682    20
# Name: Duration, Length: 10673, dtype: object

# %%
bad_data = dataset[dataset['Duration']=='19h']
bad_data.index
# Out:
# Int64Index([2, 1634, 3089, 3926, 5863, 6315, 8961, 9173, 10324], dtype='int64')

# %%
for ele in bad_data.index:
    dataset.drop(ele,axis=0,inplace=True)

# %%
bad_data = dataset[dataset['Duration']=='2h']
bad_data.index
# Out:
# Int64Index([], dtype='int64')

# %%
dataset['Duration'].str.split(' ').str[0].str.split('h').str[0]
# Out:
# 0        2
# 1        7
# 3        5
# 4        4
# 5        2
#         ..
# 10678    2
# 10679    2
# 10680    3
# 10681    2
# 10682    8
# Name: Duration, Length: 10673, dtype: object

# %%
dataset['Duration_hour'] = dataset['Duration'].str.split(' ').str[0].str.split('h').str[0]
dataset['Duration_min'] = dataset['Duration'].str[3:5]

# %%
dataset['Duration_hour'] = dataset['Duration_hour'].astype(int)
#dataset['Duration_min'] = dataset['Duration_min'].astype(int)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5         SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR   2h 30m
# 10679    Air India   Kolkata    Banglore              CCU → BLR   2h 35m
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       3h
# 10681      Vistara  Banglore   New Delhi              BLR → DEL   2h 40m
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK   8h 20m
#
#       Total_Stops Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# ...

# %%
dataset.drop('Duration',axis=1,inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination                  Route Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# 5         SpiceJet   Kolkata    Banglore              CCU → BLR    non-stop
# ...            ...       ...         ...                    ...         ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679    Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    non-stop
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
# ...

# %%
dataset['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
dataset['Total_Stops'].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: object

# %%
dataset['Total_Stops']=dataset['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})

# %%
dataset
# Out:
#            Airline    Source Destination                  Route  Total_Stops  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL          0.0
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR          2.0
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR          1.0
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL          1.0
# 5         SpiceJet   Kolkata    Banglore              CCU → BLR          0.0
# ...            ...       ...         ...                    ...          ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR          0.0
# 10679    Air India   Kolkata    Banglore              CCU → BLR          0.0
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL          0.0
# 10681      Vistara  Banglore   New Delhi              BLR → DEL          0.0
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK          2.0
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10673 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10673 non-null  object
#  1   Source           10673 non-null  object
#  2   Destination      10673 non-null  object
#  3   Route            10672 non-null  object
#  4   Total_Stops      10672 non-null  float64
#  5   Additional_Info  10673 non-null  object
#  6   Price            10673 non-null  int64
#  7   Date             10673 non-null  int32
#  8   Month            10673 non-null  int32
#  9   Year             10673 non-null  int32
#  10  Arrival_hour     10673 non-null  int32
#  11  Arrival_min      10673 non-null  int32
#  12  Dep_min          10673 non-null  int32
#  13  Dep_hour         10673 non-null  int32
#  14  Duration_hour    10673 non-null  int32
#  15  Duration_min     10673 non-null  object
# ...

# %%
dataset.drop('Route',axis=1,inplace=True)

# %%
dataset
# Out:
#            Airline    Source Destination  Total_Stops Additional_Info  Price  \
# 0           IndiGo  Banglore   New Delhi          0.0         No info   3897
# 1        Air India   Kolkata    Banglore          2.0         No info   7662
# 3           IndiGo   Kolkata    Banglore          1.0         No info   6218
# 4           IndiGo  Banglore   New Delhi          1.0         No info  13302
# 5         SpiceJet   Kolkata    Banglore          0.0         No info   3873
# ...            ...       ...         ...          ...             ...    ...
# 10678     Air Asia   Kolkata    Banglore          0.0         No info   4107
# 10679    Air India   Kolkata    Banglore          0.0         No info   4145
# 10680  Jet Airways  Banglore       Delhi          0.0         No info   7229
# 10681      Vistara  Banglore   New Delhi          0.0         No info  12648
# 10682    Air India     Delhi      Cochin          2.0         No info  11753
#
# ...

# %%
dataset['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'SpiceJet', 'Jet Airways',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
dataset['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
dataset['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
dataset['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
pd.get_dummies(dataset,columns=['Airline','Source','Destination','Additional_Info'])
# Out:
#        Total_Stops  Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 0              0.0   3897    24     24    24             1           10
# 1              2.0   7662     1      1     1            13           15
# 3              1.0   6218    12     12    12            23           30
# 4              1.0  13302     1      1     1            21           35
# 5              0.0   3873    24     24    24            11           25
# ...            ...    ...   ...    ...   ...           ...          ...
# 10678          0.0   4107     9      9     9            22           25
# 10679          0.0   4145    27     27    27            23           20
# 10680          0.0   7229    27     27    27            11           20
# 10681          0.0  12648     1      1     1            14           10
# 10682          2.0  11753     9      9     9            19           15
#
#        Dep_min  Dep_hour  Duration_hour Duration_min  Airline_Air Asia  \
# ...
